# %% [markdown]
# # **Deep Learning Method**
# ### Group 1 - Detection of Negation and Uncertainty
#
# - Marino Oliveros Blanco NIU:1668563
# - Pere Mayol Carbonell NIU:1669503
# - Andreu Gascón Marzo NIU:1670919
# - Judith Zaragoza NIU:1634071

# %% [markdown]
# ## **Library and Data Loading**

# %%
# Libraries
import json
import re
from langdetect import detect # Library for language detection
from spellchecker import SpellChecker
import spacy
import random
import numpy as np
import pandas as pd
import string

# %%
# Loading the training json file
loading_train = open("negacio_train_v2024.json",)
training_data = json.load(loading_train)
print("The training set contains: ", len(training_data), " samples")
# Out:
# The training set contains:  254  samples

# %%
# Loading the json object
loading_test = open("negacio_test_v2024.json")
test_data = json.load(loading_test)
print("The test set contains: ", len(test_data), " samples")
# Out:
# The test set contains:  64  samples

# %% [markdown]
# ## **Data Annotation**
# - Set using ground truth word to either O, NEG, UNC, NSCO, USCO

# %%
def tag_words_from_json(json_data):
    # Initialize lists for all tagged texts and counts
    all_tagged_texts = []
    all_counts = []

    # Iterate through each entry in the JSON data
    for entry in json_data:
        # Extract text and predictions from JSON entry
        text = entry['data']['text']
        predictions = entry['predictions'][0]['result']

        # Initialize counters
        counts = {'NEG': 0, 'NSCO': 0, 'UNC': 0, 'USCO': 0}

        # Initialize tokens and their coordinates
        tokens = []
        start_pos = 0

        # Split text into tokens while tracking their start and end positions
        for word in text.split():
            start = text.find(word, start_pos)
            end = start + len(word)
            tokens.append((word, start, end))
            start_pos = end

        # Initialize tags list
        tags = ['O'] * len(tokens)

        # Tag each word
        for pred in predictions:
            pred_start = pred['value']['start']
            pred_end = pred['value']['end']
            label = pred['value']['labels'][0]

            if label in counts:
                counts[label] += 1
                for i, (word, start, end) in enumerate(tokens):
                    if start < pred_end and end > pred_start:
                        tags[i] = label

        # Combine tokens with tags
        tagged_text = [(token[0], (token[1], token[2]), tags[i]) for i, token in enumerate(tokens)]

        # Append the results to the lists
        all_tagged_texts.append(tagged_text)
        all_counts.append(counts)

    # Return the list of tagged words and counts for all entries
    return all_tagged_texts, all_counts

# %%
# Example usage with all entries
labels, counts_list = tag_words_from_json(training_data)

print("Number of entries in the entry:", len(labels))
print(labels[0]) # Print out an example entry
print(labels[0][0]) # Print out an example word
print(labels[0][0][2]) # Tag
len(labels[0])
# Out:
# Number of entries in the entry: 254
# [('nº', (1, 3), 'O'), ('historia', (4, 12), 'O'), ('clinica:', (13, 21), 'O'), ('**', (22, 24), 'O'), ('***', (25, 28), 'O'), ('***', (29, 32), 'O'), ('nºepisodi:', (33, 43), 'O'), ('********', (44, 52), 'O'), ('sexe:', (53, 58), 'O'), ('home', (59, 63), 'O'), ('data', (64, 68), 'O'), ('de', (69, 71), 'O'), ('naixement:', (72, 82), 'O'), ('16.05.1936', (83, 93), 'O'), ('edat:', (94, 99), 'O'), ('82', (100, 102), 'O'), ('anys', (103, 107), 'O'), ('procedencia', (108, 119), 'O'), ('cex', (120, 123), 'O'), ('mateix', (124, 130), 'O'), ('hosp', (131, 135), 'O'), ('servei', (136, 142), 'O'), ('urologia', (143, 151), 'O'), ('data', (152, 156), 'O'), ("d'ingres", (157, 165), 'O'), ('24.07.2018', (166, 176), 'O'), ('data', (177, 181), 'O'), ("d'alta", (182, 188), 'O'), ('25.07.2018', (189, 199), 'O'), ('08:54:04', (200, 208), 'O'), ('ates', (209, 213), 'O'), ('per', (214, 217), 'O'), ('***************,', (218, 234), 'O'), ('*****;', (235, 241), 'O'), ('****************,', (242, 259), 'O'), ('******', (260, 266), 'O'), ('informe', (267, 274), 'O'), ("d'alta", (275, 281), 'O'), ("d'hospitalitzacio", (282, 299), 'O'), ('motiu', (300, 305), 'O'), ("d'ingres", (306, 314), 'O'), ('paciente', (315, 323), 'O'), ('que', (324, 327), 'O'), ('ingresa', (328, 335), 'O'), ('de', (336, 338), 'O'), ('forma', (339, 344), 'O'), ('programada', (345, 355), 'O'), ('para', (356, 360), 'O'), ('realizacion', (361, 372), 'O'), ('de', (373, 375), 'O'), ('uretrotomia', (376, 387), 'O'), ('interna', (388, 395), 'O'), ('.', (396, 397), 'O'), ('antecedents', (398, 409), 'O'), ('alergia', (410, 417), 'O'), ('a', (418, 419), 'O'), ('penicilina', (420, 430), 'O'), ('y', (431, 432), 'O'), ('cloramfenicol', (433, 446), 'O'), ('.', (447, 448), 'O'), ('no', (449, 451), 'NEG'), ('habitos', (452, 459), 'NSCO'), ('toxicos.', (460, 468), 'NSCO'), ('antecedentes', (469, 481), 'O'), ('medicos:', (482, 490), 'O'), ('bloqueo', (491, 498), 'O'), ('auriculoventricular', (499, 518), 'O'), ('de', (519, 521), 'O'), ('primer', (522, 528), 'O'), ('grado', (529, 534), 'O'), ('hipertension', (535, 547), 'O'), ('arterial.', (548, 557), 'O'), ('diverticulosis', (558, 572), 'O'), ('extensa', (573, 580), 'O'), ('insuficiencia', (581, 594), 'O'), ('renal', (595, 600), 'O'), ('cronica', (601, 608), 'O'), ('colelitiasis', (609, 621), 'O'), ('antecedentes', (622, 634), 'O'), ('quirurgicos:', (635, 647), 'O'), ('exeresis', (648, 656), 'O'), ('de', (657, 659), 'O'), ('lesiones', (660, 668), 'O'), ('cutaneas', (669, 677), 'O'), ('con', (678, 681), 'O'), ('anestesia', (682, 691), 'O'), ('local', (692, 697), 'O'), ('protesis', (698, 706), 'O'), ('total', (707, 712), 'O'), ('de', (713, 715), 'O'), ('cadera', (716, 722), 'O'), ('cordectomia', (723, 734), 'O'), ('herniorrafia', (735, 747), 'O'), ('inguinal', (748, 756), 'O'), ('proces', (757, 763), 'O'), ('actual', (764, 770), 'O'), ('varon', (771, 776), 'O'), ('de', (777, 779), 'O'), ('81a', (780, 783), 'O'), ('que', (784, 787), 'O'), ('a', (788, 789), 'O'), ('raiz', (790, 794), 'O'), ('de', (795, 797), 'O'), ('episodio', (798, 806), 'O'), ('de', (807, 809), 'O'), ('hematuria', (810, 819), 'O'), ('macroscopica', (820, 832), 'O'), ('se', (833, 835), 'O'), ('realiza', (836, 843), 'O'), ('cistoscopia', (844, 855), 'NSCO'), ('que', (856, 859), 'O'), ('es', (860, 862), 'O'), ('negativa', (863, 871), 'NEG'), ('para', (872, 876), 'NSCO'), ('lesiones', (877, 885), 'NSCO'), ('malignas', (886, 894), 'NSCO'), ('pero', (895, 899), 'O'), ('se', (900, 902), 'O'), ('objetiva', (903, 911), 'O'), ('estenosis', (912, 921), 'O'), ('de', (922, 924), 'O'), ('uretra', (925, 931), 'O'), ('.', (932, 933), 'O'), ('se', (934, 936), 'O'), ('intentan', (937, 945), 'O'), ('dilataciones', (946, 958), 'O'), ('progresivas', (959, 970), 'O'), ('en', (971, 973), 'O'), ('el', (974, 976), 'O'), ('gabinete', (977, 985), 'O'), ('de', (986, 988), 'O'), ('urologia', (989, 997), 'O'), ('sin', (998, 1001), 'NEG'), ('exito.', (1002, 1008), 'NSCO'), ('se', (1009, 1011), 'O'), ('solicita', (1012, ...
# ('nº', (1, 3), 'O')
# O
# 554

# %%
word_feature = []
scope_feature = []
tag_feature = []
maj_number = []
contains_num = []
num = ['1', '2', '3', '4', '5', '6', '7', '8', '9', '0']

def num_in_word(word):
    for thing in word:
        if thing in num:
            return 1
    return 0

def proportion_number(word):
    count= 0
    for thing in word:
        if thing in num:
            count+=1
    if count > (len(word)/2):
        return 1
    return 0


for label in labels:
    for it in label:
        word_feature.append(it[0])
        scope_feature.append(it[1])
        tag_feature.append(it[2])

        word_separate = it[0].split()

        contains_num.append(num_in_word(it[0]))
        maj_number.append(proportion_number(it[0]))

# %%
print(f'The lenght of Word Feature is {len(word_feature)}')
print(f'The lenght of Scope Feature is {len(scope_feature)}')
print(f'The lenght of Tag Feature is {len(tag_feature)}')
print(f'The lenght of Majority Number Feature is {len(maj_number)}')
print(f'The lenght of Contains Number Feature is {len(contains_num)}')
# Out:
# The lenght of Word Feature is 185054
# The lenght of Scope Feature is 185054
# The lenght of Tag Feature is 185054
# The lenght of Majority Number Feature is 185054
# The lenght of Contains Number Feature is 185054

# %% [markdown]
# ## **Feature Extraction**

# %% [markdown]
# Relevant features to be extracted:
# - POS Tags
# - NER Tags
# - Dependency Parsing trees
# - Coordinates
# - Negation Cues and Uncertainty Cues
# - Context Window????

# %%
#load spacy's spanish special.
nlp = spacy.load("es_core_news_md")
#to get the POS as a feature for each word.
def get_pos_tags(words):
    text = ' '.join(words) #convert the words to text.
    doc = nlp(text) #make it a doc using the function dowloaded before from spacy.

    #Create a dictionary where the key = word and the value = POS tag.
    pos_tags_dict = {token.text: token.pos_ for token in doc} 
    lemma_tags_dict = {token.text: token.lemma_ for token in doc} 
    
    pos_tags = [pos_tags_dict.get(word, 'O') for word in words]
    lemma_ = [lemma_tags_dict.get(word, 'O') for word in words]
    #print(f'Length of Words---> {len(pos_tags_dict)}') 
    return pos_tags, lemma_

seperate_texts = []
for label in labels:
    text = []
    for it in label:
        text.append(it[0])
    seperate_texts.append(text)

# %%
# Create a list of texts from the labels
separate_texts = []
for label in labels:
    text = []
    for it in label:
        if isinstance(it, str):
            text.append(it)
        elif isinstance(it, tuple) and isinstance(it[0], str):
            text.append(it[0])
    separate_texts.append(text)

# Get POS tags for each text
pos_texts = []
lemma_texts = []

for text in separate_texts:
    pos_tags, lemma_tags = get_pos_tags(text)
    pos_texts.append(pos_tags)
    lemma_texts.append(lemma_tags)


# Print lengths for comparison
print(len(separate_texts[0]))  # Length of the first text in separate_texts
print(len(pos_texts[0]))  # Length of the POS tags dictionary for the first text

# Print the POS tags for the first text as a sample
print(separate_texts[1])
print(pos_texts[1])
# Out:
# 554
# 554
# ['nº', 'historia', 'clinica:', '**', '***', '***', 'nºepisodi:', '********', 'sexe:', 'dona', 'data', 'de', 'naixement:', '04.08.2000', 'edat:', '19', 'anys', 'procedencia', 'domicil/res.soc', 'servei', 'obstetricia', 'data', "d'ingres", '04.10.2019', 'data', "d'alta", '06.10.2019', '13:02:36', 'ates', 'per', '******************,', '*****;', '****************,', '********', 'informe', "d'alta", "d'hospitalitzacio", 'motiu', "d'ingres", 'treball', 'de', 'part', 'antecedents', 'no', 'al·lergies', 'medicamentoses', 'conegudes.', 'no', 'intervencions', 'quirurgiques', 'ni', 'altres', 'antecedents', 'patologics.', 'nega', 'habits', 'toxics.', 'no', 'medicacio', 'habitual.', 'evolucio', 'clinica', 'evolucion', 'parto', 'finaliza', 'por', 'parto', 'eutocico', 'el', 'dia', '04/10', 'a', 'las', '9:34h', 'obtencion', 'de', 'rn', ',', 'sexo:', 'masculino', ',', 'peso:', '2820', 'apgar', ':', '9/10', 'gs:', 'ab+', 'el', 'pueperio', 'transcurre', 'dentro', 'de', 'la', 'normalidad,', 'permaneciendo', 'apiretica,', 'normotensa', 'y', 'con', 'buen', 'estado', 'general.', 'lactancia', 'materna.', 'diagnosticos', 'trabajo', 'de', 'parto', 'desgarros', 'puerperio', 'procedimientos', 'venoclisis', 'monitorizacion', 'nst', 'amniotomia', 'estimulacion', 'oxitocica', 'atencion', 'del', 'parto', 'revision', 'del', 'canal', 'blando', 'del', 'parto', 'sutura', 'de', 'desgarros', 'analgesicos', 'sueroterapia', 'nhc', '**', '***', '***', '&nbsp;(********)', '&nbsp;ami-v-obs', '1/2', 'lopd', 'analiticas', 'recomendaciones', 'control', 'por', 'su', 'tocologo', 'de', 'zona', 'volver', 'a', 'urgencias', 'si', 'precisa', 'ferro', '1', 'comp', 'al', 'dia', 'acido', 'folico', '1', 'al', 'dia', 'durante', 'la', 'lactancia', 'paracetamol', 'si', 'precisa', 'orientacio', 'diagnostica', 'z33.3', 'estat', 'de', 'gestacio,', 'portadora', 'gestacional', 'destinacio', 'a', "l'alta:", 'a', 'domicili', 'nhc', '**', '***', '***', '&nbsp;(********)', '&nbsp;ami-v-obs', '2/2', 'lopd']
# ['NUM', 'NOUN', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'VERB', 'VERB', 'ADP', 'O', 'NUM', 'O', 'NUM', 'PROPN', 'NOUN', 'O', 'PROPN', 'PROPN', 'VERB', 'PROPN', 'NUM', 'VERB', 'PROPN', 'NUM', 'NUM', 'NOUN', 'ADP', 'O', 'O', 'O', 'O', 'NOUN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'ADP', 'PROPN', 'ADJ', 'ADV', 'PROPN', 'PROPN', 'O', 'ADV', 'VERB', 'PROPN', 'CCONJ', 'NUM', 'ADJ', 'O', 'VERB', 'VERB', 'O', 'ADV', 'ADJ', 'O', 'VERB', 'NOUN', 'PROPN', 'PROPN', 'VERB', 'ADP', 'PROPN', 'ADJ', 'DET', 'NOUN', 'NUM', 'ADP', 'DET', 'NUM', 'NOUN', 'ADP', 'PROPN', 'PUNCT', 'O', 'ADJ', 'PUNCT', 'O', 'NUM', 'VERB', 'PUNCT', 'NUM', 'O', 'SYM', 'DET', 'NOUN', 'VERB', 'ADV', 'ADP', 'DET', 'O', 'VERB', 'O', 'ADJ', 'CCONJ', 'ADP', 'ADJ', 'NOUN', 'O', 'NOUN', 'O', 'NOUN', 'NOUN', 'ADP', 'PROPN', 'NOUN', 'ADJ', 'NOUN', 'VERB', 'NOUN', 'VERB', 'ADJ', 'PROPN', 'PROPN', 'PROPN', 'ADP', 'PROPN', 'ADJ', 'ADP', 'NOUN', 'PROPN', 'ADP', 'PROPN', 'NOUN', 'ADP', 'NOUN', 'ADJ', 'NOUN', 'DET', 'O', 'O', 'O', 'O', 'O', 'NUM', 'ADJ', 'ADJ', 'NOUN', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADP', 'NOUN', 'VERB', 'ADP', 'NOUN', 'SCONJ', 'VERB', 'NOUN', 'NUM', 'VERB', 'ADP', 'NOUN', 'ADJ', 'ADJ', 'NUM', 'ADP', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', 'SCONJ', 'VERB', 'PROPN', 'VERB', 'NUM', 'NOUN', 'ADP', 'O', 'NOUN', 'ADJ', 'ADJ', 'ADP', 'O', 'ADP', 'NOUN', 'DET', 'O', 'O', 'O', 'O', 'O', 'NUM', 'ADJ']

# %%
pos_feature_pandas = []
lemma_feature_pandas = []

for text in pos_texts:
    for pos in text:
        pos_feature_pandas.append(pos)
for text in lemma_texts:
    for lemma in text:
        lemma_feature_pandas.append(lemma)

# %%
initial_scopes = []
final_scopes = []

for start, end in scope_feature:
    initial_scopes.append(start)
    final_scopes.append(end)
    
print(f'The lenght of Word Feature is {len(word_feature)}')
print(f'The lenght of Initial Scopes Feature is {len(initial_scopes)}')
print(f'The lenght of Initial Scopes Feature is {len(final_scopes)}')
print(f'The lenght of Tag Feature is {len(tag_feature)}')
print(f'The lenght of POS Feature is {len(pos_feature_pandas)}')
print(f'The lenght of LEMMA Feature is {len(lemma_feature_pandas)}')
# Out:
# The lenght of Word Feature is 185054
# The lenght of Initial Scopes Feature is 185054
# The lenght of Initial Scopes Feature is 185054
# The lenght of Tag Feature is 185054
# The lenght of POS Feature is 185054
# The lenght of LEMMA Feature is 185054

# %%
import pandas as pd
data_tuples = list(zip(word_feature, initial_scopes, final_scopes, tag_feature, pos_feature_pandas, lemma_feature_pandas, contains_num, maj_number))

data = pd.DataFrame(data_tuples, columns=['Word', 'Initial Scopes','Final Scopes','Tag', 'POS', 'LEMMA', 'Contains NUMBER', 'Maj NUMBER'])

# %%
from IPython.display import display

def show_data(datos, first, second):
    styled_data = datos.iloc[first:second].style.set_properties(**{'text-align': 'left'})
    display(styled_data)

show_data(datos=data, first=41, second=100)
# Out:
# <style type="text/css">
# #T_182b9_row0_col0, #T_182b9_row0_col1, #T_182b9_row0_col2, #T_182b9_row0_col3, #T_182b9_row0_col4, #T_182b9_row0_col5, #T_182b9_row0_col6, #T_182b9_row0_col7, #T_182b9_row1_col0, #T_182b9_row1_col1, #T_182b9_row1_col2, #T_182b9_row1_col3, #T_182b9_row1_col4, #T_182b9_row1_col5, #T_182b9_row1_col6, #T_182b9_row1_col7, #T_182b9_row2_col0, #T_182b9_row2_col1, #T_182b9_row2_col2, #T_182b9_row2_col3, #T_182b9_row2_col4, #T_182b9_row2_col5, #T_182b9_row2_col6, #T_182b9_row2_col7, #T_182b9_row3_col0, #T_182b9_row3_col1, #T_182b9_row3_col2, #T_182b9_row3_col3, #T_182b9_row3_col4, #T_182b9_row3_col5, #T_182b9_row3_col6, #T_182b9_row3_col7, #T_182b9_row4_col0, #T_182b9_row4_col1, #T_182b9_row4_col2, #T_182b9_row4_col3, #T_182b9_row4_col4, #T_182b9_row4_col5, #T_182b9_row4_col6, #T_182b9_row4_col7, #T_182b9_row5_col0, #T_182b9_row5_col1, #T_182b9_row5_col2, #T_182b9_row5_col3, #T_182b9_row5_col4, #T_182b9_row5_col5, #T_182b9_row5_col6, #T_182b9_row5_col7, #T_182b9_row6_col0, #T_182b9_row6_col1, #T_182b9_row6_col2, #T_182b9_row6_col3, #T_182b9_row6_col4, #T_182b9_row6_col5, #T_182b9_row6_col6, #T_182b9_row6_col7, #T_182b9_row7_col0, #T_182b9_row7_col1, #T_182b9_row7_col2, #T_182b9_row7_col3, #T_182b9_row7_col4, #T_182b9_row7_col5, #T_182b9_row7_col6, #T_182b9_row7_col7, #T_182b9_row8_col0, #T_182b9_row8_col1, #T_182b9_row8_col2, #T_182b9_row8_col3, #T_182b9_row8_col4, #T_182b9_row8_col5, #T_182b9_row8_col6, #T_182b9_row8_col7, #T_182b9_row9_col0, #T_182b9_row9_col1, #T_182b9_row9_col2, #T_182b9_row9_col3, #T_182b9_row9_col4, #T_182b9_row9_col5, #T_182b9_row9_col6, #T_182b9_row9_col7, #T_182b9_row10_col0, #T_182b9_row10_col1, #T_182b9_row10_col2, #T_182b9_row10_col3, #T_182b9_row10_col4, #T_182b9_row10_col5, #T_182b9_row10_col6, #T_182b9_row10_col7, #T_182b9_row11_col0, #T_182b9_row11_col1, #T_182b9_row11_col2, #T_182b9_row11_col3, #T_182b9_row11_col4, #T_182b9_row11_col5, #T_182b9_row11_col6, #T_182b9_row11_col7, #T_182b9_row12_col0, #T_182b9_row12_col1, #T_182b9_row12_col2, #T_182b9_row12_col3, #T_182b9_row12_col4, #T_182b9_row12_col5, #T_182b9_row12_col6, #T_182b9_row12_col7, #T_182b9_row13_col0, #T_182b9_row13_col1, #T_182b9_row13_col2, #T_182b9_row13_col3, #T_182b9_row13_col4, #T_182b9_row13_col5, #T_182b9_row13_col6, #T_182b9_row13_col7, #T_182b9_row14_col0, #T_182b9_row14_col1, #T_182b9_row14_col2, #T_182b9_row14_col3, #T_182b9_row14_col4, #T_182b9_row14_col5, #T_182b9_row14_col6, #T_182b9_row14_col7, #T_182b9_row15_col0, #T_182b9_row15_col1, #T_182b9_row15_col2, #T_182b9_row15_col3, #T_182b9_row15_col4, #T_182b9_row15_col5, #T_182b9_row15_col6, #T_182b9_row15_col7, #T_182b9_row16_col0, #T_182b9_row16_col1, #T_182b9_row16_col2, #T_182b9_row16_col3, #T_182b9_row16_col4, #T_182b9_row16_col5, #T_182b9_row16_col6, #T_182b9_row16_col7, #T_182b9_row17_col0, #T_182b9_row17_col1, #T_182b9_row17_col2, #T_182b9_row17_col3, #T_182b9_row17_col4, #T_182b9_row17_col5, #T_182b9_row17_col6, #T_182b9_row17_col7, #T_182b9_row18_col0, #T_182b9_row18_col1, #T_182b9_row18_col2, #T_182b9_row18_col3, #T_182b9_row18_col4, #T_182b9_row18_col5, #T_182b9_row18_col6, #T_182b9_row18_col7, #T_182b9_row19_col0, #T_182b9_row19_col1, #T_182b9_row19_col2, #T_182b9_row19_col3, #T_182b9_row19_col4, #T_182b9_row19_col5, #T_182b9_row19_col6, #T_182b9_row19_col7, #T_182b9_row20_col0, #T_182b9_row20_col1, #T_182b9_row20_col2, #T_182b9_row20_col3, #T_182b9_row20_col4, #T_182b9_row20_col5, #T_182b9_row20_col6, #T_182b9_row20_col7, #T_182b9_row21_col0, #T_182b9_row21_col1, #T_182b9_row21_col2, #T_182b9_row21_col3, #T_182b9_row21_col4, #T_182b9_row21_col5, #T_182b9_row21_col6, #T_182b9_row21_col7, #T_182b9_row22_col0, #T_182b9_row22_col1, #T_182b9_row22_col2, #T_182b9_row22_col3, #T_182b9_row22_col4, #T_182b9_row22_col5, #T_182b9_row22_col6, #T_182b9_row22_col7, #T_182b9_row23_col0, #T_182b9_row23_col1, #T_182b9_row23_col2, #T_182b9_row23_col3, #T_182b9_row23_col4, #T_182b9_row23_col5, #T_182b9_row23_col6, #T_182b9_row23_col7, #T_182b9_row24_col0, #T_182b9_row24_col1, #T_182 ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 185054 entries, 0 to 185053
# Data columns (total 8 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Word             185054 non-null  object
#  1   Initial Scopes   185054 non-null  int64
#  2   Final Scopes     185054 non-null  int64
#  3   Tag              185054 non-null  object
#  4   POS              185054 non-null  object
#  5   LEMMA            185054 non-null  object
#  6   Contains NUMBER  185054 non-null  int64
#  7   Maj NUMBER       185054 non-null  int64
# dtypes: int64(4), object(4)
# memory usage: 11.3+ MB

# %%
# Filter the DataFrame where "Maj NUMBER" is equal to 1
filtered_df = data[(data['Maj NUMBER'] == 0) & (data['Contains NUMBER'] == 1)] 
show_data(datos=filtered_df, first=0, second=10)
# Out:
# <style type="text/css">
# #T_56f65_row0_col0, #T_56f65_row0_col1, #T_56f65_row0_col2, #T_56f65_row0_col3, #T_56f65_row0_col4, #T_56f65_row0_col5, #T_56f65_row0_col6, #T_56f65_row0_col7, #T_56f65_row1_col0, #T_56f65_row1_col1, #T_56f65_row1_col2, #T_56f65_row1_col3, #T_56f65_row1_col4, #T_56f65_row1_col5, #T_56f65_row1_col6, #T_56f65_row1_col7, #T_56f65_row2_col0, #T_56f65_row2_col1, #T_56f65_row2_col2, #T_56f65_row2_col3, #T_56f65_row2_col4, #T_56f65_row2_col5, #T_56f65_row2_col6, #T_56f65_row2_col7, #T_56f65_row3_col0, #T_56f65_row3_col1, #T_56f65_row3_col2, #T_56f65_row3_col3, #T_56f65_row3_col4, #T_56f65_row3_col5, #T_56f65_row3_col6, #T_56f65_row3_col7, #T_56f65_row4_col0, #T_56f65_row4_col1, #T_56f65_row4_col2, #T_56f65_row4_col3, #T_56f65_row4_col4, #T_56f65_row4_col5, #T_56f65_row4_col6, #T_56f65_row4_col7, #T_56f65_row5_col0, #T_56f65_row5_col1, #T_56f65_row5_col2, #T_56f65_row5_col3, #T_56f65_row5_col4, #T_56f65_row5_col5, #T_56f65_row5_col6, #T_56f65_row5_col7, #T_56f65_row6_col0, #T_56f65_row6_col1, #T_56f65_row6_col2, #T_56f65_row6_col3, #T_56f65_row6_col4, #T_56f65_row6_col5, #T_56f65_row6_col6, #T_56f65_row6_col7, #T_56f65_row7_col0, #T_56f65_row7_col1, #T_56f65_row7_col2, #T_56f65_row7_col3, #T_56f65_row7_col4, #T_56f65_row7_col5, #T_56f65_row7_col6, #T_56f65_row7_col7, #T_56f65_row8_col0, #T_56f65_row8_col1, #T_56f65_row8_col2, #T_56f65_row8_col3, #T_56f65_row8_col4, #T_56f65_row8_col5, #T_56f65_row8_col6, #T_56f65_row8_col7, #T_56f65_row9_col0, #T_56f65_row9_col1, #T_56f65_row9_col2, #T_56f65_row9_col3, #T_56f65_row9_col4, #T_56f65_row9_col5, #T_56f65_row9_col6, #T_56f65_row9_col7 {
#   text-align: left;
# }
# </style>
# <table id="T_56f65">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_56f65_level0_col0" class="col_heading level0 col0" >Word</th>
#       <th id="T_56f65_level0_col1" class="col_heading level0 col1" >Initial Scopes</th>
#       <th id="T_56f65_level0_col2" class="col_heading level0 col2" >Final Scopes</th>
#       <th id="T_56f65_level0_col3" class="col_heading level0 col3" >Tag</th>
#       <th id="T_56f65_level0_col4" class="col_heading level0 col4" >POS</th>
#       <th id="T_56f65_level0_col5" class="col_heading level0 col5" >LEMMA</th>
#       <th id="T_56f65_level0_col6" class="col_heading level0 col6" >Contains NUMBER</th>
#       <th id="T_56f65_level0_col7" class="col_heading level0 col7" >Maj NUMBER</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_56f65_level0_row0" class="row_heading level0 row0" >505</th>
#       <td id="T_56f65_row0_col0" class="data row0 col0" >38ºc,</td>
#       <td id="T_56f65_row0_col1" class="data row0 col1" >3549</td>
#       <td id="T_56f65_row0_col2" class="data row0 col2" >3554</td>
#       <td id="T_56f65_row0_col3" class="data row0 col3" >O</td>
#       <td id="T_56f65_row0_col4" class="data row0 col4" >O</td>
#       <td id="T_56f65_row0_col5" class="data row0 col5" >O</td>
#       <td id="T_56f65_row0_col6" class="data row0 col6" >1</td>
#       <td id="T_56f65_row0_col7" class="data row0 col7" >0</td>
#     </tr>
#     <tr>
#       <th id="T_56f65_level0_row1" class="row_heading level0 row1" >972</th>
#       <td id="T_56f65_row1_col0" class="data row1 col0" >4gr</td>
#       <td id="T_56f65_row1_col1" class="data row1 col1" >1670</td>
#       <td id="T_56f65_row1_col2" class="data row1 col2" >1673</td>
#       <td id="T_56f65_row1_col3" class="data row1 col3" >O</td>
#       <td id="T_56f65_row1_col4" class="data row1 col4" >NUM</td>
#       <td id="T_56f65_row1_col5" class="data row1 col5" >4gr</td>
#       <td id="T_56f65_row1_col6" class="data row1 col6" >1</td>
#       <td id="T_56f65_row1_col7" class="data row1 col7" >0</td>
#     </tr>
#     <tr>
#       <th id="T_56f65_level0_row2" class="row_heading level0 row2" >974</th>
#       <td id="T_56f65_row2_col0" class="data row2 col0" >c/6hrs</td>
#       <td id="T_56f65_row2_col1" class="data row2 col1" >1677</td>
#       <td id="T_56f65_row2_col2" class="data row2 col2" >1683</td>
#       <td id="T_56f65_row2_col3" class="data row2 col3" >O</td>
#       <td id="T_56f65_row2_col4" class="data row2 col4" >PROPN</td>
#       <td id="T_56f65_row2_col5" class="data row2 col5" >c/6hrs</td>
#       <td id="T_56f65_row2_col6" class="data row2 col6" >1</td>
#       <td id="T_56f65_row2_col7" class="data row2 col7" >0</td>
#     </tr>
#     <tr>
#       <th id="T_56f65_level0_row3" class="row_heading level0 row3" >1042</th>
#       <td id="T_56f65_row3_col0" class="data row3 col0" >c/8hrs</td>
#       <td id="T_56f65_row3_col1" class="data row3 col1" >2124</td>
#       <td id="T_56f65_row3_col2" class="data row3 col2" >2130</td>
#       <td id="T_56f65_row3_col3" class="data row3 col3" >O</td>
#       <td id="T_56f65_row3_col4" class="data row3 col4" >PROPN</td>
#       <td id="T_56f65_row3_col5" class="data row3 col5" >c/8hrs</td>
#       <td id="T_56f65_row3_col6" class="data row3 col6" >1</td>
#       <td id="T_56f65_row3_col7" class="data row3 col7" >0</td>
#     </tr>
#     <tr>
#       <th id="T_56f65_level0_row4" class="row_heading level0 row4" >1207</th>
#       <td id="T_56f65_row4_col0" class="data row4 col0" >x3</td>
#       <td id="T_56f65_row4_col1" class="data row4 col1" >3274</td>
#       <td id="T_56f65_row4_col2" class="data row4 col2" >3276</td>
#       <td id="T_56f65_row4_col3" class="data row4 col3" >O</td>
#       <td id="T_56f65_row4_col4" class="data row4 col4" >PROPN</td>
#       <td id="T_56f65_row4_col5" class="data row4 col5" >x3</td>
#       <td id="T_56f65_row4_col6" class="data row4 col6" >1</td>
#       <td id="T_56f65_row4_col7" class="data row4 col7" >0</td>
#     </tr>
#     <tr>
#       <th id="T_56f65_level0_row5" class="row_heading level0 row5" >1218</th>
#       <td id="T_56f65_row5_col0" class="data row5 col0" >4mg/6h</td>
#       <td id="T_56f65_row5_col1" class="data row5 col1" >3368</td>
#       <td id="T_56f65_row5_col2" class="data row5 col2" >3374</td>
#       <td id="T_56f65_row5_col3" class="data row5 col3" >O</td>
#       <td id="T_56f65_row5_col4" class="data row5 col4" >NUM</td>
#       <td id="T_56f65_row5_col5" class="data row5 col5" >4mg/6h</td>
#       <td id="T_56f65_row5_col6" class="data row5 col6" >1</td>
#       <td id="T_56f65_row5_col7" class="data row5 col7" >0</td>
#     </tr>
#     <tr>
#       <th id="T_56f65_level0_row6" class="row_heading level0 row6" >1233</th>
#       <td id="T_56f65_row6_col0" class="data row6 col0" >500mg/8h</td>
#       <td id="T_56f65_row6_col1" class="data row6 col1" >3484</td>
#       <td id="T_56f65_row6_col2" class="data row6 col2" >3492</td>
#       <td id="T_56f65_row6_col3" class="data row6 col3" >O</td>
#       <td id="T_56f65_row6_col4" class="data row6 col4" >NUM</td>
#       <td id="T_56f65_row6_col5" class="data row6 col5" >500mg/8h</td>
#       <td id="T_56f65_row6_col6" class="data row6 col6" >1</td>
#       <td id="T_56f65_row6_col7" class="data row6 col7" >0</td>
#     </tr>
#     <tr>
#       <th id="T_56f65_level0_row7" class="row_heading level0 row7" >1442</th>
#       <td id="T_56f65_row7_col0" class="data row7 col0" >1º</td>
#       <td id="T_56f65_row7_col1" class="data row7 col1" >620</td>
#       <td id="T_56f65_row7_col2" class="data row7 col2" >622</td>
#       <td id="T_56f65_row7_col3" class="data row7 col3" >O</td>
#       <td id="T_56f65_row7_col4" class="data row7 col4" >NUM</td>
#       <td id="T_56f65_row7_col5" class="data row7 col5" >1º</td>
#       <td id="T_56f65_row7_col6" class="data row7 col6" >1</td>
#       <td id="T_56f65_row7_col7" class="data row7 col7" >0</td>
#     </tr>
#     <tr>
#       <th id="T_56f65_level0_row8" class="row_heading level0 row8" >1492</th>
#       <td id="T_56f65_row8_col0" class="data row8 col0" >abril/18.</td>
#       <td id="T_56f65_row8_col1" class="data row8 col1" >916</td>
#       <td id="T_56f65_row8_col2" class="data row8 col2" >925</td>
#       <td id="T_56f65_row8_col3" class="data row8 col3" >O</td>
#       <td id="T_56f65_row8_col4" class="data row8 col4" >O</td>
#       <td id="T_56f65_row8_col5" class="data row8 col5" >O</td>
#       <td id="T_56f65_row8_col6" class="data row8 col6" >1</td>
#       <td id="T_56f65_row8_col7"

# %%
# Filter the DataFrame where "Maj NUMBER" is equal to 1
filtered_df = data[(data['Maj NUMBER'] == 1) & (data['Contains NUMBER'] == 1)] 
show_data(datos=filtered_df, first=0, second=10)
# Out:
# <style type="text/css">
# #T_7b6fa_row0_col0, #T_7b6fa_row0_col1, #T_7b6fa_row0_col2, #T_7b6fa_row0_col3, #T_7b6fa_row0_col4, #T_7b6fa_row0_col5, #T_7b6fa_row0_col6, #T_7b6fa_row0_col7, #T_7b6fa_row1_col0, #T_7b6fa_row1_col1, #T_7b6fa_row1_col2, #T_7b6fa_row1_col3, #T_7b6fa_row1_col4, #T_7b6fa_row1_col5, #T_7b6fa_row1_col6, #T_7b6fa_row1_col7, #T_7b6fa_row2_col0, #T_7b6fa_row2_col1, #T_7b6fa_row2_col2, #T_7b6fa_row2_col3, #T_7b6fa_row2_col4, #T_7b6fa_row2_col5, #T_7b6fa_row2_col6, #T_7b6fa_row2_col7, #T_7b6fa_row3_col0, #T_7b6fa_row3_col1, #T_7b6fa_row3_col2, #T_7b6fa_row3_col3, #T_7b6fa_row3_col4, #T_7b6fa_row3_col5, #T_7b6fa_row3_col6, #T_7b6fa_row3_col7, #T_7b6fa_row4_col0, #T_7b6fa_row4_col1, #T_7b6fa_row4_col2, #T_7b6fa_row4_col3, #T_7b6fa_row4_col4, #T_7b6fa_row4_col5, #T_7b6fa_row4_col6, #T_7b6fa_row4_col7, #T_7b6fa_row5_col0, #T_7b6fa_row5_col1, #T_7b6fa_row5_col2, #T_7b6fa_row5_col3, #T_7b6fa_row5_col4, #T_7b6fa_row5_col5, #T_7b6fa_row5_col6, #T_7b6fa_row5_col7, #T_7b6fa_row6_col0, #T_7b6fa_row6_col1, #T_7b6fa_row6_col2, #T_7b6fa_row6_col3, #T_7b6fa_row6_col4, #T_7b6fa_row6_col5, #T_7b6fa_row6_col6, #T_7b6fa_row6_col7, #T_7b6fa_row7_col0, #T_7b6fa_row7_col1, #T_7b6fa_row7_col2, #T_7b6fa_row7_col3, #T_7b6fa_row7_col4, #T_7b6fa_row7_col5, #T_7b6fa_row7_col6, #T_7b6fa_row7_col7, #T_7b6fa_row8_col0, #T_7b6fa_row8_col1, #T_7b6fa_row8_col2, #T_7b6fa_row8_col3, #T_7b6fa_row8_col4, #T_7b6fa_row8_col5, #T_7b6fa_row8_col6, #T_7b6fa_row8_col7, #T_7b6fa_row9_col0, #T_7b6fa_row9_col1, #T_7b6fa_row9_col2, #T_7b6fa_row9_col3, #T_7b6fa_row9_col4, #T_7b6fa_row9_col5, #T_7b6fa_row9_col6, #T_7b6fa_row9_col7 {
#   text-align: left;
# }
# </style>
# <table id="T_7b6fa">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7b6fa_level0_col0" class="col_heading level0 col0" >Word</th>
#       <th id="T_7b6fa_level0_col1" class="col_heading level0 col1" >Initial Scopes</th>
#       <th id="T_7b6fa_level0_col2" class="col_heading level0 col2" >Final Scopes</th>
#       <th id="T_7b6fa_level0_col3" class="col_heading level0 col3" >Tag</th>
#       <th id="T_7b6fa_level0_col4" class="col_heading level0 col4" >POS</th>
#       <th id="T_7b6fa_level0_col5" class="col_heading level0 col5" >LEMMA</th>
#       <th id="T_7b6fa_level0_col6" class="col_heading level0 col6" >Contains NUMBER</th>
#       <th id="T_7b6fa_level0_col7" class="col_heading level0 col7" >Maj NUMBER</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7b6fa_level0_row0" class="row_heading level0 row0" >13</th>
#       <td id="T_7b6fa_row0_col0" class="data row0 col0" >16.05.1936</td>
#       <td id="T_7b6fa_row0_col1" class="data row0 col1" >83</td>
#       <td id="T_7b6fa_row0_col2" class="data row0 col2" >93</td>
#       <td id="T_7b6fa_row0_col3" class="data row0 col3" >O</td>
#       <td id="T_7b6fa_row0_col4" class="data row0 col4" >NUM</td>
#       <td id="T_7b6fa_row0_col5" class="data row0 col5" >16.05.1936</td>
#       <td id="T_7b6fa_row0_col6" class="data row0 col6" >1</td>
#       <td id="T_7b6fa_row0_col7" class="data row0 col7" >1</td>
#     </tr>
#     <tr>
#       <th id="T_7b6fa_level0_row1" class="row_heading level0 row1" >15</th>
#       <td id="T_7b6fa_row1_col0" class="data row1 col0" >82</td>
#       <td id="T_7b6fa_row1_col1" class="data row1 col1" >100</td>
#       <td id="T_7b6fa_row1_col2" class="data row1 col2" >102</td>
#       <td id="T_7b6fa_row1_col3" class="data row1 col3" >O</td>
#       <td id="T_7b6fa_row1_col4" class="data row1 col4" >NUM</td>
#       <td id="T_7b6fa_row1_col5" class="data row1 col5" >82</td>
#       <td id="T_7b6fa_row1_col6" class="data row1 col6" >1</td>
#       <td id="T_7b6fa_row1_col7" class="data row1 col7" >1</td>
#     </tr>
#     <tr>
#       <th id="T_7b6fa_level0_row2" class="row_heading level0 row2" >25</th>
#       <td id="T_7b6fa_row2_col0" class="data row2 col0" >24.07.2018</td>
#       <td id="T_7b6fa_row2_col1" class="data row2 col1" >166</td>
#       <td id="T_7b6fa_row2_col2" class="data row2 col2" >176</td>
#       <td id="T_7b6fa_row2_col3" class="data row2 col3" >O</td>
#       <td id="T_7b6fa_row2_col4" class="data row2 col4" >NUM</td>
#       <td id="T_7b6fa_row2_col5" class="data row2 col5" >24.07.2018</td>
#       <td id="T_7b6fa_row2_col6" class="data row2 col6" >1</td>
#       <td id="T_7b6fa_row2_col7" class="data row2 col7" >1</td>
#     </tr>
#     <tr>
#       <th id="T_7b6fa_level0_row3" class="row_heading level0 row3" >28</th>
#       <td id="T_7b6fa_row3_col0" class="data row3 col0" >25.07.2018</td>
#       <td id="T_7b6fa_row3_col1" class="data row3 col1" >189</td>
#       <td id="T_7b6fa_row3_col2" class="data row3 col2" >199</td>
#       <td id="T_7b6fa_row3_col3" class="data row3 col3" >O</td>
#       <td id="T_7b6fa_row3_col4" class="data row3 col4" >NUM</td>
#       <td id="T_7b6fa_row3_col5" class="data row3 col5" >25.07.2018</td>
#       <td id="T_7b6fa_row3_col6" class="data row3 col6" >1</td>
#       <td id="T_7b6fa_row3_col7" class="data row3 col7" >1</td>
#     </tr>
#     <tr>
#       <th id="T_7b6fa_level0_row4" class="row_heading level0 row4" >29</th>
#       <td id="T_7b6fa_row4_col0" class="data row4 col0" >08:54:04</td>
#       <td id="T_7b6fa_row4_col1" class="data row4 col1" >200</td>
#       <td id="T_7b6fa_row4_col2" class="data row4 col2" >208</td>
#       <td id="T_7b6fa_row4_col3" class="data row4 col3" >O</td>
#       <td id="T_7b6fa_row4_col4" class="data row4 col4" >NUM</td>
#       <td id="T_7b6fa_row4_col5" class="data row4 col5" >08:54:04</td>
#       <td id="T_7b6fa_row4_col6" class="data row4 col6" >1</td>
#       <td id="T_7b6fa_row4_col7" class="data row4 col7" >1</td>
#     </tr>
#     <tr>
#       <th id="T_7b6fa_level0_row5" class="row_heading level0 row5" >98</th>
#       <td id="T_7b6fa_row5_col0" class="data row5 col0" >81a</td>
#       <td id="T_7b6fa_row5_col1" class="data row5 col1" >780</td>
#       <td id="T_7b6fa_row5_col2" class="data row5 col2" >783</td>
#       <td id="T_7b6fa_row5_col3" class="data row5 col3" >O</td>
#       <td id="T_7b6fa_row5_col4" class="data row5 col4" >NUM</td>
#       <td id="T_7b6fa_row5_col5" class="data row5 col5" >81a</td>
#       <td id="T_7b6fa_row5_col6" class="data row5 col6" >1</td>
#       <td id="T_7b6fa_row5_col7" class="data row5 col7" >1</td>
#     </tr>
#     <tr>
#       <th id="T_7b6fa_level0_row6" class="row_heading level0 row6" >163</th>
#       <td id="T_7b6fa_row6_col0" class="data row6 col0" >(11/2017):</td>
#       <td id="T_7b6fa_row6_col1" class="data row6 col1" >1206</td>
#       <td id="T_7b6fa_row6_col2" class="data row6 col2" >1216</td>
#       <td id="T_7b6fa_row6_col3" class="data row6 col3" >O</td>
#       <td id="T_7b6fa_row6_col4" class="data row6 col4" >O</td>
#       <td id="T_7b6fa_row6_col5" class="data row6 col5" >O</td>
#       <td id="T_7b6fa_row6_col6" class="data row6 col6" >1</td>
#       <td id="T_7b6fa_row6_col7" class="data row6 col7" >1</td>
#     </tr>
#     <tr>
#       <th id="T_7b6fa_level0_row7" class="row_heading level0 row7" >195</th>
#       <td id="T_7b6fa_row7_col0" class="data row7 col0" >(250</td>
#       <td id="T_7b6fa_row7_col1" class="data row7 col1" >1420</td>
#       <td id="T_7b6fa_row7_col2" class="data row7 col2" >1424</td>
#       <td id="T_7b6fa_row7_col3" class="data row7 col3" >O</td>
#       <td id="T_7b6fa_row7_col4" class="data row7 col4" >O</td>
#       <td id="T_7b6fa_row7_col5" class="data row7 col5" >O</td>
#       <td id="T_7b6fa_row7_col6" class="data row7 col6" >1</td>
#       <td id="T_7b6fa_row7_col7" class="data row7 col7" >1</td>
#     </tr>
#     <tr>
#       <th id="T_7b6fa_level0_row8" class="row_heading level0 row8" >258</th>
#       <td id="T_7b6fa_row8_col0" class="data row8 col0" >(10/2017)</td>
#       <td id="T_7b6fa_row8_col1" class="data row8 col1" >1892</td>
#       <td id="T_7b6fa_row8_col2" class="data row8 col2" >1901</td>
#       <td id="T_7b6fa_row8_col3" class="data row8 col3" >O</td>
#       <td id="T_7b6fa_row8_col4" class="data row8 col4" >O</td>
#       <td id="T_7b6fa_row8_col5" class="data row8 col5" >O</td>
#       <td id="T_7b6fa_row8_col6" class="data row8 col6" >1</td>
#       <td id="T_7b6fa_row8_col7"

# %%
# Filter the DataFrame where "Maj NUMBER" is equal to 1
filtered_df = data[(data['Maj NUMBER'] == 1) & (data['Contains NUMBER'] == 0)] 
show_data(datos=filtered_df, first=0, second=10)
# Out:
# <style type="text/css">
# </style>
# <table id="T_de3e1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_de3e1_level0_col0" class="col_heading level0 col0" >Word</th>
#       <th id="T_de3e1_level0_col1" class="col_heading level0 col1" >Initial Scopes</th>
#       <th id="T_de3e1_level0_col2" class="col_heading level0 col2" >Final Scopes</th>
#       <th id="T_de3e1_level0_col3" class="col_heading level0 col3" >Tag</th>
#       <th id="T_de3e1_level0_col4" class="col_heading level0 col4" >POS</th>
#       <th id="T_de3e1_level0_col5" class="col_heading level0 col5" >LEMMA</th>
#       <th id="T_de3e1_level0_col6" class="col_heading level0 col6" >Contains NUMBER</th>
#       <th id="T_de3e1_level0_col7" class="col_heading level0 col7" >Maj NUMBER</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
# Filter the DataFrame where "Maj NUMBER" is equal to 1
filtered_df = data[(data['Maj NUMBER'] == 0) & (data['Contains NUMBER'] == 0)] 
show_data(datos=filtered_df, first=0, second=10)
# Out:
# <style type="text/css">
# #T_6ed45_row0_col0, #T_6ed45_row0_col1, #T_6ed45_row0_col2, #T_6ed45_row0_col3, #T_6ed45_row0_col4, #T_6ed45_row0_col5, #T_6ed45_row0_col6, #T_6ed45_row0_col7, #T_6ed45_row1_col0, #T_6ed45_row1_col1, #T_6ed45_row1_col2, #T_6ed45_row1_col3, #T_6ed45_row1_col4, #T_6ed45_row1_col5, #T_6ed45_row1_col6, #T_6ed45_row1_col7, #T_6ed45_row2_col0, #T_6ed45_row2_col1, #T_6ed45_row2_col2, #T_6ed45_row2_col3, #T_6ed45_row2_col4, #T_6ed45_row2_col5, #T_6ed45_row2_col6, #T_6ed45_row2_col7, #T_6ed45_row3_col0, #T_6ed45_row3_col1, #T_6ed45_row3_col2, #T_6ed45_row3_col3, #T_6ed45_row3_col4, #T_6ed45_row3_col5, #T_6ed45_row3_col6, #T_6ed45_row3_col7, #T_6ed45_row4_col0, #T_6ed45_row4_col1, #T_6ed45_row4_col2, #T_6ed45_row4_col3, #T_6ed45_row4_col4, #T_6ed45_row4_col5, #T_6ed45_row4_col6, #T_6ed45_row4_col7, #T_6ed45_row5_col0, #T_6ed45_row5_col1, #T_6ed45_row5_col2, #T_6ed45_row5_col3, #T_6ed45_row5_col4, #T_6ed45_row5_col5, #T_6ed45_row5_col6, #T_6ed45_row5_col7, #T_6ed45_row6_col0, #T_6ed45_row6_col1, #T_6ed45_row6_col2, #T_6ed45_row6_col3, #T_6ed45_row6_col4, #T_6ed45_row6_col5, #T_6ed45_row6_col6, #T_6ed45_row6_col7, #T_6ed45_row7_col0, #T_6ed45_row7_col1, #T_6ed45_row7_col2, #T_6ed45_row7_col3, #T_6ed45_row7_col4, #T_6ed45_row7_col5, #T_6ed45_row7_col6, #T_6ed45_row7_col7, #T_6ed45_row8_col0, #T_6ed45_row8_col1, #T_6ed45_row8_col2, #T_6ed45_row8_col3, #T_6ed45_row8_col4, #T_6ed45_row8_col5, #T_6ed45_row8_col6, #T_6ed45_row8_col7, #T_6ed45_row9_col0, #T_6ed45_row9_col1, #T_6ed45_row9_col2, #T_6ed45_row9_col3, #T_6ed45_row9_col4, #T_6ed45_row9_col5, #T_6ed45_row9_col6, #T_6ed45_row9_col7 {
#   text-align: left;
# }
# </style>
# <table id="T_6ed45">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6ed45_level0_col0" class="col_heading level0 col0" >Word</th>
#       <th id="T_6ed45_level0_col1" class="col_heading level0 col1" >Initial Scopes</th>
#       <th id="T_6ed45_level0_col2" class="col_heading level0 col2" >Final Scopes</th>
#       <th id="T_6ed45_level0_col3" class="col_heading level0 col3" >Tag</th>
#       <th id="T_6ed45_level0_col4" class="col_heading level0 col4" >POS</th>
#       <th id="T_6ed45_level0_col5" class="col_heading level0 col5" >LEMMA</th>
#       <th id="T_6ed45_level0_col6" class="col_heading level0 col6" >Contains NUMBER</th>
#       <th id="T_6ed45_level0_col7" class="col_heading level0 col7" >Maj NUMBER</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6ed45_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6ed45_row0_col0" class="data row0 col0" >nº</td>
#       <td id="T_6ed45_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_6ed45_row0_col2" class="data row0 col2" >3</td>
#       <td id="T_6ed45_row0_col3" class="data row0 col3" >O</td>
#       <td id="T_6ed45_row0_col4" class="data row0 col4" >NUM</td>
#       <td id="T_6ed45_row0_col5" class="data row0 col5" >nº</td>
#       <td id="T_6ed45_row0_col6" class="data row0 col6" >0</td>
#       <td id="T_6ed45_row0_col7" class="data row0 col7" >0</td>
#     </tr>
#     <tr>
#       <th id="T_6ed45_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6ed45_row1_col0" class="data row1 col0" >historia</td>
#       <td id="T_6ed45_row1_col1" class="data row1 col1" >4</td>
#       <td id="T_6ed45_row1_col2" class="data row1 col2" >12</td>
#       <td id="T_6ed45_row1_col3" class="data row1 col3" >O</td>
#       <td id="T_6ed45_row1_col4" class="data row1 col4" >NOUN</td>
#       <td id="T_6ed45_row1_col5" class="data row1 col5" >historia</td>
#       <td id="T_6ed45_row1_col6" class="data row1 col6" >0</td>
#       <td id="T_6ed45_row1_col7" class="data row1 col7" >0</td>
#     </tr>
#     <tr>
#       <th id="T_6ed45_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6ed45_row2_col0" class="data row2 col0" >clinica:</td>
#       <td id="T_6ed45_row2_col1" class="data row2 col1" >13</td>
#       <td id="T_6ed45_row2_col2" class="data row2 col2" >21</td>
#       <td id="T_6ed45_row2_col3" class="data row2 col3" >O</td>
#       <td id="T_6ed45_row2_col4" class="data row2 col4" >O</td>
#       <td id="T_6ed45_row2_col5" class="data row2 col5" >O</td>
#       <td id="T_6ed45_row2_col6" class="data row2 col6" >0</td>
#       <td id="T_6ed45_row2_col7" class="data row2 col7" >0</td>
#     </tr>
#     <tr>
#       <th id="T_6ed45_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6ed45_row3_col0" class="data row3 col0" >**</td>
#       <td id="T_6ed45_row3_col1" class="data row3 col1" >22</td>
#       <td id="T_6ed45_row3_col2" class="data row3 col2" >24</td>
#       <td id="T_6ed45_row3_col3" class="data row3 col3" >O</td>
#       <td id="T_6ed45_row3_col4" class="data row3 col4" >O</td>
#       <td id="T_6ed45_row3_col5" class="data row3 col5" >O</td>
#       <td id="T_6ed45_row3_col6" class="data row3 col6" >0</td>
#       <td id="T_6ed45_row3_col7" class="data row3 col7" >0</td>
#     </tr>
#     <tr>
#       <th id="T_6ed45_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6ed45_row4_col0" class="data row4 col0" >***</td>
#       <td id="T_6ed45_row4_col1" class="data row4 col1" >25</td>
#       <td id="T_6ed45_row4_col2" class="data row4 col2" >28</td>
#       <td id="T_6ed45_row4_col3" class="data row4 col3" >O</td>
#       <td id="T_6ed45_row4_col4" class="data row4 col4" >O</td>
#       <td id="T_6ed45_row4_col5" class="data row4 col5" >O</td>
#       <td id="T_6ed45_row4_col6" class="data row4 col6" >0</td>
#       <td id="T_6ed45_row4_col7" class="data row4 col7" >0</td>
#     </tr>
#     <tr>
#       <th id="T_6ed45_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_6ed45_row5_col0" class="data row5 col0" >***</td>
#       <td id="T_6ed45_row5_col1" class="data row5 col1" >29</td>
#       <td id="T_6ed45_row5_col2" class="data row5 col2" >32</td>
#       <td id="T_6ed45_row5_col3" class="data row5 col3" >O</td>
#       <td id="T_6ed45_row5_col4" class="data row5 col4" >O</td>
#       <td id="T_6ed45_row5_col5" class="data row5 col5" >O</td>
#       <td id="T_6ed45_row5_col6" class="data row5 col6" >0</td>
#       <td id="T_6ed45_row5_col7" class="data row5 col7" >0</td>
#     </tr>
#     <tr>
#       <th id="T_6ed45_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_6ed45_row6_col0" class="data row6 col0" >nºepisodi:</td>
#       <td id="T_6ed45_row6_col1" class="data row6 col1" >33</td>
#       <td id="T_6ed45_row6_col2" class="data row6 col2" >43</td>
#       <td id="T_6ed45_row6_col3" class="data row6 col3" >O</td>
#       <td id="T_6ed45_row6_col4" class="data row6 col4" >O</td>
#       <td id="T_6ed45_row6_col5" class="data row6 col5" >O</td>
#       <td id="T_6ed45_row6_col6" class="data row6 col6" >0</td>
#       <td id="T_6ed45_row6_col7" class="data row6 col7" >0</td>
#     </tr>
#     <tr>
#       <th id="T_6ed45_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_6ed45_row7_col0" class="data row7 col0" >********</td>
#       <td id="T_6ed45_row7_col1" class="data row7 col1" >44</td>
#       <td id="T_6ed45_row7_col2" class="data row7 col2" >52</td>
#       <td id="T_6ed45_row7_col3" class="data row7 col3" >O</td>
#       <td id="T_6ed45_row7_col4" class="data row7 col4" >O</td>
#       <td id="T_6ed45_row7_col5" class="data row7 col5" >O</td>
#       <td id="T_6ed45_row7_col6" class="data row7 col6" >0</td>
#       <td id="T_6ed45_row7_col7" class="data row7 col7" >0</td>
#     </tr>
#     <tr>
#       <th id="T_6ed45_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_6ed45_row8_col0" class="data row8 col0" >sexe:</td>
#       <td id="T_6ed45_row8_col1" class="data row8 col1" >53</td>
#       <td id="T_6ed45_row8_col2" class="data row8 col2" >58</td>
#       <td id="T_6ed45_row8_col3" class="data row8 col3" >O</td>
#       <td id="T_6ed45_row8_col4" class="data row8 col4" >O</td>
#       <td id="T_6ed45_row8_col5" class="data row8 col5" >O</td>
#       <td id="T_6ed45_row8_col6" class="data row8 col6" >0</td>
#       <td id="T_6ed45_row8_col7" class="data row8 col7" >0</td>
#     </tr>
#     <tr>
#       <th id="T_6ed45_level0_row9" class

# %% [markdown]
# ## **MODEL**

# %% [markdown]
# ## **MODEL EVALUATION**
