# %% [markdown]
# # **Deep Learning Method**
# ### Group 1 - Detection of Negation and Uncertainty
#
# - Marino Oliveros Blanco NIU:1668563
# - Pere Mayol Carbonell NIU:1669503
# - Andreu Gascón Marzo NIU:1670919
# - Judith Zaragoza NIU:1634071

# %% [markdown]
# ## **Library and Data Loading**

# %%
# Libraries
import json
import re
from langdetect import detect # Library for language detection
from spellchecker import SpellChecker
import spacy
import random
import numpy as np
import pandas as pd
import string
import os

# %%
os.chdir('C:/GitHub Repositories/NLP-Detection-of-Negation-and-Uncertainty-Project-24/Data/')

# %%
# Loading the training json file
loading_train = open("negacio_train_v2024.json",)
training_data = json.load(loading_train)
print("The training set contains: ", len(training_data), " samples")
# Out:
# The training set contains:  254  samples

# %%
# Loading the json object
loading_test = open("negacio_test_v2024.json")
test_data = json.load(loading_test)
print("The test set contains: ", len(test_data), " samples")
# Out:
# The test set contains:  64  samples

# %% [markdown]
# ## **Data Annotation**
# - Set using ground truth word to either O, NEG, UNC, NSCO, USCO

# %%
def tag_words_from_json(json_data):
    # Initialize lists for all tagged texts and counts
    all_tagged_texts = []
    all_counts = []

    # Iterate through each entry in the JSON data
    for entry in json_data:
        # Extract text and predictions from JSON entry
        text = entry['data']['text']
        predictions = entry['predictions'][0]['result']

        # Initialize counters
        counts = {'NEG': 0, 'NSCO': 0, 'UNC': 0, 'USCO': 0}

        # Initialize tokens and their coordinates
        tokens = []
        start_pos = 0

        # Split text into tokens while tracking their start and end positions
        for word in text.split():
            start = text.find(word, start_pos)
            end = start + len(word)
            tokens.append((word, start, end))
            start_pos = end

        # Initialize tags list
        tags = ['O'] * len(tokens)

        # Tag each word
        for pred in predictions:
            pred_start = pred['value']['start']
            pred_end = pred['value']['end']
            label = pred['value']['labels'][0]

            if label in counts:
                counts[label] += 1
                for i, (word, start, end) in enumerate(tokens):
                    if start < pred_end and end > pred_start:
                        tags[i] = label

        # Combine tokens with tags
        tagged_text = [(token[0], (token[1], token[2]), tags[i]) for i, token in enumerate(tokens)]

        # Append the results to the lists
        all_tagged_texts.append(tagged_text)
        all_counts.append(counts)

    # Return the list of tagged words and counts for all entries
    return all_tagged_texts, all_counts

# %%
def strip_tokens(tagged_text):
    def find_indices(tokens, start_token, end_token, occurrence=1):
        start_index = None
        end_index = None
        end_token_count = 0
        for i, (word, _, _) in enumerate(tokens):
            if word == start_token and start_index is None:
                start_index = i
            if word == end_token:
                end_token_count += 1
                if end_token_count == occurrence:
                    end_index = i
                    break
        return start_index, end_index

    # Remove sections from "nº" to the second occurrence of "d'ingres"
    start1, end1 = find_indices(tagged_text, 'nº', "d'ingres", occurrence=2)
    if end1 is not None:
        end1 += 1  # Include the end token

    # If the indices are found, remove the section
    new_tagged_text = []
    if start1 is not None and end1 is not None:
        new_tagged_text = tagged_text[:start1] + tagged_text[end1:]
    else:
        new_tagged_text = tagged_text[:]

    # Continuously find and remove all sections from "nhc" to "lopd"
    while True:
        start2, end2 = find_indices(new_tagged_text, 'nhc', 'lopd')
        if start2 is not None and end2 is not None:
            end2 += 1  # Include the end token
            new_tagged_text = new_tagged_text[:start2] + new_tagged_text[end2:]
        else:
            break

    return new_tagged_text

def tag_words_from_json(json_data):
    # Initialize lists for all tagged texts and counts
    all_tagged_texts = []
    all_counts = []

    # Iterate through each entry in the JSON data
    for entry in json_data:
        # Extract text and predictions from JSON entry
        text = entry['data']['text']
        predictions = entry['predictions'][0]['result']

        # Initialize counters
        counts = {'NEG': 0, 'NSCO': 0, 'UNC': 0, 'USCO': 0}

        # Initialize tokens and their coordinates
        tokens = []
        start_pos = 0

        # Split text into tokens while tracking their start and end positions
        for word in text.split():
            start = text.find(word, start_pos)
            end = start + len(word)
            tokens.append((word, start, end))
            start_pos = end

        # Initialize tags list
        tags = ['O'] * len(tokens)

        # Tag each word
        for pred in predictions:
            pred_start = pred['value']['start']
            pred_end = pred['value']['end']
            label = pred['value']['labels'][0]

            if label in counts:
                counts[label] += 1
                for i, (word, start, end) in enumerate(tokens):
                    if start < pred_end and end > pred_start:
                        tags[i] = label

        # Combine tokens with tags
        tagged_text = [(token[0], (token[1], token[2]), tags[i]) for i, token in enumerate(tokens)]

        # Strip unwanted tokens
        stripped_tagged_text = strip_tokens(tagged_text)

        # Append the results to the lists
        all_tagged_texts.append(stripped_tagged_text)
        all_counts.append(counts)

    # Return the list of tagged words and counts for all entries
    return all_tagged_texts, all_counts

# %%
# Example usage with all entries
labels, counts_list = tag_words_from_json(training_data)

print("Number of entries in the entry:", len(labels))
print(labels[0]) # Print out an example entry
print(labels[0][0]) # Print out an example word
print(labels[0][0][2]) # Tag
len(labels[0])
# Out:
# Number of entries in the entry: 254
# [('paciente', (315, 323), 'O'), ('que', (324, 327), 'O'), ('ingresa', (328, 335), 'O'), ('de', (336, 338), 'O'), ('forma', (339, 344), 'O'), ('programada', (345, 355), 'O'), ('para', (356, 360), 'O'), ('realizacion', (361, 372), 'O'), ('de', (373, 375), 'O'), ('uretrotomia', (376, 387), 'O'), ('interna', (388, 395), 'O'), ('.', (396, 397), 'O'), ('antecedents', (398, 409), 'O'), ('alergia', (410, 417), 'O'), ('a', (418, 419), 'O'), ('penicilina', (420, 430), 'O'), ('y', (431, 432), 'O'), ('cloramfenicol', (433, 446), 'O'), ('.', (447, 448), 'O'), ('no', (449, 451), 'NEG'), ('habitos', (452, 459), 'NSCO'), ('toxicos.', (460, 468), 'NSCO'), ('antecedentes', (469, 481), 'O'), ('medicos:', (482, 490), 'O'), ('bloqueo', (491, 498), 'O'), ('auriculoventricular', (499, 518), 'O'), ('de', (519, 521), 'O'), ('primer', (522, 528), 'O'), ('grado', (529, 534), 'O'), ('hipertension', (535, 547), 'O'), ('arterial.', (548, 557), 'O'), ('diverticulosis', (558, 572), 'O'), ('extensa', (573, 580), 'O'), ('insuficiencia', (581, 594), 'O'), ('renal', (595, 600), 'O'), ('cronica', (601, 608), 'O'), ('colelitiasis', (609, 621), 'O'), ('antecedentes', (622, 634), 'O'), ('quirurgicos:', (635, 647), 'O'), ('exeresis', (648, 656), 'O'), ('de', (657, 659), 'O'), ('lesiones', (660, 668), 'O'), ('cutaneas', (669, 677), 'O'), ('con', (678, 681), 'O'), ('anestesia', (682, 691), 'O'), ('local', (692, 697), 'O'), ('protesis', (698, 706), 'O'), ('total', (707, 712), 'O'), ('de', (713, 715), 'O'), ('cadera', (716, 722), 'O'), ('cordectomia', (723, 734), 'O'), ('herniorrafia', (735, 747), 'O'), ('inguinal', (748, 756), 'O'), ('proces', (757, 763), 'O'), ('actual', (764, 770), 'O'), ('varon', (771, 776), 'O'), ('de', (777, 779), 'O'), ('81a', (780, 783), 'O'), ('que', (784, 787), 'O'), ('a', (788, 789), 'O'), ('raiz', (790, 794), 'O'), ('de', (795, 797), 'O'), ('episodio', (798, 806), 'O'), ('de', (807, 809), 'O'), ('hematuria', (810, 819), 'O'), ('macroscopica', (820, 832), 'O'), ('se', (833, 835), 'O'), ('realiza', (836, 843), 'O'), ('cistoscopia', (844, 855), 'NSCO'), ('que', (856, 859), 'O'), ('es', (860, 862), 'O'), ('negativa', (863, 871), 'NEG'), ('para', (872, 876), 'NSCO'), ('lesiones', (877, 885), 'NSCO'), ('malignas', (886, 894), 'NSCO'), ('pero', (895, 899), 'O'), ('se', (900, 902), 'O'), ('objetiva', (903, 911), 'O'), ('estenosis', (912, 921), 'O'), ('de', (922, 924), 'O'), ('uretra', (925, 931), 'O'), ('.', (932, 933), 'O'), ('se', (934, 936), 'O'), ('intentan', (937, 945), 'O'), ('dilataciones', (946, 958), 'O'), ('progresivas', (959, 970), 'O'), ('en', (971, 973), 'O'), ('el', (974, 976), 'O'), ('gabinete', (977, 985), 'O'), ('de', (986, 988), 'O'), ('urologia', (989, 997), 'O'), ('sin', (998, 1001), 'NEG'), ('exito.', (1002, 1008), 'NSCO'), ('se', (1009, 1011), 'O'), ('solicita', (1012, 1020), 'O'), ('estudio', (1021, 1028), 'O'), ('de', (1029, 1031), 'O'), ('imagen', (1032, 1038), 'O'), ('que', (1039, 1042), 'O'), ('confirma', (1043, 1051), 'O'), ('la', (1052, 1054), 'O'), ('existencia', (1055, 1065), 'O'), ('de', (1066, 1068), 'O'), ('estenosis', (1069, 1078), 'O'), ('a', (1079, 1080), 'O'), ('nivel', (1081, 1086), 'O'), ('d', (1087, 1088), 'O'), ('uretra', (1089, 1095), 'O'), ('bulbar', (1096, 1102), 'O'), ('por', (1103, 1106), 'O'), ('lo', (1107, 1109), 'O'), ('que', (1110, 1113), 'O'), ('se', (1114, 1116), 'O'), ('indica', (1117, 1123), 'O'), ('uretrtomia', (1124, 1134), 'O'), ('interna.', (1135, 1143), 'O'), ('exploracio', (1144, 1154), 'O'), ('complementaria', (1155, 1169), 'O'), ('uretrocistografia', (1170, 1187), 'O'), ('retrograda', (1188, 1198), 'O'), ('+', (1199, 1200), 'O'), ('cums', (1201, 1205), 'O'), ('(11/2017):', (1206, 1216), 'O'), ('la', (1217, 1219), 'O'), ('uretrografia', (1220, 1232), 'O'), ('retrograda', (1233, 1243), 'O'), ('muestra', (1244, 1251), 'O'), ('una', (1252, 1255), 'O'), ('uretra', (1256, 1262), 'O'), ('anterior', (1263, 1271), 'O'), ('con', (1272, 1275), 'O'), ('dos', (1276, 1279), 'O'), ('estenosis', (1280, 1 ...
# ('paciente', (315, 323), 'O')
# O
# 497

# %%
word_feature = []
scope_feature = []
tag_feature = []
maj_number = []
contains_num = []
is_number = []
num = ['1', '2', '3', '4', '5', '6', '7', '8', '9', '0']

def num_in_word(word):
    for thing in word:
        if thing in num:
            return 1
    return 0

def num_(word):
    if word.isdigit():
            return 1
    return 0

def proportion_number(word):
    count= 0
    for thing in word:
        if thing in num:
            count+=1
    if count > (len(word)/2):
        return 1
    return 0

for label in labels:
    for it in label:
        word_feature.append(it[0])
        scope_feature.append(it[1])
        tag_feature.append(it[2])

        word_separate = it[0].split()

        contains_num.append(num_in_word(it[0]))
        maj_number.append(proportion_number(it[0]))
        is_number.append(num_(it[0]))

# %%
feature_dict = {}
for i in range(len(word_feature)):
    feature_dict[word_feature[i]] = {
        'Scope': scope_feature[i],
        'Tag': tag_feature[i],
        'Maj NUMBER': maj_number[i],
        'Contains NUMBER': contains_num[i],
        'Is NUMBER': is_number[i]
    }
first_item = next(iter(feature_dict.items()))
print(first_item)
# Out:
# ('paciente', {'Scope': (3194, 3202), 'Tag': 'O', 'Maj NUMBER': 0, 'Contains NUMBER': 0, 'Is NUMBER': 0})

# %%
print(f'The lenght of Word Feature is {len(word_feature)}')
print(f'The lenght of Scope Feature is {len(scope_feature)}')
print(f'The lenght of Tag Feature is {len(tag_feature)}')
print(f'The lenght of Majority Number Feature is {len(maj_number)}')
print(f'The lenght of Contains Number Feature is {len(contains_num)}')
# Out:
# The lenght of Word Feature is 168887
# The lenght of Scope Feature is 168887
# The lenght of Tag Feature is 168887
# The lenght of Majority Number Feature is 168887
# The lenght of Contains Number Feature is 168887

# %% [markdown]
# ## **Feature Extraction**

# %% [markdown]
# Relevant features to be extracted:
# - POS Tags
# - NER Tags
# - Dependency Parsing trees
# - Coordinates
# - Negation Cues and Uncertainty Cues
# - Context Window????

# %%
# !python -m spacy download es_core_news_md
# Out:
# Collecting es-core-news-md==3.7.0
#   Using cached https://github.com/explosion/spacy-models/releases/download/es_core_news_md-3.7.0/es_core_news_md-3.7.0-py3-none-any.whl (42.3 MB)
# Requirement already satisfied: spacy<3.8.0,>=3.7.0 in c:\users\agasc\appdata\local\programs\python\python312\lib\site-packages (from es-core-news-md==3.7.0) (3.7.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\agasc\appdata\local\programs\python\python312\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\agasc\appdata\local\programs\python\python312\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\agasc\appdata\local\programs\python\python312\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\agasc\appdata\local\programs\python\python312\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\agasc\appdata\local\programs\python\python312\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in c:\users\agasc\appdata\local\programs\python\python312\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\agasc\appdata\local\programs\python\python312\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\agasc\appdata\local\programs\python\python312\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\agasc\appdata\local\programs\python\python312\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in c:\users\agasc\appdata\local\programs\python\python312\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\agasc\appdata\local\programs\python\python312\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (0.9.4)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\agasc\appdata\local\programs\python\python312\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\agasc\appdata\local\programs\python\python312\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (4.66.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\agasc\appdata\local\programs\python\python312\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\agasc\appdata\local\programs\python\python312\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (2.7.1)
# Requirement already satisfied: jinja2 in c:\users\agasc\appdata\local\programs\python\python312\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (3.1.4)
# Requirement already satisfied: setuptools in c:\users\agasc\appdata\local\programs\python\python312\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (69.5.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\agasc\appdata\roaming\python\python312\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (24.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\agasc\appdata\local\programs\python\python312\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (3.4.0)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\agasc\appdata\local\programs\python\python312\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (1.26.4)
# Requirement already satisfied: language-data>=1.2 in c:\users\agasc\appdata\local\programs\python\python312\lib\site-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (1.2.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\agasc\appdata\local\programs\python\python312\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.2 in c:\users\agasc\appdata\local\programs\python\python312\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (2.18.2)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\agasc\appdata\local\programs\python\python312\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\agasc\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\agasc\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\agasc\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\agasc\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (2024.2.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\agasc\appdata\local\programs\python\python312\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\agasc\appdata\local\programs\python\python312\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (0.1.4)
# Requirement already satisfied: colorama in c:\users\agasc\appdata\roaming\python\python312\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\agasc\appdata\local\programs\python\python312\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in c:\users\agasc\appdata\local\programs\python\python312\lib\site-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\agasc\appdata\local\programs\python\python312\lib\site-packages (from jinja2->spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (2.1.5)
# Requirement already satisfied: marisa-trie>=0.7.7 in c:\users\agasc\appdata\local\programs\python\python312\lib\site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (1.1.1)
# ✔ Download and installation successful
# You can now load the package via spacy.load('es_core_news_md')

# %%
#load spacy's spanish special.
nlp = spacy.load("es_core_news_md")
#to get the POS as a feature for each word.
def get_pos_tags(words):
    text = ' '.join(words) #convert the words to text.
    doc = nlp(text) #make it a doc using the function dowloaded before from spacy.

    #Create a dictionary where the key = word and the value = POS tag.
    pos_tags_dict = {token.text: token.pos_ for token in doc} 
    lemma_tags_dict = {token.text: token.lemma_ for token in doc} 
    
    pos_tags = [pos_tags_dict.get(word, 'O') for word in words]
    lemma_ = [lemma_tags_dict.get(word, 'O') for word in words]
    #print(f'Length of Words---> {len(pos_tags_dict)}') 
    return pos_tags, lemma_

seperate_texts = []
for label in labels:
    text = []
    for it in label:
        text.append(it[0])
    seperate_texts.append(text)

# %%
# Create a list of texts from the labels
separate_texts = []
for label in labels:
    text = []
    for it in label:
        if isinstance(it, str):
            text.append(it)
        elif isinstance(it, tuple) and isinstance(it[0], str):
            text.append(it[0])
    separate_texts.append(text)

# Get POS tags for each text
pos_texts = []
lemma_texts = []

for text in separate_texts:
    pos_tags, lemma_tags = get_pos_tags(text)
    pos_texts.append(pos_tags)
    lemma_texts.append(lemma_tags)


# Print lengths for comparison
print(len(separate_texts[0]))  # Length of the first text in separate_texts
print(len(pos_texts[0]))  # Length of the POS tags dictionary for the first text

# Print the POS tags for the first text as a sample
print(separate_texts[1])
print(pos_texts[1])
# Out:
# 497
# 497
# ['treball', 'de', 'part', 'antecedents', 'no', 'al·lergies', 'medicamentoses', 'conegudes.', 'no', 'intervencions', 'quirurgiques', 'ni', 'altres', 'antecedents', 'patologics.', 'nega', 'habits', 'toxics.', 'no', 'medicacio', 'habitual.', 'evolucio', 'clinica', 'evolucion', 'parto', 'finaliza', 'por', 'parto', 'eutocico', 'el', 'dia', '04/10', 'a', 'las', '9:34h', 'obtencion', 'de', 'rn', ',', 'sexo:', 'masculino', ',', 'peso:', '2820', 'apgar', ':', '9/10', 'gs:', 'ab+', 'el', 'pueperio', 'transcurre', 'dentro', 'de', 'la', 'normalidad,', 'permaneciendo', 'apiretica,', 'normotensa', 'y', 'con', 'buen', 'estado', 'general.', 'lactancia', 'materna.', 'diagnosticos', 'trabajo', 'de', 'parto', 'desgarros', 'puerperio', 'procedimientos', 'venoclisis', 'monitorizacion', 'nst', 'amniotomia', 'estimulacion', 'oxitocica', 'atencion', 'del', 'parto', 'revision', 'del', 'canal', 'blando', 'del', 'parto', 'sutura', 'de', 'desgarros', 'analgesicos', 'sueroterapia', 'analiticas', 'recomendaciones', 'control', 'por', 'su', 'tocologo', 'de', 'zona', 'volver', 'a', 'urgencias', 'si', 'precisa', 'ferro', '1', 'comp', 'al', 'dia', 'acido', 'folico', '1', 'al', 'dia', 'durante', 'la', 'lactancia', 'paracetamol', 'si', 'precisa', 'orientacio', 'diagnostica', 'z33.3', 'estat', 'de', 'gestacio,', 'portadora', 'gestacional', 'destinacio', 'a', "l'alta:", 'a', 'domicili']
# ['PROPN', 'ADP', 'PROPN', 'ADJ', 'ADV', 'PROPN', 'PROPN', 'O', 'ADV', 'VERB', 'PROPN', 'CCONJ', 'NUM', 'ADJ', 'O', 'VERB', 'VERB', 'O', 'ADV', 'ADJ', 'O', 'VERB', 'NOUN', 'PROPN', 'PROPN', 'VERB', 'ADP', 'PROPN', 'ADJ', 'DET', 'NOUN', 'NUM', 'ADP', 'DET', 'NUM', 'NOUN', 'ADP', 'PROPN', 'PUNCT', 'O', 'ADJ', 'PUNCT', 'O', 'NUM', 'VERB', 'PUNCT', 'NUM', 'O', 'SYM', 'DET', 'NOUN', 'VERB', 'ADV', 'ADP', 'DET', 'O', 'VERB', 'O', 'ADJ', 'CCONJ', 'ADP', 'ADJ', 'NOUN', 'O', 'NOUN', 'O', 'NOUN', 'NOUN', 'ADP', 'PROPN', 'NOUN', 'ADJ', 'NOUN', 'VERB', 'NOUN', 'VERB', 'ADJ', 'PROPN', 'PROPN', 'PROPN', 'ADP', 'PROPN', 'ADJ', 'ADP', 'NOUN', 'PROPN', 'ADP', 'PROPN', 'NOUN', 'ADP', 'NOUN', 'ADJ', 'NOUN', 'ADJ', 'NOUN', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADP', 'NOUN', 'VERB', 'ADP', 'NOUN', 'SCONJ', 'VERB', 'NOUN', 'NUM', 'VERB', 'ADP', 'NOUN', 'ADJ', 'ADJ', 'NUM', 'ADP', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', 'SCONJ', 'VERB', 'PROPN', 'VERB', 'NUM', 'NOUN', 'ADP', 'O', 'NOUN', 'ADJ', 'ADJ', 'ADP', 'O', 'ADP', 'NOUN']

# %%
pos_feature_pandas = []
lemma_feature_pandas = []
sentence_id = []
sentence_idx = 0  # Initialize sentence index

# Assuming pos_texts and lemma_texts are lists of lists, where each inner list represents a sentence
for pos_sentence, lemma_sentence in zip(pos_texts, lemma_texts):
    for pos, lemma in zip(pos_sentence, lemma_sentence):
        pos_feature_pandas.append(pos)
        lemma_feature_pandas.append(lemma)
        sentence_id.append(sentence_idx)
    sentence_idx += 1  # Increment sentence index after processing each sentence

# %%
initial_scopes = []
final_scopes = []

for start, end in scope_feature:
    initial_scopes.append(start)
    final_scopes.append(end)
    
print(f'The lenght of Word Feature is {len(word_feature)}')
print(f'The lenght of Initial Scopes Feature is {len(initial_scopes)}')
print(f'The lenght of Initial Scopes Feature is {len(final_scopes)}')
print(f'The lenght of Tag Feature is {len(tag_feature)}')
print(f'The lenght of POS Feature is {len(pos_feature_pandas)}')
print(f'The lenght of LEMMA Feature is {len(lemma_feature_pandas)}')
# Out:
# The lenght of Word Feature is 168887
# The lenght of Initial Scopes Feature is 168887
# The lenght of Initial Scopes Feature is 168887
# The lenght of Tag Feature is 168887
# The lenght of POS Feature is 168887
# The lenght of LEMMA Feature is 168887

# %%
import pandas as pd
data_tuples = list(zip(word_feature, initial_scopes, final_scopes, tag_feature, pos_feature_pandas, lemma_feature_pandas, is_number,contains_num, maj_number,sentence_id))

data = pd.DataFrame(data_tuples, columns=['Word', 'Initial Scopes','Final Scopes','Tag', 'POS', 'LEMMA', 'NUMBER', 'Contains NUMBER', 'Maj NUMBER', 'text_id'])

# %%
from IPython.display import display

def show_data(datos, first, second):
    styled_data = datos.iloc[first:second].style.set_properties(**{'text-align': 'left'})
    display(styled_data)

show_data(datos=data, first=41, second=100)
# Out:
# <style type="text/css">
# #T_f4065_row0_col0, #T_f4065_row0_col1, #T_f4065_row0_col2, #T_f4065_row0_col3, #T_f4065_row0_col4, #T_f4065_row0_col5, #T_f4065_row0_col6, #T_f4065_row0_col7, #T_f4065_row0_col8, #T_f4065_row0_col9, #T_f4065_row1_col0, #T_f4065_row1_col1, #T_f4065_row1_col2, #T_f4065_row1_col3, #T_f4065_row1_col4, #T_f4065_row1_col5, #T_f4065_row1_col6, #T_f4065_row1_col7, #T_f4065_row1_col8, #T_f4065_row1_col9, #T_f4065_row2_col0, #T_f4065_row2_col1, #T_f4065_row2_col2, #T_f4065_row2_col3, #T_f4065_row2_col4, #T_f4065_row2_col5, #T_f4065_row2_col6, #T_f4065_row2_col7, #T_f4065_row2_col8, #T_f4065_row2_col9, #T_f4065_row3_col0, #T_f4065_row3_col1, #T_f4065_row3_col2, #T_f4065_row3_col3, #T_f4065_row3_col4, #T_f4065_row3_col5, #T_f4065_row3_col6, #T_f4065_row3_col7, #T_f4065_row3_col8, #T_f4065_row3_col9, #T_f4065_row4_col0, #T_f4065_row4_col1, #T_f4065_row4_col2, #T_f4065_row4_col3, #T_f4065_row4_col4, #T_f4065_row4_col5, #T_f4065_row4_col6, #T_f4065_row4_col7, #T_f4065_row4_col8, #T_f4065_row4_col9, #T_f4065_row5_col0, #T_f4065_row5_col1, #T_f4065_row5_col2, #T_f4065_row5_col3, #T_f4065_row5_col4, #T_f4065_row5_col5, #T_f4065_row5_col6, #T_f4065_row5_col7, #T_f4065_row5_col8, #T_f4065_row5_col9, #T_f4065_row6_col0, #T_f4065_row6_col1, #T_f4065_row6_col2, #T_f4065_row6_col3, #T_f4065_row6_col4, #T_f4065_row6_col5, #T_f4065_row6_col6, #T_f4065_row6_col7, #T_f4065_row6_col8, #T_f4065_row6_col9, #T_f4065_row7_col0, #T_f4065_row7_col1, #T_f4065_row7_col2, #T_f4065_row7_col3, #T_f4065_row7_col4, #T_f4065_row7_col5, #T_f4065_row7_col6, #T_f4065_row7_col7, #T_f4065_row7_col8, #T_f4065_row7_col9, #T_f4065_row8_col0, #T_f4065_row8_col1, #T_f4065_row8_col2, #T_f4065_row8_col3, #T_f4065_row8_col4, #T_f4065_row8_col5, #T_f4065_row8_col6, #T_f4065_row8_col7, #T_f4065_row8_col8, #T_f4065_row8_col9, #T_f4065_row9_col0, #T_f4065_row9_col1, #T_f4065_row9_col2, #T_f4065_row9_col3, #T_f4065_row9_col4, #T_f4065_row9_col5, #T_f4065_row9_col6, #T_f4065_row9_col7, #T_f4065_row9_col8, #T_f4065_row9_col9, #T_f4065_row10_col0, #T_f4065_row10_col1, #T_f4065_row10_col2, #T_f4065_row10_col3, #T_f4065_row10_col4, #T_f4065_row10_col5, #T_f4065_row10_col6, #T_f4065_row10_col7, #T_f4065_row10_col8, #T_f4065_row10_col9, #T_f4065_row11_col0, #T_f4065_row11_col1, #T_f4065_row11_col2, #T_f4065_row11_col3, #T_f4065_row11_col4, #T_f4065_row11_col5, #T_f4065_row11_col6, #T_f4065_row11_col7, #T_f4065_row11_col8, #T_f4065_row11_col9, #T_f4065_row12_col0, #T_f4065_row12_col1, #T_f4065_row12_col2, #T_f4065_row12_col3, #T_f4065_row12_col4, #T_f4065_row12_col5, #T_f4065_row12_col6, #T_f4065_row12_col7, #T_f4065_row12_col8, #T_f4065_row12_col9, #T_f4065_row13_col0, #T_f4065_row13_col1, #T_f4065_row13_col2, #T_f4065_row13_col3, #T_f4065_row13_col4, #T_f4065_row13_col5, #T_f4065_row13_col6, #T_f4065_row13_col7, #T_f4065_row13_col8, #T_f4065_row13_col9, #T_f4065_row14_col0, #T_f4065_row14_col1, #T_f4065_row14_col2, #T_f4065_row14_col3, #T_f4065_row14_col4, #T_f4065_row14_col5, #T_f4065_row14_col6, #T_f4065_row14_col7, #T_f4065_row14_col8, #T_f4065_row14_col9, #T_f4065_row15_col0, #T_f4065_row15_col1, #T_f4065_row15_col2, #T_f4065_row15_col3, #T_f4065_row15_col4, #T_f4065_row15_col5, #T_f4065_row15_col6, #T_f4065_row15_col7, #T_f4065_row15_col8, #T_f4065_row15_col9, #T_f4065_row16_col0, #T_f4065_row16_col1, #T_f4065_row16_col2, #T_f4065_row16_col3, #T_f4065_row16_col4, #T_f4065_row16_col5, #T_f4065_row16_col6, #T_f4065_row16_col7, #T_f4065_row16_col8, #T_f4065_row16_col9, #T_f4065_row17_col0, #T_f4065_row17_col1, #T_f4065_row17_col2, #T_f4065_row17_col3, #T_f4065_row17_col4, #T_f4065_row17_col5, #T_f4065_row17_col6, #T_f4065_row17_col7, #T_f4065_row17_col8, #T_f4065_row17_col9, #T_f4065_row18_col0, #T_f4065_row18_col1, #T_f4065_row18_col2, #T_f4065_row18_col3, #T_f4065_row18_col4, #T_f4065_row18_col5, #T_f4065_row18_col6, #T_f4065_row18_col7, #T_f4065_row18_col8, #T_f4065_row18_col9, #T_f4065_row19_col0, #T_f4065_row19_col1, #T_f4065_row19_col2, #T_f4065_row19_col3, #T_f4065_row19_col4, #T_f4 ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 168887 entries, 0 to 168886
# Data columns (total 10 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Word             168887 non-null  object
#  1   Initial Scopes   168887 non-null  int64
#  2   Final Scopes     168887 non-null  int64
#  3   Tag              168887 non-null  object
#  4   POS              168887 non-null  object
#  5   LEMMA            168887 non-null  object
#  6   NUMBER           168887 non-null  int64
#  7   Contains NUMBER  168887 non-null  int64
#  8   Maj NUMBER       168887 non-null  int64
#  9   text_id          168887 non-null  int64
# dtypes: int64(6), object(4)
# memory usage: 12.9+ MB

# %%
# Filter the DataFrame where "Maj NUMBER" is equal to 1
filtered_df = data[(data['Maj NUMBER'] == 0) & (data['Contains NUMBER'] == 1)] 
show_data(datos=filtered_df, first=0, second=10)
# Out:
# <style type="text/css">
# #T_a7bf3_row0_col0, #T_a7bf3_row0_col1, #T_a7bf3_row0_col2, #T_a7bf3_row0_col3, #T_a7bf3_row0_col4, #T_a7bf3_row0_col5, #T_a7bf3_row0_col6, #T_a7bf3_row0_col7, #T_a7bf3_row0_col8, #T_a7bf3_row0_col9, #T_a7bf3_row1_col0, #T_a7bf3_row1_col1, #T_a7bf3_row1_col2, #T_a7bf3_row1_col3, #T_a7bf3_row1_col4, #T_a7bf3_row1_col5, #T_a7bf3_row1_col6, #T_a7bf3_row1_col7, #T_a7bf3_row1_col8, #T_a7bf3_row1_col9, #T_a7bf3_row2_col0, #T_a7bf3_row2_col1, #T_a7bf3_row2_col2, #T_a7bf3_row2_col3, #T_a7bf3_row2_col4, #T_a7bf3_row2_col5, #T_a7bf3_row2_col6, #T_a7bf3_row2_col7, #T_a7bf3_row2_col8, #T_a7bf3_row2_col9, #T_a7bf3_row3_col0, #T_a7bf3_row3_col1, #T_a7bf3_row3_col2, #T_a7bf3_row3_col3, #T_a7bf3_row3_col4, #T_a7bf3_row3_col5, #T_a7bf3_row3_col6, #T_a7bf3_row3_col7, #T_a7bf3_row3_col8, #T_a7bf3_row3_col9, #T_a7bf3_row4_col0, #T_a7bf3_row4_col1, #T_a7bf3_row4_col2, #T_a7bf3_row4_col3, #T_a7bf3_row4_col4, #T_a7bf3_row4_col5, #T_a7bf3_row4_col6, #T_a7bf3_row4_col7, #T_a7bf3_row4_col8, #T_a7bf3_row4_col9, #T_a7bf3_row5_col0, #T_a7bf3_row5_col1, #T_a7bf3_row5_col2, #T_a7bf3_row5_col3, #T_a7bf3_row5_col4, #T_a7bf3_row5_col5, #T_a7bf3_row5_col6, #T_a7bf3_row5_col7, #T_a7bf3_row5_col8, #T_a7bf3_row5_col9, #T_a7bf3_row6_col0, #T_a7bf3_row6_col1, #T_a7bf3_row6_col2, #T_a7bf3_row6_col3, #T_a7bf3_row6_col4, #T_a7bf3_row6_col5, #T_a7bf3_row6_col6, #T_a7bf3_row6_col7, #T_a7bf3_row6_col8, #T_a7bf3_row6_col9, #T_a7bf3_row7_col0, #T_a7bf3_row7_col1, #T_a7bf3_row7_col2, #T_a7bf3_row7_col3, #T_a7bf3_row7_col4, #T_a7bf3_row7_col5, #T_a7bf3_row7_col6, #T_a7bf3_row7_col7, #T_a7bf3_row7_col8, #T_a7bf3_row7_col9, #T_a7bf3_row8_col0, #T_a7bf3_row8_col1, #T_a7bf3_row8_col2, #T_a7bf3_row8_col3, #T_a7bf3_row8_col4, #T_a7bf3_row8_col5, #T_a7bf3_row8_col6, #T_a7bf3_row8_col7, #T_a7bf3_row8_col8, #T_a7bf3_row8_col9, #T_a7bf3_row9_col0, #T_a7bf3_row9_col1, #T_a7bf3_row9_col2, #T_a7bf3_row9_col3, #T_a7bf3_row9_col4, #T_a7bf3_row9_col5, #T_a7bf3_row9_col6, #T_a7bf3_row9_col7, #T_a7bf3_row9_col8, #T_a7bf3_row9_col9 {
#   text-align: left;
# }
# </style>
# <table id="T_a7bf3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a7bf3_level0_col0" class="col_heading level0 col0" >Word</th>
#       <th id="T_a7bf3_level0_col1" class="col_heading level0 col1" >Initial Scopes</th>
#       <th id="T_a7bf3_level0_col2" class="col_heading level0 col2" >Final Scopes</th>
#       <th id="T_a7bf3_level0_col3" class="col_heading level0 col3" >Tag</th>
#       <th id="T_a7bf3_level0_col4" class="col_heading level0 col4" >POS</th>
#       <th id="T_a7bf3_level0_col5" class="col_heading level0 col5" >LEMMA</th>
#       <th id="T_a7bf3_level0_col6" class="col_heading level0 col6" >NUMBER</th>
#       <th id="T_a7bf3_level0_col7" class="col_heading level0 col7" >Contains NUMBER</th>
#       <th id="T_a7bf3_level0_col8" class="col_heading level0 col8" >Maj NUMBER</th>
#       <th id="T_a7bf3_level0_col9" class="col_heading level0 col9" >text_id</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a7bf3_level0_row0" class="row_heading level0 row0" >456</th>
#       <td id="T_a7bf3_row0_col0" class="data row0 col0" >38ºc,</td>
#       <td id="T_a7bf3_row0_col1" class="data row0 col1" >3549</td>
#       <td id="T_a7bf3_row0_col2" class="data row0 col2" >3554</td>
#       <td id="T_a7bf3_row0_col3" class="data row0 col3" >O</td>
#       <td id="T_a7bf3_row0_col4" class="data row0 col4" >O</td>
#       <td id="T_a7bf3_row0_col5" class="data row0 col5" >O</td>
#       <td id="T_a7bf3_row0_col6" class="data row0 col6" >0</td>
#       <td id="T_a7bf3_row0_col7" class="data row0 col7" >1</td>
#       <td id="T_a7bf3_row0_col8" class="data row0 col8" >0</td>
#       <td id="T_a7bf3_row0_col9" class="data row0 col9" >0</td>
#     </tr>
#     <tr>
#       <th id="T_a7bf3_level0_row1" class="row_heading level0 row1" >818</th>
#       <td id="T_a7bf3_row1_col0" class="data row1 col0" >4gr</td>
#       <td id="T_a7bf3_row1_col1" class="data row1 col1" >1670</td>
#       <td id="T_a7bf3_row1_col2" class="data row1 col2" >1673</td>
#       <td id="T_a7bf3_row1_col3" class="data row1 col3" >O</td>
#       <td id="T_a7bf3_row1_col4" class="data row1 col4" >NUM</td>
#       <td id="T_a7bf3_row1_col5" class="data row1 col5" >4gr</td>
#       <td id="T_a7bf3_row1_col6" class="data row1 col6" >0</td>
#       <td id="T_a7bf3_row1_col7" class="data row1 col7" >1</td>
#       <td id="T_a7bf3_row1_col8" class="data row1 col8" >0</td>
#       <td id="T_a7bf3_row1_col9" class="data row1 col9" >2</td>
#     </tr>
#     <tr>
#       <th id="T_a7bf3_level0_row2" class="row_heading level0 row2" >820</th>
#       <td id="T_a7bf3_row2_col0" class="data row2 col0" >c/6hrs</td>
#       <td id="T_a7bf3_row2_col1" class="data row2 col1" >1677</td>
#       <td id="T_a7bf3_row2_col2" class="data row2 col2" >1683</td>
#       <td id="T_a7bf3_row2_col3" class="data row2 col3" >O</td>
#       <td id="T_a7bf3_row2_col4" class="data row2 col4" >PROPN</td>
#       <td id="T_a7bf3_row2_col5" class="data row2 col5" >c/6hrs</td>
#       <td id="T_a7bf3_row2_col6" class="data row2 col6" >0</td>
#       <td id="T_a7bf3_row2_col7" class="data row2 col7" >1</td>
#       <td id="T_a7bf3_row2_col8" class="data row2 col8" >0</td>
#       <td id="T_a7bf3_row2_col9" class="data row2 col9" >2</td>
#     </tr>
#     <tr>
#       <th id="T_a7bf3_level0_row3" class="row_heading level0 row3" >880</th>
#       <td id="T_a7bf3_row3_col0" class="data row3 col0" >c/8hrs</td>
#       <td id="T_a7bf3_row3_col1" class="data row3 col1" >2124</td>
#       <td id="T_a7bf3_row3_col2" class="data row3 col2" >2130</td>
#       <td id="T_a7bf3_row3_col3" class="data row3 col3" >O</td>
#       <td id="T_a7bf3_row3_col4" class="data row3 col4" >PROPN</td>
#       <td id="T_a7bf3_row3_col5" class="data row3 col5" >c/8hrs</td>
#       <td id="T_a7bf3_row3_col6" class="data row3 col6" >0</td>
#       <td id="T_a7bf3_row3_col7" class="data row3 col7" >1</td>
#       <td id="T_a7bf3_row3_col8" class="data row3 col8" >0</td>
#       <td id="T_a7bf3_row3_col9" class="data row3 col9" >2</td>
#     </tr>
#     <tr>
#       <th id="T_a7bf3_level0_row4" class="row_heading level0 row4" >1045</th>
#       <td id="T_a7bf3_row4_col0" class="data row4 col0" >x3</td>
#       <td id="T_a7bf3_row4_col1" class="data row4 col1" >3274</td>
#       <td id="T_a7bf3_row4_col2" class="data row4 col2" >3276</td>
#       <td id="T_a7bf3_row4_col3" class="data row4 col3" >O</td>
#       <td id="T_a7bf3_row4_col4" class="data row4 col4" >PROPN</td>
#       <td id="T_a7bf3_row4_col5" class="data row4 col5" >x3</td>
#       <td id="T_a7bf3_row4_col6" class="data row4 col6" >0</td>
#       <td id="T_a7bf3_row4_col7" class="data row4 col7" >1</td>
#       <td id="T_a7bf3_row4_col8" class="data row4 col8" >0</td>
#       <td id="T_a7bf3_row4_col9" class="data row4 col9" >2</td>
#     </tr>
#     <tr>
#       <th id="T_a7bf3_level0_row5" class="row_heading level0 row5" >1056</th>
#       <td id="T_a7bf3_row5_col0" class="data row5 col0" >4mg/6h</td>
#       <td id="T_a7bf3_row5_col1" class="data row5 col1" >3368</td>
#       <td id="T_a7bf3_row5_col2" class="data row5 col2" >3374</td>
#       <td id="T_a7bf3_row5_col3" class="data row5 col3" >O</td>
#       <td id="T_a7bf3_row5_col4" class="data row5 col4" >NUM</td>
#       <td id="T_a7bf3_row5_col5" class="data row5 col5" >4mg/6h</td>
#       <td id="T_a7bf3_row5_col6" class="data row5 col6" >0</td>
#       <td id="T_a7bf3_row5_col7" class="data row5 col7" >1</td>
#       <td id="T_a7bf3_row5_col8" class="data row5 col8" >0</td>
#       <td id="T_a7bf3_row5_col9" class="data row5 col9" >2</td>
#     </tr>
#     <tr>
#       <th id="T_a7bf3_level0_row6" class="row_heading level0 row6" >1071</th>
#       <td id="T_a7bf3_row6_col0" class="data row6 col0" >500mg/8h</td>
#       <td id="T_a7bf3_row6_col1" class="data row6 col1" >3484</td>
#       <td id="T_a7bf3_row6_col2" class="data row6 col2" >3492</td>
#       <td id="T_a7bf3_row6_col3" class="data row6 col3" >O</td>
#       <td id="T_a7bf3_row6_col4" class="data row6 col4" >NUM</td>
#       <td id="T_a7bf3_row6_col5" class="data row6 col5" >500mg/8h</td>
#       <

# %%
# Filter the DataFrame where "Maj NUMBER" is equal to 1
filtered_df = data[(data['Maj NUMBER'] == 1) & (data['Contains NUMBER'] == 1)] 
show_data(datos=filtered_df, first=0, second=10)
# Out:
# <style type="text/css">
# #T_dd99a_row0_col0, #T_dd99a_row0_col1, #T_dd99a_row0_col2, #T_dd99a_row0_col3, #T_dd99a_row0_col4, #T_dd99a_row0_col5, #T_dd99a_row0_col6, #T_dd99a_row0_col7, #T_dd99a_row0_col8, #T_dd99a_row0_col9, #T_dd99a_row1_col0, #T_dd99a_row1_col1, #T_dd99a_row1_col2, #T_dd99a_row1_col3, #T_dd99a_row1_col4, #T_dd99a_row1_col5, #T_dd99a_row1_col6, #T_dd99a_row1_col7, #T_dd99a_row1_col8, #T_dd99a_row1_col9, #T_dd99a_row2_col0, #T_dd99a_row2_col1, #T_dd99a_row2_col2, #T_dd99a_row2_col3, #T_dd99a_row2_col4, #T_dd99a_row2_col5, #T_dd99a_row2_col6, #T_dd99a_row2_col7, #T_dd99a_row2_col8, #T_dd99a_row2_col9, #T_dd99a_row3_col0, #T_dd99a_row3_col1, #T_dd99a_row3_col2, #T_dd99a_row3_col3, #T_dd99a_row3_col4, #T_dd99a_row3_col5, #T_dd99a_row3_col6, #T_dd99a_row3_col7, #T_dd99a_row3_col8, #T_dd99a_row3_col9, #T_dd99a_row4_col0, #T_dd99a_row4_col1, #T_dd99a_row4_col2, #T_dd99a_row4_col3, #T_dd99a_row4_col4, #T_dd99a_row4_col5, #T_dd99a_row4_col6, #T_dd99a_row4_col7, #T_dd99a_row4_col8, #T_dd99a_row4_col9, #T_dd99a_row5_col0, #T_dd99a_row5_col1, #T_dd99a_row5_col2, #T_dd99a_row5_col3, #T_dd99a_row5_col4, #T_dd99a_row5_col5, #T_dd99a_row5_col6, #T_dd99a_row5_col7, #T_dd99a_row5_col8, #T_dd99a_row5_col9, #T_dd99a_row6_col0, #T_dd99a_row6_col1, #T_dd99a_row6_col2, #T_dd99a_row6_col3, #T_dd99a_row6_col4, #T_dd99a_row6_col5, #T_dd99a_row6_col6, #T_dd99a_row6_col7, #T_dd99a_row6_col8, #T_dd99a_row6_col9, #T_dd99a_row7_col0, #T_dd99a_row7_col1, #T_dd99a_row7_col2, #T_dd99a_row7_col3, #T_dd99a_row7_col4, #T_dd99a_row7_col5, #T_dd99a_row7_col6, #T_dd99a_row7_col7, #T_dd99a_row7_col8, #T_dd99a_row7_col9, #T_dd99a_row8_col0, #T_dd99a_row8_col1, #T_dd99a_row8_col2, #T_dd99a_row8_col3, #T_dd99a_row8_col4, #T_dd99a_row8_col5, #T_dd99a_row8_col6, #T_dd99a_row8_col7, #T_dd99a_row8_col8, #T_dd99a_row8_col9, #T_dd99a_row9_col0, #T_dd99a_row9_col1, #T_dd99a_row9_col2, #T_dd99a_row9_col3, #T_dd99a_row9_col4, #T_dd99a_row9_col5, #T_dd99a_row9_col6, #T_dd99a_row9_col7, #T_dd99a_row9_col8, #T_dd99a_row9_col9 {
#   text-align: left;
# }
# </style>
# <table id="T_dd99a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dd99a_level0_col0" class="col_heading level0 col0" >Word</th>
#       <th id="T_dd99a_level0_col1" class="col_heading level0 col1" >Initial Scopes</th>
#       <th id="T_dd99a_level0_col2" class="col_heading level0 col2" >Final Scopes</th>
#       <th id="T_dd99a_level0_col3" class="col_heading level0 col3" >Tag</th>
#       <th id="T_dd99a_level0_col4" class="col_heading level0 col4" >POS</th>
#       <th id="T_dd99a_level0_col5" class="col_heading level0 col5" >LEMMA</th>
#       <th id="T_dd99a_level0_col6" class="col_heading level0 col6" >NUMBER</th>
#       <th id="T_dd99a_level0_col7" class="col_heading level0 col7" >Contains NUMBER</th>
#       <th id="T_dd99a_level0_col8" class="col_heading level0 col8" >Maj NUMBER</th>
#       <th id="T_dd99a_level0_col9" class="col_heading level0 col9" >text_id</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dd99a_level0_row0" class="row_heading level0 row0" >57</th>
#       <td id="T_dd99a_row0_col0" class="data row0 col0" >81a</td>
#       <td id="T_dd99a_row0_col1" class="data row0 col1" >780</td>
#       <td id="T_dd99a_row0_col2" class="data row0 col2" >783</td>
#       <td id="T_dd99a_row0_col3" class="data row0 col3" >O</td>
#       <td id="T_dd99a_row0_col4" class="data row0 col4" >NUM</td>
#       <td id="T_dd99a_row0_col5" class="data row0 col5" >81a</td>
#       <td id="T_dd99a_row0_col6" class="data row0 col6" >0</td>
#       <td id="T_dd99a_row0_col7" class="data row0 col7" >1</td>
#       <td id="T_dd99a_row0_col8" class="data row0 col8" >1</td>
#       <td id="T_dd99a_row0_col9" class="data row0 col9" >0</td>
#     </tr>
#     <tr>
#       <th id="T_dd99a_level0_row1" class="row_heading level0 row1" >122</th>
#       <td id="T_dd99a_row1_col0" class="data row1 col0" >(11/2017):</td>
#       <td id="T_dd99a_row1_col1" class="data row1 col1" >1206</td>
#       <td id="T_dd99a_row1_col2" class="data row1 col2" >1216</td>
#       <td id="T_dd99a_row1_col3" class="data row1 col3" >O</td>
#       <td id="T_dd99a_row1_col4" class="data row1 col4" >O</td>
#       <td id="T_dd99a_row1_col5" class="data row1 col5" >O</td>
#       <td id="T_dd99a_row1_col6" class="data row1 col6" >0</td>
#       <td id="T_dd99a_row1_col7" class="data row1 col7" >1</td>
#       <td id="T_dd99a_row1_col8" class="data row1 col8" >1</td>
#       <td id="T_dd99a_row1_col9" class="data row1 col9" >0</td>
#     </tr>
#     <tr>
#       <th id="T_dd99a_level0_row2" class="row_heading level0 row2" >154</th>
#       <td id="T_dd99a_row2_col0" class="data row2 col0" >(250</td>
#       <td id="T_dd99a_row2_col1" class="data row2 col1" >1420</td>
#       <td id="T_dd99a_row2_col2" class="data row2 col2" >1424</td>
#       <td id="T_dd99a_row2_col3" class="data row2 col3" >O</td>
#       <td id="T_dd99a_row2_col4" class="data row2 col4" >O</td>
#       <td id="T_dd99a_row2_col5" class="data row2 col5" >O</td>
#       <td id="T_dd99a_row2_col6" class="data row2 col6" >0</td>
#       <td id="T_dd99a_row2_col7" class="data row2 col7" >1</td>
#       <td id="T_dd99a_row2_col8" class="data row2 col8" >1</td>
#       <td id="T_dd99a_row2_col9" class="data row2 col9" >0</td>
#     </tr>
#     <tr>
#       <th id="T_dd99a_level0_row3" class="row_heading level0 row3" >217</th>
#       <td id="T_dd99a_row3_col0" class="data row3 col0" >(10/2017)</td>
#       <td id="T_dd99a_row3_col1" class="data row3 col1" >1892</td>
#       <td id="T_dd99a_row3_col2" class="data row3 col2" >1901</td>
#       <td id="T_dd99a_row3_col3" class="data row3 col3" >O</td>
#       <td id="T_dd99a_row3_col4" class="data row3 col4" >O</td>
#       <td id="T_dd99a_row3_col5" class="data row3 col5" >O</td>
#       <td id="T_dd99a_row3_col6" class="data row3 col6" >0</td>
#       <td id="T_dd99a_row3_col7" class="data row3 col7" >1</td>
#       <td id="T_dd99a_row3_col8" class="data row3 col8" >1</td>
#       <td id="T_dd99a_row3_col9" class="data row3 col9" >0</td>
#     </tr>
#     <tr>
#       <th id="T_dd99a_level0_row4" class="row_heading level0 row4" >243</th>
#       <td id="T_dd99a_row4_col0" class="data row4 col0" >24</td>
#       <td id="T_dd99a_row4_col1" class="data row4 col1" >2086</td>
#       <td id="T_dd99a_row4_col2" class="data row4 col2" >2088</td>
#       <td id="T_dd99a_row4_col3" class="data row4 col3" >O</td>
#       <td id="T_dd99a_row4_col4" class="data row4 col4" >NUM</td>
#       <td id="T_dd99a_row4_col5" class="data row4 col5" >24</td>
#       <td id="T_dd99a_row4_col6" class="data row4 col6" >1</td>
#       <td id="T_dd99a_row4_col7" class="data row4 col7" >1</td>
#       <td id="T_dd99a_row4_col8" class="data row4 col8" >1</td>
#       <td id="T_dd99a_row4_col9" class="data row4 col9" >0</td>
#     </tr>
#     <tr>
#       <th id="T_dd99a_level0_row5" class="row_heading level0 row5" >247</th>
#       <td id="T_dd99a_row5_col0" class="data row5 col0" >2018</td>
#       <td id="T_dd99a_row5_col1" class="data row5 col1" >2101</td>
#       <td id="T_dd99a_row5_col2" class="data row5 col2" >2105</td>
#       <td id="T_dd99a_row5_col3" class="data row5 col3" >O</td>
#       <td id="T_dd99a_row5_col4" class="data row5 col4" >NUM</td>
#       <td id="T_dd99a_row5_col5" class="data row5 col5" >2018</td>
#       <td id="T_dd99a_row5_col6" class="data row5 col6" >1</td>
#       <td id="T_dd99a_row5_col7" class="data row5 col7" >1</td>
#       <td id="T_dd99a_row5_col8" class="data row5 col8" >1</td>
#       <td id="T_dd99a_row5_col9" class="data row5 col9" >0</td>
#     </tr>
#     <tr>
#       <th id="T_dd99a_level0_row6" class="row_heading level0 row6" >335</th>
#       <td id="T_dd99a_row6_col0" class="data row6 col0" >n40.0</td>
#       <td id="T_dd99a_row6_col1" class="data row6 col1" >2741</td>
#       <td id="T_dd99a_row6_col2" class="data row6 col2" >2746</td>
#       <td id="T_dd99a_row6_col3" class="data row6 col3" >O</td>
#       <td id="T_dd99a_row6_col4" class="data row6 col4" >ADJ</td>
#       <td id="T_dd99a_row6_col5" class="data row6 col5" >n40.0</td>
#       <td id="T_dd99a_row6_col6" clas

# %%
# Filter the DataFrame where "Maj NUMBER" is equal to 1
filtered_df = data[(data['Maj NUMBER'] == 1) & (data['Contains NUMBER'] == 0)] 
show_data(datos=filtered_df, first=0, second=10)
# Out:
# <style type="text/css">
# </style>
# <table id="T_2ff16">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2ff16_level0_col0" class="col_heading level0 col0" >Word</th>
#       <th id="T_2ff16_level0_col1" class="col_heading level0 col1" >Initial Scopes</th>
#       <th id="T_2ff16_level0_col2" class="col_heading level0 col2" >Final Scopes</th>
#       <th id="T_2ff16_level0_col3" class="col_heading level0 col3" >Tag</th>
#       <th id="T_2ff16_level0_col4" class="col_heading level0 col4" >POS</th>
#       <th id="T_2ff16_level0_col5" class="col_heading level0 col5" >LEMMA</th>
#       <th id="T_2ff16_level0_col6" class="col_heading level0 col6" >NUMBER</th>
#       <th id="T_2ff16_level0_col7" class="col_heading level0 col7" >Contains NUMBER</th>
#       <th id="T_2ff16_level0_col8" class="col_heading level0 col8" >Maj NUMBER</th>
#       <th id="T_2ff16_level0_col9" class="col_heading level0 col9" >text_id</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
# Filter the DataFrame where "Maj NUMBER" is equal to 1
filtered_df = data[(data['Maj NUMBER'] == 0) & (data['Contains NUMBER'] == 0)] 
show_data(datos=filtered_df, first=0, second=10)
# Out:
# <style type="text/css">
# #T_f7aaa_row0_col0, #T_f7aaa_row0_col1, #T_f7aaa_row0_col2, #T_f7aaa_row0_col3, #T_f7aaa_row0_col4, #T_f7aaa_row0_col5, #T_f7aaa_row0_col6, #T_f7aaa_row0_col7, #T_f7aaa_row0_col8, #T_f7aaa_row0_col9, #T_f7aaa_row1_col0, #T_f7aaa_row1_col1, #T_f7aaa_row1_col2, #T_f7aaa_row1_col3, #T_f7aaa_row1_col4, #T_f7aaa_row1_col5, #T_f7aaa_row1_col6, #T_f7aaa_row1_col7, #T_f7aaa_row1_col8, #T_f7aaa_row1_col9, #T_f7aaa_row2_col0, #T_f7aaa_row2_col1, #T_f7aaa_row2_col2, #T_f7aaa_row2_col3, #T_f7aaa_row2_col4, #T_f7aaa_row2_col5, #T_f7aaa_row2_col6, #T_f7aaa_row2_col7, #T_f7aaa_row2_col8, #T_f7aaa_row2_col9, #T_f7aaa_row3_col0, #T_f7aaa_row3_col1, #T_f7aaa_row3_col2, #T_f7aaa_row3_col3, #T_f7aaa_row3_col4, #T_f7aaa_row3_col5, #T_f7aaa_row3_col6, #T_f7aaa_row3_col7, #T_f7aaa_row3_col8, #T_f7aaa_row3_col9, #T_f7aaa_row4_col0, #T_f7aaa_row4_col1, #T_f7aaa_row4_col2, #T_f7aaa_row4_col3, #T_f7aaa_row4_col4, #T_f7aaa_row4_col5, #T_f7aaa_row4_col6, #T_f7aaa_row4_col7, #T_f7aaa_row4_col8, #T_f7aaa_row4_col9, #T_f7aaa_row5_col0, #T_f7aaa_row5_col1, #T_f7aaa_row5_col2, #T_f7aaa_row5_col3, #T_f7aaa_row5_col4, #T_f7aaa_row5_col5, #T_f7aaa_row5_col6, #T_f7aaa_row5_col7, #T_f7aaa_row5_col8, #T_f7aaa_row5_col9, #T_f7aaa_row6_col0, #T_f7aaa_row6_col1, #T_f7aaa_row6_col2, #T_f7aaa_row6_col3, #T_f7aaa_row6_col4, #T_f7aaa_row6_col5, #T_f7aaa_row6_col6, #T_f7aaa_row6_col7, #T_f7aaa_row6_col8, #T_f7aaa_row6_col9, #T_f7aaa_row7_col0, #T_f7aaa_row7_col1, #T_f7aaa_row7_col2, #T_f7aaa_row7_col3, #T_f7aaa_row7_col4, #T_f7aaa_row7_col5, #T_f7aaa_row7_col6, #T_f7aaa_row7_col7, #T_f7aaa_row7_col8, #T_f7aaa_row7_col9, #T_f7aaa_row8_col0, #T_f7aaa_row8_col1, #T_f7aaa_row8_col2, #T_f7aaa_row8_col3, #T_f7aaa_row8_col4, #T_f7aaa_row8_col5, #T_f7aaa_row8_col6, #T_f7aaa_row8_col7, #T_f7aaa_row8_col8, #T_f7aaa_row8_col9, #T_f7aaa_row9_col0, #T_f7aaa_row9_col1, #T_f7aaa_row9_col2, #T_f7aaa_row9_col3, #T_f7aaa_row9_col4, #T_f7aaa_row9_col5, #T_f7aaa_row9_col6, #T_f7aaa_row9_col7, #T_f7aaa_row9_col8, #T_f7aaa_row9_col9 {
#   text-align: left;
# }
# </style>
# <table id="T_f7aaa">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f7aaa_level0_col0" class="col_heading level0 col0" >Word</th>
#       <th id="T_f7aaa_level0_col1" class="col_heading level0 col1" >Initial Scopes</th>
#       <th id="T_f7aaa_level0_col2" class="col_heading level0 col2" >Final Scopes</th>
#       <th id="T_f7aaa_level0_col3" class="col_heading level0 col3" >Tag</th>
#       <th id="T_f7aaa_level0_col4" class="col_heading level0 col4" >POS</th>
#       <th id="T_f7aaa_level0_col5" class="col_heading level0 col5" >LEMMA</th>
#       <th id="T_f7aaa_level0_col6" class="col_heading level0 col6" >NUMBER</th>
#       <th id="T_f7aaa_level0_col7" class="col_heading level0 col7" >Contains NUMBER</th>
#       <th id="T_f7aaa_level0_col8" class="col_heading level0 col8" >Maj NUMBER</th>
#       <th id="T_f7aaa_level0_col9" class="col_heading level0 col9" >text_id</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f7aaa_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f7aaa_row0_col0" class="data row0 col0" >paciente</td>
#       <td id="T_f7aaa_row0_col1" class="data row0 col1" >315</td>
#       <td id="T_f7aaa_row0_col2" class="data row0 col2" >323</td>
#       <td id="T_f7aaa_row0_col3" class="data row0 col3" >O</td>
#       <td id="T_f7aaa_row0_col4" class="data row0 col4" >NOUN</td>
#       <td id="T_f7aaa_row0_col5" class="data row0 col5" >paciente</td>
#       <td id="T_f7aaa_row0_col6" class="data row0 col6" >0</td>
#       <td id="T_f7aaa_row0_col7" class="data row0 col7" >0</td>
#       <td id="T_f7aaa_row0_col8" class="data row0 col8" >0</td>
#       <td id="T_f7aaa_row0_col9" class="data row0 col9" >0</td>
#     </tr>
#     <tr>
#       <th id="T_f7aaa_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f7aaa_row1_col0" class="data row1 col0" >que</td>
#       <td id="T_f7aaa_row1_col1" class="data row1 col1" >324</td>
#       <td id="T_f7aaa_row1_col2" class="data row1 col2" >327</td>
#       <td id="T_f7aaa_row1_col3" class="data row1 col3" >O</td>
#       <td id="T_f7aaa_row1_col4" class="data row1 col4" >SCONJ</td>
#       <td id="T_f7aaa_row1_col5" class="data row1 col5" >que</td>
#       <td id="T_f7aaa_row1_col6" class="data row1 col6" >0</td>
#       <td id="T_f7aaa_row1_col7" class="data row1 col7" >0</td>
#       <td id="T_f7aaa_row1_col8" class="data row1 col8" >0</td>
#       <td id="T_f7aaa_row1_col9" class="data row1 col9" >0</td>
#     </tr>
#     <tr>
#       <th id="T_f7aaa_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f7aaa_row2_col0" class="data row2 col0" >ingresa</td>
#       <td id="T_f7aaa_row2_col1" class="data row2 col1" >328</td>
#       <td id="T_f7aaa_row2_col2" class="data row2 col2" >335</td>
#       <td id="T_f7aaa_row2_col3" class="data row2 col3" >O</td>
#       <td id="T_f7aaa_row2_col4" class="data row2 col4" >VERB</td>
#       <td id="T_f7aaa_row2_col5" class="data row2 col5" >ingresar</td>
#       <td id="T_f7aaa_row2_col6" class="data row2 col6" >0</td>
#       <td id="T_f7aaa_row2_col7" class="data row2 col7" >0</td>
#       <td id="T_f7aaa_row2_col8" class="data row2 col8" >0</td>
#       <td id="T_f7aaa_row2_col9" class="data row2 col9" >0</td>
#     </tr>
#     <tr>
#       <th id="T_f7aaa_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f7aaa_row3_col0" class="data row3 col0" >de</td>
#       <td id="T_f7aaa_row3_col1" class="data row3 col1" >336</td>
#       <td id="T_f7aaa_row3_col2" class="data row3 col2" >338</td>
#       <td id="T_f7aaa_row3_col3" class="data row3 col3" >O</td>
#       <td id="T_f7aaa_row3_col4" class="data row3 col4" >ADP</td>
#       <td id="T_f7aaa_row3_col5" class="data row3 col5" >de</td>
#       <td id="T_f7aaa_row3_col6" class="data row3 col6" >0</td>
#       <td id="T_f7aaa_row3_col7" class="data row3 col7" >0</td>
#       <td id="T_f7aaa_row3_col8" class="data row3 col8" >0</td>
#       <td id="T_f7aaa_row3_col9" class="data row3 col9" >0</td>
#     </tr>
#     <tr>
#       <th id="T_f7aaa_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f7aaa_row4_col0" class="data row4 col0" >forma</td>
#       <td id="T_f7aaa_row4_col1" class="data row4 col1" >339</td>
#       <td id="T_f7aaa_row4_col2" class="data row4 col2" >344</td>
#       <td id="T_f7aaa_row4_col3" class="data row4 col3" >O</td>
#       <td id="T_f7aaa_row4_col4" class="data row4 col4" >NOUN</td>
#       <td id="T_f7aaa_row4_col5" class="data row4 col5" >forma</td>
#       <td id="T_f7aaa_row4_col6" class="data row4 col6" >0</td>
#       <td id="T_f7aaa_row4_col7" class="data row4 col7" >0</td>
#       <td id="T_f7aaa_row4_col8" class="data row4 col8" >0</td>
#       <td id="T_f7aaa_row4_col9" class="data row4 col9" >0</td>
#     </tr>
#     <tr>
#       <th id="T_f7aaa_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f7aaa_row5_col0" class="data row5 col0" >programada</td>
#       <td id="T_f7aaa_row5_col1" class="data row5 col1" >345</td>
#       <td id="T_f7aaa_row5_col2" class="data row5 col2" >355</td>
#       <td id="T_f7aaa_row5_col3" class="data row5 col3" >O</td>
#       <td id="T_f7aaa_row5_col4" class="data row5 col4" >ADJ</td>
#       <td id="T_f7aaa_row5_col5" class="data row5 col5" >programado</td>
#       <td id="T_f7aaa_row5_col6" class="data row5 col6" >0</td>
#       <td id="T_f7aaa_row5_col7" class="data row5 col7" >0</td>
#       <td id="T_f7aaa_row5_col8" class="data row5 col8" >0</td>
#       <td id="T_f7aaa_row5_col9" class="data row5 col9" >0</td>
#     </tr>
#     <tr>
#       <th id="T_f7aaa_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f7aaa_row6_col0" class="data row6 col0" >para</td>
#       <td id="T_f7aaa_row6_col1" class="data row6 col1" >356</td>
#       <td id="T_f7aaa_row6_col2" class="data row6 col2" >360</td>
#       <td id="T_f7aaa_row6_col3" class="data row6 col3" >O</td>
#       <td id="T_f7aaa_row6_col4" class="data row6 col4" >ADP</td>
#       <td id="T_f7aaa_row6_col5" class="data row6 col5" >para</td>
#       <td id="T_f7aaa_row6

# %%
# Filter the DataFrame where "Maj NUMBER" is equal to 1
filtered_df = data[data['NUMBER'] == 1] 
show_data(datos=filtered_df, first=0, second=10)
# Out:
# <style type="text/css">
# #T_be9ab_row0_col0, #T_be9ab_row0_col1, #T_be9ab_row0_col2, #T_be9ab_row0_col3, #T_be9ab_row0_col4, #T_be9ab_row0_col5, #T_be9ab_row0_col6, #T_be9ab_row0_col7, #T_be9ab_row0_col8, #T_be9ab_row0_col9, #T_be9ab_row1_col0, #T_be9ab_row1_col1, #T_be9ab_row1_col2, #T_be9ab_row1_col3, #T_be9ab_row1_col4, #T_be9ab_row1_col5, #T_be9ab_row1_col6, #T_be9ab_row1_col7, #T_be9ab_row1_col8, #T_be9ab_row1_col9, #T_be9ab_row2_col0, #T_be9ab_row2_col1, #T_be9ab_row2_col2, #T_be9ab_row2_col3, #T_be9ab_row2_col4, #T_be9ab_row2_col5, #T_be9ab_row2_col6, #T_be9ab_row2_col7, #T_be9ab_row2_col8, #T_be9ab_row2_col9, #T_be9ab_row3_col0, #T_be9ab_row3_col1, #T_be9ab_row3_col2, #T_be9ab_row3_col3, #T_be9ab_row3_col4, #T_be9ab_row3_col5, #T_be9ab_row3_col6, #T_be9ab_row3_col7, #T_be9ab_row3_col8, #T_be9ab_row3_col9, #T_be9ab_row4_col0, #T_be9ab_row4_col1, #T_be9ab_row4_col2, #T_be9ab_row4_col3, #T_be9ab_row4_col4, #T_be9ab_row4_col5, #T_be9ab_row4_col6, #T_be9ab_row4_col7, #T_be9ab_row4_col8, #T_be9ab_row4_col9, #T_be9ab_row5_col0, #T_be9ab_row5_col1, #T_be9ab_row5_col2, #T_be9ab_row5_col3, #T_be9ab_row5_col4, #T_be9ab_row5_col5, #T_be9ab_row5_col6, #T_be9ab_row5_col7, #T_be9ab_row5_col8, #T_be9ab_row5_col9, #T_be9ab_row6_col0, #T_be9ab_row6_col1, #T_be9ab_row6_col2, #T_be9ab_row6_col3, #T_be9ab_row6_col4, #T_be9ab_row6_col5, #T_be9ab_row6_col6, #T_be9ab_row6_col7, #T_be9ab_row6_col8, #T_be9ab_row6_col9, #T_be9ab_row7_col0, #T_be9ab_row7_col1, #T_be9ab_row7_col2, #T_be9ab_row7_col3, #T_be9ab_row7_col4, #T_be9ab_row7_col5, #T_be9ab_row7_col6, #T_be9ab_row7_col7, #T_be9ab_row7_col8, #T_be9ab_row7_col9, #T_be9ab_row8_col0, #T_be9ab_row8_col1, #T_be9ab_row8_col2, #T_be9ab_row8_col3, #T_be9ab_row8_col4, #T_be9ab_row8_col5, #T_be9ab_row8_col6, #T_be9ab_row8_col7, #T_be9ab_row8_col8, #T_be9ab_row8_col9, #T_be9ab_row9_col0, #T_be9ab_row9_col1, #T_be9ab_row9_col2, #T_be9ab_row9_col3, #T_be9ab_row9_col4, #T_be9ab_row9_col5, #T_be9ab_row9_col6, #T_be9ab_row9_col7, #T_be9ab_row9_col8, #T_be9ab_row9_col9 {
#   text-align: left;
# }
# </style>
# <table id="T_be9ab">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_be9ab_level0_col0" class="col_heading level0 col0" >Word</th>
#       <th id="T_be9ab_level0_col1" class="col_heading level0 col1" >Initial Scopes</th>
#       <th id="T_be9ab_level0_col2" class="col_heading level0 col2" >Final Scopes</th>
#       <th id="T_be9ab_level0_col3" class="col_heading level0 col3" >Tag</th>
#       <th id="T_be9ab_level0_col4" class="col_heading level0 col4" >POS</th>
#       <th id="T_be9ab_level0_col5" class="col_heading level0 col5" >LEMMA</th>
#       <th id="T_be9ab_level0_col6" class="col_heading level0 col6" >NUMBER</th>
#       <th id="T_be9ab_level0_col7" class="col_heading level0 col7" >Contains NUMBER</th>
#       <th id="T_be9ab_level0_col8" class="col_heading level0 col8" >Maj NUMBER</th>
#       <th id="T_be9ab_level0_col9" class="col_heading level0 col9" >text_id</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_be9ab_level0_row0" class="row_heading level0 row0" >243</th>
#       <td id="T_be9ab_row0_col0" class="data row0 col0" >24</td>
#       <td id="T_be9ab_row0_col1" class="data row0 col1" >2086</td>
#       <td id="T_be9ab_row0_col2" class="data row0 col2" >2088</td>
#       <td id="T_be9ab_row0_col3" class="data row0 col3" >O</td>
#       <td id="T_be9ab_row0_col4" class="data row0 col4" >NUM</td>
#       <td id="T_be9ab_row0_col5" class="data row0 col5" >24</td>
#       <td id="T_be9ab_row0_col6" class="data row0 col6" >1</td>
#       <td id="T_be9ab_row0_col7" class="data row0 col7" >1</td>
#       <td id="T_be9ab_row0_col8" class="data row0 col8" >1</td>
#       <td id="T_be9ab_row0_col9" class="data row0 col9" >0</td>
#     </tr>
#     <tr>
#       <th id="T_be9ab_level0_row1" class="row_heading level0 row1" >247</th>
#       <td id="T_be9ab_row1_col0" class="data row1 col0" >2018</td>
#       <td id="T_be9ab_row1_col1" class="data row1 col1" >2101</td>
#       <td id="T_be9ab_row1_col2" class="data row1 col2" >2105</td>
#       <td id="T_be9ab_row1_col3" class="data row1 col3" >O</td>
#       <td id="T_be9ab_row1_col4" class="data row1 col4" >NUM</td>
#       <td id="T_be9ab_row1_col5" class="data row1 col5" >2018</td>
#       <td id="T_be9ab_row1_col6" class="data row1 col6" >1</td>
#       <td id="T_be9ab_row1_col7" class="data row1 col7" >1</td>
#       <td id="T_be9ab_row1_col8" class="data row1 col8" >1</td>
#       <td id="T_be9ab_row1_col9" class="data row1 col9" >0</td>
#     </tr>
#     <tr>
#       <th id="T_be9ab_level0_row2" class="row_heading level0 row2" >433</th>
#       <td id="T_be9ab_row2_col0" class="data row2 col0" >14</td>
#       <td id="T_be9ab_row2_col1" class="data row2 col1" >3411</td>
#       <td id="T_be9ab_row2_col2" class="data row2 col2" >3413</td>
#       <td id="T_be9ab_row2_col3" class="data row2 col3" >O</td>
#       <td id="T_be9ab_row2_col4" class="data row2 col4" >NUM</td>
#       <td id="T_be9ab_row2_col5" class="data row2 col5" >14</td>
#       <td id="T_be9ab_row2_col6" class="data row2 col6" >1</td>
#       <td id="T_be9ab_row2_col7" class="data row2 col7" >1</td>
#       <td id="T_be9ab_row2_col8" class="data row2 col8" >1</td>
#       <td id="T_be9ab_row2_col9" class="data row2 col9" >0</td>
#     </tr>
#     <tr>
#       <th id="T_be9ab_level0_row3" class="row_heading level0 row3" >445</th>
#       <td id="T_be9ab_row3_col0" class="data row3 col0" >1</td>
#       <td id="T_be9ab_row3_col1" class="data row3 col1" >3498</td>
#       <td id="T_be9ab_row3_col2" class="data row3 col2" >3499</td>
#       <td id="T_be9ab_row3_col3" class="data row3 col3" >O</td>
#       <td id="T_be9ab_row3_col4" class="data row3 col4" >NUM</td>
#       <td id="T_be9ab_row3_col5" class="data row3 col5" >1</td>
#       <td id="T_be9ab_row3_col6" class="data row3 col6" >1</td>
#       <td id="T_be9ab_row3_col7" class="data row3 col7" >1</td>
#       <td id="T_be9ab_row3_col8" class="data row3 col8" >1</td>
#       <td id="T_be9ab_row3_col9" class="data row3 col9" >0</td>
#     </tr>
#     <tr>
#       <th id="T_be9ab_level0_row4" class="row_heading level0 row4" >448</th>
#       <td id="T_be9ab_row4_col0" class="data row4 col0" >8</td>
#       <td id="T_be9ab_row4_col1" class="data row4 col1" >3507</td>
#       <td id="T_be9ab_row4_col2" class="data row4 col2" >3508</td>
#       <td id="T_be9ab_row4_col3" class="data row4 col3" >O</td>
#       <td id="T_be9ab_row4_col4" class="data row4 col4" >NUM</td>
#       <td id="T_be9ab_row4_col5" class="data row4 col5" >8</td>
#       <td id="T_be9ab_row4_col6" class="data row4 col6" >1</td>
#       <td id="T_be9ab_row4_col7" class="data row4 col7" >1</td>
#       <td id="T_be9ab_row4_col8" class="data row4 col8" >1</td>
#       <td id="T_be9ab_row4_col9" class="data row4 col9" >0</td>
#     </tr>
#     <tr>
#       <th id="T_be9ab_level0_row5" class="row_heading level0 row5" >540</th>
#       <td id="T_be9ab_row5_col0" class="data row5 col0" >2820</td>
#       <td id="T_be9ab_row5_col1" class="data row5 col1" >626</td>
#       <td id="T_be9ab_row5_col2" class="data row5 col2" >630</td>
#       <td id="T_be9ab_row5_col3" class="data row5 col3" >O</td>
#       <td id="T_be9ab_row5_col4" class="data row5 col4" >NUM</td>
#       <td id="T_be9ab_row5_col5" class="data row5 col5" >2820</td>
#       <td id="T_be9ab_row5_col6" class="data row5 col6" >1</td>
#       <td id="T_be9ab_row5_col7" class="data row5 col7" >1</td>
#       <td id="T_be9ab_row5_col8" class="data row5 col8" >1</td>
#       <td id="T_be9ab_row5_col9" class="data row5 col9" >1</td>
#     </tr>
#     <tr>
#       <th id="T_be9ab_level0_row6" class="row_heading level0 row6" >604</th>
#       <td id="T_be9ab_row6_col0" class="data row6 col0" >1</td>
#       <td id="T_be9ab_row6_col1" class="data row6 col1" >1163</td>
#       <td id="T_be9ab_row6_col2" class="data row6 col2" >1164</td>
#       <td id="T_be9ab_row6_col3" class="data row6 col3" >O</td>
#       <td id="T_be9ab_row6_col4" class="data row6 col4" >NUM</td>
#       <td id="T_be9ab_row6_col5" class="data row6 col5" >1</td>
#       <td id="T_be9ab_row6_col6" class="data row6 col6

# %% [markdown]
# ## **MODEL**

# %%
data.head(10)
# Out:
#           Word  Initial Scopes  Final Scopes Tag    POS        LEMMA  NUMBER  \
# 0     paciente             315           323   O   NOUN     paciente       0
# 1          que             324           327   O  SCONJ          que       0
# 2      ingresa             328           335   O   VERB     ingresar       0
# 3           de             336           338   O    ADP           de       0
# 4        forma             339           344   O   NOUN        forma       0
# 5   programada             345           355   O    ADJ   programado       0
# 6         para             356           360   O    ADP         para       0
# 7  realizacion             361           372   O  PROPN  realizacion       0
# 8           de             373           375   O    ADP           de       0
# 9  uretrotomia             376           387   O   NOUN  uretrotomia       0
#
#    Contains NUMBER  Maj NUMBER  text_id
# 0                0           0        0
# 1                0           0        0
# 2                0           0        0
# 3                0           0        0
# 4                0           0        0
# 5                0           0        0
# 6                0           0        0
# 7                0           0        0
# 8                0           0        0
# 9                0           0        0

# %%
from sklearn.preprocessing import LabelEncoder
pos = data['POS']
tag = data['Tag']

# Encoding categorical data to integers
word_encoder = LabelEncoder()
tag_encoder = LabelEncoder()

data['POS_encoded'] = word_encoder.fit_transform(pos)
data['Tag_encoded'] = tag_encoder.fit_transform(tag)

data['POS'] = data['POS_encoded']
data['Tag'] = data['Tag_encoded']

# %%
data.head()
# Out:
#        Word  Initial Scopes  Final Scopes  Tag  POS     LEMMA  NUMBER  \
# 0  paciente             315           323    2    7  paciente       0
# 1       que             324           327    2   14       que       0
# 2   ingresa             328           335    2   16  ingresar       0
# 3        de             336           338    2    1        de       0
# 4     forma             339           344    2    7     forma       0
#
#    Contains NUMBER  Maj NUMBER  text_id  POS_encoded  Tag_encoded
# 0                0           0        0            7            2
# 1                0           0        0           14            2
# 2                0           0        0           16            2
# 3                0           0        0            1            2
# 4                0           0        0            7            2

# %%
from gensim.models import Word2Vec

words = list(data['Word'])
lema = list(data['LEMMA'])

# Train Word2Vec on words
# Optionally, train FastText for handling out-of-vocabulary words
Word2Vec_word = Word2Vec(words, vector_size=300, window=5, min_count=1, workers=4)
Word2Vec_word.save("fasttext_words.model")

Word2Vec_lemma = Word2Vec(lema, vector_size=300, window=5, min_count=1, workers=4)
Word2Vec_lemma.save("fasttext_words.model")

# %%
data['Word_encoded'] = Word2Vec_word
data['Lemma_encoded'] = Word2Vec_lemma

# %%
data.head()
# Out:
#        Word  Initial Scopes  Final Scopes  Tag  POS     LEMMA  NUMBER  \
# 0  paciente             315           323    2    7  paciente       0
# 1       que             324           327    2   14       que       0
# 2   ingresa             328           335    2   16  ingresar       0
# 3        de             336           338    2    1        de       0
# 4     forma             339           344    2    7     forma       0
#
#    Contains NUMBER  Maj NUMBER  text_id  POS_encoded  Tag_encoded  \
# 0                0           0        0            7            2
# 1                0           0        0           14            2
# 2                0           0        0           16            2
# 3                0           0        0            1            2
# 4                0           0        0            7            2
#
#                                        Word_encoded  \
# 0  Word2Vec<vocab=74, vector_size=300, alpha=0.025>
# 1  Word2Vec<vocab=74, vector_size=300, alpha=0.025>
# 2  Word2Vec<vocab=74, vector_size=300, alpha=0.025>
# 3  Word2Vec<vocab=74, vector_size=300, alpha=0.025>
# 4  Word2Vec<vocab=74, vector_size=300, alpha=0.025>
#
#                                       Lemma_encoded
# 0  Word2Vec<vocab=72, vector_size=300, alpha=0.025>
# 1  Word2Vec<vocab=72, vector_size=300, alpha=0.025>
# 2  Word2Vec<vocab=72, vector_size=300, alpha=0.025>
# 3  Word2Vec<vocab=72, vector_size=300, alpha=0.025>
# 4  Word2Vec<vocab=72, vector_size=300, alpha=0.025>

# %%
data.drop(columns=['POS', 'Tag','Initial Scopes','Final Scopes','NUMBER','Contains NUMBER','Maj NUMBER', 'Word','LEMMA'], inplace = True)

# %%
data.head()
# Out:
#    text_id  POS_encoded  Tag_encoded  \
# 0        0            7            2
# 1        0           14            2
# 2        0           16            2
# 3        0            1            2
# 4        0            7            2
#
#                                        Word_encoded  \
# 0  Word2Vec<vocab=74, vector_size=300, alpha=0.025>
# 1  Word2Vec<vocab=74, vector_size=300, alpha=0.025>
# 2  Word2Vec<vocab=74, vector_size=300, alpha=0.025>
# 3  Word2Vec<vocab=74, vector_size=300, alpha=0.025>
# 4  Word2Vec<vocab=74, vector_size=300, alpha=0.025>
#
#                                       Lemma_encoded
# 0  Word2Vec<vocab=72, vector_size=300, alpha=0.025>
# 1  Word2Vec<vocab=72, vector_size=300, alpha=0.025>
# 2  Word2Vec<vocab=72, vector_size=300, alpha=0.025>
# 3  Word2Vec<vocab=72, vector_size=300, alpha=0.025>
# 4  Word2Vec<vocab=72, vector_size=300, alpha=0.025>

# %%
print(len(data))
# Out:
# 168887

# %%
unique_pos_tags = data['POS_encoded'].unique()
print(unique_pos_tags)
# Out:
# [ 7 14 16  1  0 12 13  4  2  9 11  8  3  5 15  6 10 17]

# %%
import torch
import torch.nn as nn
import torch.optim as optim

class NLPModel(nn.Module):
    def __init__(self, num_embeddings, embedding_dim, num_pos_tags, pos_embedding_dim, num_embeddings_lemma, lemma_embedding_dim, hidden_dim, lstm_out_dim, output_dim):
        super(NLPModel, self).__init__()
        
        # Embedding layers
        self.word_embeddings = nn.Embedding(num_embeddings, embedding_dim)  # Pre-trained, frozen
        self.pos_embeddings = nn.Embedding(num_pos_tags, pos_embedding_dim)
        self.case_embeddings = nn.Embedding(num_embeddings_lemma, lemma_embedding_dim)
        
        # Concatenation dimension
        concat_dim = embedding_dim + pos_embedding_dim + lemma_embedding_dim
        
        # Dense layer prior to LSTM
        self.dense = nn.Linear(concat_dim, hidden_dim)
        
        # LSTM layer
        self.lstm = nn.LSTM(hidden_dim, lstm_out_dim, batch_first=True, bidirectional=True)
        
        # Output layer
        self.output_layer = nn.Linear(2 * lstm_out_dim, output_dim)  # Correct input dimension

        # Dropout layer
        self.dropout = nn.Dropout(0.25)

    def forward(self, x, pos, lemma):
        # Embed each input type
        x = self.word_embeddings(x)
        pos = self.pos_embeddings(pos)
        lemma = self.case_embeddings(lemma)  # Corrected from 'case' to 'lemma'
        
        # Concatenate embeddings
        x = torch.cat((x, pos, lemma), dim=-1)
        
        # Apply dense and activation
        x = torch.tanh(self.dense(x))
        
        # Apply dropout
        x = self.dropout(x)
        
        # LSTM layer
        lstm_out, _ = self.lstm(x)
        
        # Output layer
        output = self.output_layer(lstm_out)
        
        return output


# Hyperparameters and model instantiation

# %%
def train_model(dataloader, model, batch_size, criterion, optimizer, num_epochs):
    model.train()

    losses = []
    for epoch in range(num_epochs):

        for batch, (x, y) in enumerate(dataloader):
            h_state, c_state = model.init_hidden(batch_size)

            optimizer.zero_grad()

            y_pred, h_state, c_state = model(x, h_state, c_state)

            input_lengths = torch.full(size=(batch_size,), fill_value=64, dtype=torch.long)
            ##input_lengths = torch.sum((y_pred != 0), dim=1)
            ##input_lengths = torch.full(size=(batch_size,), fill_value=64, dtype=torch.long)

            target_lengths = torch.full(size=(batch_size,), fill_value=24, dtype=torch.long)
            ##target_lengths = torch.randint(high=max_str_len, size=(batch_size,), dtype=torch.long)
            ##target_lengths = torch.randint(low=1, high=max_str_len, size=(batch_size,), dtype=torch.long)
            ##target_lengths = torch.sum((y != 0), dim=1)

            y_pred = y_pred.transpose(1,0)
            loss = criterion(y_pred, y, input_lengths, target_lengths) #.transpose(1, 2)

            loss.backward()

            # Gradient clipping
            #nn.utils.clip_grad_norm_(model.parameters(), 1)
            #gradient_clipping(model, 0.0001, 1)

            for name, param in model.named_parameters():
              if param.grad is not None:
                print(name, torch.mean(param.grad).item(), loss.item())

            optimizer.step()

            if batch%30 == 0:
                print({ 'epoch': epoch, 'batch': batch, 'loss': loss.item() })
                losses.append(loss.item())
    return losses

# %%
num_embeddings = len(data)  # Vocabulary size of word embeddings
embedding_dim = 300    # Dimension of pre-trained word embeddings

num_pos_tags = len(data)      # Number of unique POS tags
pos_embedding_dim = 50 # Dimension of POS embeddings

num_embeddings_lemma = len(data)
lemma_embedding_dim = 300

#num_case_tags = 4      # Number of casing categories
#case_embedding_dim = 8 # Dimension of case embeddings
hidden_dim = 200       # Dense layer size
lstm_out_dim = 300     # LSTM output dimension
output_dim = 4  # Output dimension based on the task (e.g., number of classes)

model = NLPModel(num_embeddings, embedding_dim, num_pos_tags, pos_embedding_dim,
                 num_embeddings_lemma, lemma_embedding_dim, hidden_dim, lstm_out_dim, output_dim)

# Optimizer
optimizer = optim.Adagrad(model.parameters(), lr=0.01)

# %%
batch_size = 128
num_epochs = 10
losses = {"train": [], "val": []}
for epoch in range(10):
    train_loss = train_model(train_loader, model, batch_size, criterion, optimizer, num_epochs)
    val_loss = validate(criterion, model, valid_loader)

    losses["train"].append(train_loss)
    losses["val"].append(val_loss)

    plt.plot(losses["train"], label="training loss")
    plt.plot(losses["val"], label="validation loss")

    plt.legend()
    plt.pause(0.000001)
    plt.show()

## Gradients are vanishing
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[267], line 5
#       3 losses = {"train": [], "val": []}
#       4 for epoch in range(10):
# ----> 5     train_loss = train_model(train_loader, model, batch_size, criterion, optimizer, num_epochs)
#       6     val_loss = validate(criterion, model, valid_loader)
#       8     losses["train"].append(train_loss)
#
# NameError: name 'train_loader' is not defined

# %% [markdown]
# ## **MODEL EVALUATION**
