# %% [markdown]
# # **Deep Learning Method**
# ### Group 1 - Detection of Negation and Uncertainty
#
# - Marino Oliveros Blanco NIU:1668563
# - Pere Mayol Carbonell NIU:1669503
# - Andreu Gascón Marzo NIU:1670919
# - Judith Zaragoza NIU:1634071

# %% [markdown]
# ## **Library and Data Loading**

# %%
# Libraries
import json
# !pip install langdetect
# !pip install spacy
import spacy
# !python -m spacy download es_core_news_md
from langdetect import detect # Library for language detection
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from matplotlib import pyplot as plt
# Out:
# Collecting langdetect
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 10.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from langdetect) (1.16.0)
# Building wheels for collected packages: langdetect
#   Building wheel for langdetect (setup.py) ... done
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993227 sha256=ae04c1b361be7d0b12f5ddad36eb4972fd5e57bef14c9de207145b53dc42977f
#   Stored in directory: /root/.cache/pip/wheels/95/03/7d/59ea870c70ce4e5a370638b5462a7711ab78fba2f655d05106
# Successfully built langdetect
# Installing collected packages: langdetect
# Successfully installed langdetect-1.0.9
# Requirement already satisfied: spacy in /usr/local/lib/python3.10/dist-packages (3.7.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.9.4)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (4.66.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.7.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.1.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (24.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.4.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.25.2)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.10/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.2.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.2 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.18.2)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2024.2.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.3.0->spacy) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.4.0,>=0.1.0->spacy) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy) (2.1.5)
# Requirement already satisfied: marisa-trie>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.1.1)
# Collecting es-core-news-md==3.7.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/es_core_news_md-3.7.0/es_core_news_md-3.7.0-py3-none-any.whl (42.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.3/42.3 MB 16.2 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.0 in /usr/local/lib/python3.10/dist-packages (from es-core-news-md==3.7.0) (3.7.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (0.9.4)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (4.66.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (2.7.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (3.1.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (24.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (3.4.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (1.25.2)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.10/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (1.2.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.2 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (2.18.2)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (2024.2.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (2.1.5)
# Requirement already satisfied: marisa-trie>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (1.1.1)
# Installing collected packages: es-core-news-md
# Successfully installed es-core-news-md-3.7.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('es_core_news_md')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
# Loading the training json file
loading_train = open("negacio_train_v2024.json",)
training_data = json.load(loading_train)
print("The training set contains: ", len(training_data), " samples")
# Out:
# The training set contains:  254  samples

# %%
# Loading the json object
loading_test = open("negacio_test_v2024.json")
test_data = json.load(loading_test)
print("The test set contains: ", len(test_data), " samples")
# Out:
# The test set contains:  64  samples

# %% [markdown]
# ## **Data Annotation**
# - Set using ground truth word to either O, NEG, UNC, NSCO, USCO

# %%
def strip_tokens(tagged_text):
    def find_indices(tokens, start_token, end_token, occurrence=1):
        start_index = None
        end_index = None
        end_token_count = 0
        for i, (word, _, _) in enumerate(tokens):
            if word == start_token and start_index is None:
                start_index = i
            if word == end_token:
                end_token_count += 1
                if end_token_count == occurrence:
                    end_index = i
                    break
        return start_index, end_index

    # Remove sections from "nº" to the second occurrence of "d'ingres"
    start1, end1 = find_indices(tagged_text, 'nº', "d'ingres", occurrence=2)
    if end1 is not None:
        end1 += 1  # Include the end token

    # If the indices are found, remove the section
    new_tagged_text = []
    if start1 is not None and end1 is not None:
        new_tagged_text = tagged_text[:start1] + tagged_text[end1:]
    else:
        new_tagged_text = tagged_text[:]

    # Continuously find and remove all sections from "nhc" to "lopd"
    while True:
        start2, end2 = find_indices(new_tagged_text, 'nhc', 'lopd')
        if start2 is not None and end2 is not None:
            end2 += 1  # Include the end token
            new_tagged_text = new_tagged_text[:start2] + new_tagged_text[end2:]
        else:
            break

    return new_tagged_text

def tag_words_from_json(json_data):
    # Initialize lists for all tagged texts and counts
    all_tagged_texts = []
    all_counts = []

    # Iterate through each entry in the JSON data
    for entry in json_data:
        # Extract text and predictions from JSON entry
        text = entry['data']['text']
        predictions = entry['predictions'][0]['result']

        # Initialize counters
        counts = {'NEG': 0, 'NSCO': 0, 'UNC': 0, 'USCO': 0}

        # Initialize tokens and their coordinates
        tokens = []
        start_pos = 0

        # Split text into tokens while tracking their start and end positions
        for word in text.split():
            start = text.find(word, start_pos)
            end = start + len(word)
            tokens.append((word, start, end))
            start_pos = end

        # Initialize tags list
        tags = ['O'] * len(tokens)

        # Tag each word
        for pred in predictions:
            pred_start = pred['value']['start']
            pred_end = pred['value']['end']
            label = pred['value']['labels'][0]

            if label in counts:
                counts[label] += 1
                for i, (word, start, end) in enumerate(tokens):
                    if start < pred_end and end > pred_start:
                        tags[i] = label

        # Combine tokens with tags
        tagged_text = [(token[0], (token[1], token[2]), tags[i]) for i, token in enumerate(tokens)]

        # Strip unwanted tokens
        stripped_tagged_text = strip_tokens(tagged_text)

        # Append the results to the lists
        all_tagged_texts.append(stripped_tagged_text)
        all_counts.append(counts)

    # Return the list of tagged words and counts for all entries
    return all_tagged_texts, all_counts

# %%
# Example usage with all entries
labels, counts_list = tag_words_from_json(training_data)

# %%
labels, counts_list = tag_words_from_json(test_data)

# %%
print("Number of entries in the entry:", len(labels))
print(labels[0]) # Print out an example entry
print(labels[0][0]) # Print out an example word
print(labels[0][0][2]) # Tag
len(labels[0])
# Out:
# Number of entries in the entry: 64
# [('induccion', (319, 328), 'O'), ('al', (329, 331), 'O'), ('parto', (332, 337), 'O'), ('por', (338, 341), 'O'), ('pequeño', (342, 349), 'O'), ('para', (350, 354), 'O'), ('la', (355, 357), 'O'), ('edad', (358, 362), 'O'), ('gestacional', (363, 374), 'O'), ('(', (375, 376), 'O'), ('peg', (377, 380), 'O'), (')', (381, 382), 'O'), ('antecedents', (383, 394), 'O'), ('no', (395, 397), 'NEG'), ('alergias', (398, 406), 'NSCO'), ('medicamentosas', (407, 421), 'NSCO'), ('conocidas', (422, 431), 'O'), ('antcededentes', (432, 445), 'O'), ('medico-quirurgicos:', (446, 465), 'O'), ('protesis', (466, 474), 'O'), ('mamaria,', (475, 483), 'O'), ('adenoidectomia', (484, 498), 'O'), ('niega', (499, 504), 'NEG'), ('habitos', (505, 512), 'NSCO'), ('toxicos', (513, 520), 'NSCO'), ('medicacio', (521, 530), 'O'), ('habitual', (531, 539), 'O'), ('anafranil25', (540, 551), 'O'), ('mg/', (552, 555), 'O'), ('diario.', (556, 563), 'O'), ('yodocefol.', (564, 574), 'O'), ('hierro', (575, 581), 'O'), ('oral.', (582, 587), 'O'), ('ranitidina', (588, 598), 'O'), ('150', (599, 602), 'O'), ('mg.', (603, 606), 'O'), ('proces', (607, 613), 'O'), ('actual', (614, 620), 'O'), ('edad:', (621, 626), 'O'), ('42', (627, 629), 'O'), ('años', (630, 634), 'O'), ('tpal:', (635, 640), 'O'), ('1001', (641, 645), 'O'), ('(eutocico)', (646, 656), 'O'), ('fur:', (657, 661), 'O'), ('21.12.2019', (662, 672), 'O'), ('sg:', (673, 676), 'O'), ('40+0', (677, 681), 'O'), ('gsrh:a+', (682, 689), 'O'), ('gestacion', (690, 699), 'O'), ('controlada', (700, 710), 'O'), ('en', (711, 713), 'O'), ('alto', (714, 718), 'O'), ('riesgo', (719, 725), 'O'), ('obstetrico', (726, 736), 'O'), ('(aro)', (737, 742), 'O'), ('por', (743, 746), 'O'), ('antecedente', (747, 758), 'O'), ('de', (759, 761), 'O'), ('depresion', (762, 771), 'O'), ('postparto', (772, 781), 'O'), ('+', (782, 783), 'O'), ('diabetes', (784, 792), 'O'), ('gestacional', (793, 804), 'O'), ('(', (805, 806), 'O'), ('dga1', (807, 811), 'O'), (')', (812, 813), 'O'), ('+', (814, 815), 'O'), ('pequeño', (816, 823), 'O'), ('para', (824, 828), 'O'), ('la', (829, 831), 'O'), ('edad', (832, 836), 'O'), ('gestacional', (837, 848), 'O'), ('(peg)', (849, 854), 'O'), ('secundigesta', (855, 867), 'O'), ('de', (868, 870), 'O'), ('40', (871, 873), 'O'), ('semanas', (874, 881), 'O'), ('que', (882, 885), 'O'), ('ingresa', (886, 893), 'O'), ('para', (894, 898), 'O'), ('induccion', (899, 908), 'O'), ('por', (909, 912), 'O'), ('feto', (913, 917), 'O'), ('pequeño', (918, 925), 'O'), ('para', (926, 930), 'O'), ('la', (931, 933), 'O'), ('edad', (934, 938), 'O'), ('gestacional', (939, 950), 'O'), ('(peg).', (951, 957), 'O'), ('resumen', (958, 965), 'O'), ('gestacional', (966, 977), 'O'), ('-', (978, 979), 'O'), ('as', (980, 982), 'O'), ('1', (983, 984), 'O'), ('t:', (985, 987), 'O'), ('hb:12.1', (988, 995), 'O'), ('hto:34.2', (996, 1004), 'O'), ('-', (1005, 1006), 'O'), ('as', (1007, 1009), 'O'), ('2t:', (1010, 1013), 'O'), ('hb', (1014, 1016), 'O'), ('10.6,', (1017, 1022), 'O'), ('hto', (1023, 1026), 'O'), ('31.9%', (1027, 1032), 'O'), ('-', (1033, 1034), 'O'), ('as', (1035, 1037), 'O'), ('3t:', (1038, 1041), 'O'), ('hb', (1042, 1044), 'O'), ('12.9', (1045, 1049), 'O'), ('hto', (1050, 1053), 'O'), ('39,7%', (1054, 1059), 'O'), ('pq', (1060, 1062), 'O'), ('245.', (1063, 1067), 'O'), ('coagulacion', (1068, 1079), 'O'), ('normal.', (1080, 1087), 'O'), ('bioquimica', (1088, 1098), 'O'), ('normal.', (1099, 1106), 'O'), ('vih', (1107, 1110), 'NSCO'), ('negativo.', (1111, 1120), 'NEG'), ('serologias:', (1121, 1132), 'O'), ('rubeola', (1133, 1140), 'O'), ('no', (1141, 1143), 'NEG'), ('inmune,', (1144, 1151), 'NSCO'), ('toxoplasma', (1152, 1162), 'O'), ('no', (1163, 1165), 'NEG'), ('immune,', (1166, 1173), 'NSCO'), ('lues', (1174, 1178), 'NSCO'), ('vih,', (1179, 1183), 'NSCO'), ('vhb', (1184, 1187), 'NSCO'), ('y', (1188, 1189), 'NSCO'), ('vhc', (1190, 1193), 'NSCO'), ('negativos.', (1194, 1204), 'NEG'), ('-', (1205, 1206), 'O'), ('triple', (1207, 1213), 'O'), ('screening ...
# ('induccion', (319, 328), 'O')
# O
# 578

# %%
word_feature = []
scope_feature = []
tag_feature = []
maj_number = []
contains_num = []
is_number = []
num = ['1', '2', '3', '4', '5', '6', '7', '8', '9', '0']

def num_in_word(word):
    for thing in word:
        if thing in num:
            return 1
    return 0

def num_(word):
    if word.isdigit():
            return 1
    return 0

def proportion_number(word):
    count= 0
    for thing in word:
        if thing in num:
            count+=1
    if count > (len(word)/2):
        return 1
    return 0

for label in labels:
    for it in label:
        word_feature.append(it[0])
        scope_feature.append(it[1])
        tag_feature.append(it[2])

        word_separate = it[0].split()

        contains_num.append(num_in_word(it[0]))
        maj_number.append(proportion_number(it[0]))
        is_number.append(num_(it[0]))

# %%
feature_dict = {}
for i in range(len(word_feature)):
    feature_dict[word_feature[i]] = {
        'Scope': scope_feature[i],
        'Tag': tag_feature[i],
        'Maj NUMBER': maj_number[i],
        'Contains NUMBER': contains_num[i],
        'Is NUMBER': is_number[i]
    }
first_item = next(iter(feature_dict.items()))
print(first_item)
# Out:
# ('induccion', {'Scope': (2091, 2100), 'Tag': 'O', 'Maj NUMBER': 0, 'Contains NUMBER': 0, 'Is NUMBER': 0})

# %%
print(f'The lenght of Word Feature is {len(word_feature)}')
print(f'The lenght of Scope Feature is {len(scope_feature)}')
print(f'The lenght of Tag Feature is {len(tag_feature)}')
print(f'The lenght of Majority Number Feature is {len(maj_number)}')
print(f'The lenght of Contains Number Feature is {len(contains_num)}')
# Out:
# The lenght of Word Feature is 43850
# The lenght of Scope Feature is 43850
# The lenght of Tag Feature is 43850
# The lenght of Majority Number Feature is 43850
# The lenght of Contains Number Feature is 43850

# %% [markdown]
# ## **Feature Extraction**

# %%
#load spacy's spanish special.
nlp = spacy.load("es_core_news_md")
#to get the POS as a feature for each word.
def get_pos_tags(words):
    text = ' '.join(words) #convert the words to text.
    doc = nlp(text) #make it a doc using the function dowloaded before from spacy.

    #Create a dictionary where the key = word and the value = POS tag.
    pos_tags_dict = {token.text: token.pos_ for token in doc}
    lemma_tags_dict = {token.text: token.lemma_ for token in doc}

    pos_tags = [pos_tags_dict.get(word, 'O') for word in words]
    lemma_ = [lemma_tags_dict.get(word, 'O') for word in words]
    #print(f'Length of Words---> {len(pos_tags_dict)}')
    return pos_tags, lemma_

seperate_texts = []
for label in labels:
    text = []
    for it in label:
        text.append(it[0])
    seperate_texts.append(text)

# %%
# Create a list of texts from the labels
separate_texts = []
for label in labels:
    text = []
    for it in label:
        if isinstance(it, str):
            text.append(it)
        elif isinstance(it, tuple) and isinstance(it[0], str):
            text.append(it[0])
    separate_texts.append(text)

# Get POS tags for each text
pos_texts = []
lemma_texts = []

for text in separate_texts:
    pos_tags, lemma_tags = get_pos_tags(text)
    pos_texts.append(pos_tags)
    lemma_texts.append(lemma_tags)


# Print lengths for comparison
print(len(separate_texts[0]))  # Length of the first text in separate_texts
print(len(pos_texts[0]))  # Length of the POS tags dictionary for the first text

# Print the POS tags for the first text as a sample
print(separate_texts[1])
print(pos_texts[1])
# Out:
# 578
# 578
# ['varon', '22', 'años', 'que', 'acude', 'por', 'fiebre.', 'antecedents', 'alergias', 'no', 'refiere', 'alergias', 'medicamentosas', 'conocidas.', 'antecedenes', 'personales', 'niega', 'habitos', 'toxicos.', 'antecedentes', 'medicos:', '-', 'infeccion', 'por', 'vih', 'diagnosticada', 'en', 'octubre/2015,', 'control', 'por', 'dr', '***************,', 'en', 'tar', 'con', 'triumeq', 'desde', 'octubre', '2015', 'con', 'buen', 'cumplimiento', 'terapeutico.', 'en', 'seguimiento', 'en', 'cex', 'infecciosas', '(dr.', '*******).', '**ultima', 'analitica', '(nov', '17)', 'cv', '&lt;50,', 'cd4', '1300.', '**serologies:', 'hbsag', 'negatiu,', 'hbsac', 'positiu,', 'hbcac', 'negatiu,', 'vhc', 'negativa', '-antecedentes', 'its:', '**uretritis', 'gonococica', 'en', 'mayo', '2017,', 'realizo', 'tratamientio.', '**lues', 'latente', 'en', 'sept', '2017', 'tratada', 'con', '3', 'dosis', 'de', 'penicilina', 'im.', '-hsil', 'anal', '(displasia', 'moderada-ain2),', 'vph', '18,42,58,81.', 'en', 'curso', 'de', 'vacunacion', 'de', 'vph', '(ha', 'recibido', '2', 'dosis).', '**citologia', '(nov', '17):', 'mucosa', 'y', 'zona', 'de', 'transicion', 'canal', 'anal', 'con', 'signos', 'de', 'coilocitosis', 'y', 'neoplasia', 'escamosa', 'intraepitelial', 'anal', 'de', 'algo', 'grado/hg-asin.', '-amigdalitis', 'de', 'repeticion', 'por', 'la', 'que', 'se', 'autoadministra', 'amoxicilina.', 'ultimos', 'dos', 'años', 'sin', 'episodios.', 'antecedentes', 'quirurgicos:', 'no', 'refiere.', 'situacion', 'sociofuncional:', 'independiente', 'para', 'las', 'activdades', 'basicas', 'e', 'instrumentales', 'de', 'la', 'vida', 'diaria.', 'tiene', 'pareja', 'estable.', 'vive', 'con', 'su', 'tia.', 'trabaja', 'como', 'barista.', 'medicacio', 'habitual', 'triumeq', '(abacavir', '/', 'dolutegravir', '/', 'lamivudina)', 'proces', 'actual', 'refiere', 'que', 'estando', 'de', 'viaje,', 'la', 'noche', 'del', 'martes', '27', 'de', 'febrero', 'comienza', 'con', 'un', 'cuadro', 'de', 'malestar', 'general,', 'odinofagia,', 'cefalea', 'holocraneal,', 'intensa', 'que', 'le', 'despierta', 'por', 'la', 'noche', 'sin', 'haber', 'tomado', 'analgesia', 'para', 'esto.', 'el', 'cuadro', 'se', 'acompaña', 'de', 'sensacion', 'distermica,', 'con', 'escalofrios,', 'sin', 'haber', 'termometrado', 'fiebre.', 'ademas', 'refiere', 'dolor', 'en', 'region', 'lumbosacra,', 'sin', 'haber', 'presentado', 'traumatismo', 'previo.', 'niega', 'dolor', 'toracico,', 'disnea,', 'tos,', 'expectoracion,', 'dolor', 'abdominal', 'o', 'diarrea.', 'refiere', 'disuria', 'de', 'dias', 'de', 'evolucion,', 'sin', 'secrecion', 'uretral.', 'explica', 'relaciones', 'sexuales', 'sin', 'proteccion', 'con', 'su', 'pareja', 'habitual.', 'niega', 'consumo', 'de', 'toxicos', 'o', 'metamizol', 'los', 'dias', 'previos.', 'exploracio', 'fisica', 'exploracion', 'fisica', 'urgencias', 'ta', '129/66mmhg,', 'fc', '110lpm,', 'tª', '38.2ºc,', 'sato2', '100%aa', 'buen', 'estado', 'general.', 'normocoloreado,', 'normohidratado', 'y', 'normoperfundido.', 'no', 'dolor', 'a', 'la', 'palpacion', 'de', 'apofisis', 'espinosas.', 'no', 'lesiones', 'cutaneas.', 'no', 'palpo', 'adenopatias', 'cervicales', 'ni', 'supraclaviculares.', 'acv:', 'tcr,', 'no', 'ausculto', 'soplos.', 'no', 'iy', 'ni', 'rhy.', 'no', 'edemas', 'en', 'extremidades', 'inferiores.', 'pulsos', 'perifericos', 'presentes', 'y', 'simetricos.', 'ar:', 'eupneico.', 'mvc,', 'sin', 'ruidos', 'sobreañadidos.', 'abd:', 'depresible,', 'no', 'doloroso', 'a', 'la', 'palpacion.', 'no', 'palpo', 'masas', 'ni', 'megalias.', 'peristalsis', 'conservada,', 'sin', 'signos', 'de', 'irritacion', 'peritoneal.', 'ppl', 'bilateral', 'no', 'dolorosa.', 'nrl:', 'consciente', 'y', 'orientado', 'en', 'las', 'tres', 'esferas.', 'pupilas', 'isocoricas', 'y', 'normorreactivas.', 'pares', 'craneales', 'conservados', 'y', 'simetricos.', 'no', 'dismetrias,', 'no', 'flapping.', 'no', 'rigidez', 'de', 'nuca', 'ni', 'signos', 'meningeos.', 'exploracion', 'fisica', 'urgencias', 'ta', '106/70mmhg;', 'fc', '102lpm;', 'tºc' ...
# ['VERB', 'NUM', 'NOUN', 'PRON', 'VERB', 'ADP', 'O', 'NOUN', 'NOUN', 'ADV', 'VERB', 'NOUN', 'ADJ', 'O', 'NOUN', 'ADJ', 'VERB', 'NOUN', 'O', 'NOUN', 'O', 'PUNCT', 'NOUN', 'ADP', 'PROPN', 'ADJ', 'ADP', 'O', 'NOUN', 'ADP', 'NOUN', 'O', 'ADP', 'PROPN', 'ADP', 'PROPN', 'ADP', 'NOUN', 'NUM', 'ADP', 'ADJ', 'NOUN', 'O', 'ADP', 'NOUN', 'ADP', 'NOUN', 'NOUN', 'O', 'O', 'O', 'ADJ', 'O', 'O', 'PROPN', 'O', 'PROPN', 'O', 'O', 'ADJ', 'O', 'PROPN', 'O', 'NOUN', 'O', 'NOUN', 'ADJ', 'ADJ', 'O', 'O', 'ADJ', 'ADP', 'NOUN', 'O', 'VERB', 'O', 'O', 'ADJ', 'ADP', 'PROPN', 'NUM', 'ADJ', 'ADP', 'NUM', 'NOUN', 'ADP', 'NOUN', 'O', 'PROPN', 'ADJ', 'O', 'O', 'PROPN', 'O', 'ADP', 'NOUN', 'ADP', 'PROPN', 'ADP', 'PROPN', 'O', 'VERB', 'NUM', 'O', 'O', 'O', 'O', 'NOUN', 'CCONJ', 'NOUN', 'ADP', 'PROPN', 'PROPN', 'ADJ', 'ADP', 'NOUN', 'ADP', 'NOUN', 'CCONJ', 'NOUN', 'ADJ', 'ADJ', 'ADJ', 'ADP', 'PRON', 'O', 'VERB', 'ADP', 'PROPN', 'ADP', 'DET', 'PRON', 'PRON', 'VERB', 'O', 'ADJ', 'NUM', 'NOUN', 'ADP', 'O', 'NOUN', 'O', 'ADV', 'O', 'VERB', 'O', 'ADJ', 'ADP', 'DET', 'NOUN', 'ADJ', 'CCONJ', 'ADJ', 'ADP', 'DET', 'NOUN', 'O', 'VERB', 'NOUN', 'O', 'VERB', 'ADP', 'DET', 'O', 'VERB', 'SCONJ', 'O', 'ADV', 'ADJ', 'PROPN', 'O', 'PROPN', 'PROPN', 'PROPN', 'O', 'NOUN', 'ADJ', 'VERB', 'PRON', 'VERB', 'ADP', 'O', 'DET', 'NOUN', 'ADP', 'NOUN', 'NUM', 'ADP', 'NOUN', 'VERB', 'ADP', 'DET', 'NOUN', 'ADP', 'NOUN', 'O', 'O', 'NOUN', 'O', 'ADJ', 'PRON', 'PRON', 'VERB', 'ADP', 'DET', 'NOUN', 'ADP', 'AUX', 'VERB', 'NOUN', 'ADP', 'O', 'DET', 'NOUN', 'PRON', 'VERB', 'ADP', 'PROPN', 'O', 'ADP', 'O', 'ADP', 'AUX', 'VERB', 'O', 'PROPN', 'VERB', 'VERB', 'ADP', 'NOUN', 'O', 'ADP', 'AUX', 'VERB', 'NOUN', 'O', 'VERB', 'VERB', 'O', 'O', 'O', 'O', 'VERB', 'ADJ', 'CCONJ', 'O', 'VERB', 'NOUN', 'ADP', 'NOUN', 'ADP', 'O', 'ADP', 'PROPN', 'O', 'VERB', 'NOUN', 'ADJ', 'ADP', 'NOUN', 'ADP', 'DET', 'NOUN', 'O', 'VERB', 'NOUN', 'ADP', 'NOUN', 'CCONJ', 'NOUN', 'DET', 'NOUN', 'O', 'PROPN', 'ADJ', 'NOUN', 'ADJ', 'NOUN', 'PROPN', 'O', 'PROPN', 'O', 'ADP', 'O', 'PUNCT', 'NOUN', 'ADJ', 'NOUN', 'O', 'O', 'ADJ', 'CCONJ', 'O', 'ADV', 'VERB', 'ADP', 'DET', 'PROPN', 'ADP', 'NOUN', 'O', 'ADV', 'NOUN', 'O', 'ADV', 'VERB', 'NOUN', 'ADJ', 'CCONJ', 'O', 'O', 'O', 'ADV', 'ADJ', 'O', 'ADV', 'NOUN', 'CCONJ', 'O', 'ADV', 'NOUN', 'ADP', 'NOUN', 'O', 'NOUN', 'ADJ', 'ADJ', 'CCONJ', 'O', 'O', 'O', 'O', 'ADP', 'NOUN', 'O', 'O', 'O', 'ADV', 'ADJ', 'ADP', 'DET', 'O', 'ADV', 'VERB', 'NOUN', 'CCONJ', 'O', 'NOUN', 'O', 'ADP', 'NOUN', 'ADP', 'PROPN', 'O', 'NOUN', 'ADJ', 'ADV', 'O', 'O', 'ADJ', 'CCONJ', 'ADJ', 'ADP', 'DET', 'NUM', 'O', 'NOUN', 'ADJ', 'CCONJ', 'O', 'NOUN', 'ADJ', 'ADJ', 'CCONJ', 'O', 'ADV', 'O', 'ADV', 'O', 'ADV', 'NOUN', 'ADP', 'NOUN', 'CCONJ', 'NOUN', 'O', 'NOUN', 'ADJ', 'NOUN', 'PROPN', 'O', 'PROPN', 'O', 'PROPN', 'O', 'PUNCT', 'SYM', 'O', 'NOUN', 'O', 'ADJ', 'NOUN', 'O', 'NOUN', 'CCONJ', 'ADV', 'O', 'ADJ', 'CCONJ', 'O', 'ADJ', 'ADP', 'O', 'NOUN', 'CCONJ', 'O', 'ADV', 'PRON', 'VERB', 'NOUN', 'ADJ', 'CCONJ', 'O', 'PROPN', 'O', 'NOUN', 'ADJ', 'ADP', 'O', 'O', 'NOUN', 'ADJ', 'ADP', 'NOUN', 'ADJ', 'CCONJ', 'ADP', 'O', 'ADV', 'NOUN', 'ADP', 'NOUN', 'ADJ', 'CCONJ', 'NOUN', 'O', 'O', 'NOUN', 'ADJ', 'ADP', 'NOUN', 'ADJ', 'O', 'ADP', 'NOUN', 'ADJ', 'O', 'O', 'ADV', 'O', 'ADJ', 'CCONJ', 'O', 'ADV', 'ADJ', 'ADP', 'DET', 'O', 'ADV', 'PRON', 'VERB', 'NOUN', 'CCONJ', 'O', 'CCONJ', 'ADV', 'PROPN', 'O', 'ADV', 'NOUN', 'ADP', 'PROPN', 'O', 'ADP', 'NOUN', 'ADJ', 'O', 'O', 'ADJ', 'CCONJ', 'ADJ', 'ADP', 'DET', 'NUM', 'O', 'ADV', 'NOUN', 'ADP', 'O', 'ADV', 'NOUN', 'ADP', 'NOUN', 'ADJ', 'O', 'PROPN', 'ADJ', 'PROPN', 'PUNCT', 'ADJ', 'ADJ', 'ADP', 'O', 'INTJ', 'NUM', 'O', 'PROPN', 'O', 'NOUN', 'SYM', 'ADP', 'NOUN', 'ADJ', 'ADP', 'DET', 'O', 'VERB', 'NOUN', 'PUNCT', 'NOUN', 'ADJ', 'ADV', 'ADJ', 'O', 'NOUN', 'ADJ', 'O', 'ADV', 'NOUN', 'O', 'O', 'SCONJ', 'O', 'PROPN', 'O', 'NOUN', 'O', 'NOUN', 'O', 'NOUN', 'O', 'NOUN', 'O', 'ADJ', 'O', 'NOUN', 'O', 'PROPN', 'O', 'PROPN', 'O', 'AUX', 'O', 'O', 'PROPN', 'O', 'NOUN', 'O', 'PROPN', 'O', 'NOUN', 'O', 'P ...

# %%
pos_feature_pandas = []
lemma_feature_pandas = []
sentence_id = []
sentence_idx = 0  # Initialize sentence index
token_count = 0  # Initialize token count

# Assuming pos_texts and lemma_texts are lists of lists, where each inner list represents a tokenized sentence
for pos_sentence, lemma_sentence in zip(pos_texts, lemma_texts):
    for pos, lemma in zip(pos_sentence, lemma_sentence):
        pos_feature_pandas.append(pos)
        lemma_feature_pandas.append(lemma)
        sentence_id.append(sentence_idx)

        token_count += 1  # Increment token count

        # Check if 200 tokens have been added
        if token_count >= 200:
            sentence_idx += 1  # Increment sentence index
            token_count = 0  # Reset token count

# Handle any remaining tokens that didn't complete the last 200-token block
if token_count > 0:
    sentence_idx += 1  # This ensures that even the last block has a unique index if it's less than 200 tokens

print()

# %%
initial_scopes = []
final_scopes = []

for start, end in scope_feature:
    initial_scopes.append(start)
    final_scopes.append(end)

print(f'The lenght of Word Feature is {len(word_feature)}')
print(f'The lenght of Initial Scopes Feature is {len(initial_scopes)}')
print(f'The lenght of Initial Scopes Feature is {len(final_scopes)}')
print(f'The lenght of Tag Feature is {len(tag_feature)}')
print(f'The lenght of POS Feature is {len(pos_feature_pandas)}')
print(f'The lenght of LEMMA Feature is {len(lemma_feature_pandas)}')
# Out:
# The lenght of Word Feature is 43850
# The lenght of Initial Scopes Feature is 43850
# The lenght of Initial Scopes Feature is 43850
# The lenght of Tag Feature is 43850
# The lenght of POS Feature is 43850
# The lenght of LEMMA Feature is 43850

# %%
data_tuples = list(zip(word_feature, initial_scopes, final_scopes, tag_feature, pos_feature_pandas, lemma_feature_pandas, is_number,contains_num, maj_number,sentence_id))
data = pd.DataFrame(data_tuples, columns=['Word', 'Initial Scopes','Final Scopes','Tag', 'POS', 'LEMMA', 'NUMBER', 'Contains NUMBER', 'Maj NUMBER', 'text_id'])

# %%
# Export the DataFrame to a CSV file
csv_file_path = '/content/feature_extracted_dataTEST.csv'
data.to_csv(csv_file_path, index=False)

# %%
from IPython.display import display

def show_data(datos, first, second):
    styled_data = datos.iloc[first:second].style.set_properties(**{'text-align': 'left'})
    display(styled_data)

show_data(datos=data, first=41, second=100)
# Out:
# <style type="text/css">
# #T_d34a8_row0_col0, #T_d34a8_row0_col1, #T_d34a8_row0_col2, #T_d34a8_row0_col3, #T_d34a8_row0_col4, #T_d34a8_row0_col5, #T_d34a8_row0_col6, #T_d34a8_row0_col7, #T_d34a8_row0_col8, #T_d34a8_row0_col9, #T_d34a8_row1_col0, #T_d34a8_row1_col1, #T_d34a8_row1_col2, #T_d34a8_row1_col3, #T_d34a8_row1_col4, #T_d34a8_row1_col5, #T_d34a8_row1_col6, #T_d34a8_row1_col7, #T_d34a8_row1_col8, #T_d34a8_row1_col9, #T_d34a8_row2_col0, #T_d34a8_row2_col1, #T_d34a8_row2_col2, #T_d34a8_row2_col3, #T_d34a8_row2_col4, #T_d34a8_row2_col5, #T_d34a8_row2_col6, #T_d34a8_row2_col7, #T_d34a8_row2_col8, #T_d34a8_row2_col9, #T_d34a8_row3_col0, #T_d34a8_row3_col1, #T_d34a8_row3_col2, #T_d34a8_row3_col3, #T_d34a8_row3_col4, #T_d34a8_row3_col5, #T_d34a8_row3_col6, #T_d34a8_row3_col7, #T_d34a8_row3_col8, #T_d34a8_row3_col9, #T_d34a8_row4_col0, #T_d34a8_row4_col1, #T_d34a8_row4_col2, #T_d34a8_row4_col3, #T_d34a8_row4_col4, #T_d34a8_row4_col5, #T_d34a8_row4_col6, #T_d34a8_row4_col7, #T_d34a8_row4_col8, #T_d34a8_row4_col9, #T_d34a8_row5_col0, #T_d34a8_row5_col1, #T_d34a8_row5_col2, #T_d34a8_row5_col3, #T_d34a8_row5_col4, #T_d34a8_row5_col5, #T_d34a8_row5_col6, #T_d34a8_row5_col7, #T_d34a8_row5_col8, #T_d34a8_row5_col9, #T_d34a8_row6_col0, #T_d34a8_row6_col1, #T_d34a8_row6_col2, #T_d34a8_row6_col3, #T_d34a8_row6_col4, #T_d34a8_row6_col5, #T_d34a8_row6_col6, #T_d34a8_row6_col7, #T_d34a8_row6_col8, #T_d34a8_row6_col9, #T_d34a8_row7_col0, #T_d34a8_row7_col1, #T_d34a8_row7_col2, #T_d34a8_row7_col3, #T_d34a8_row7_col4, #T_d34a8_row7_col5, #T_d34a8_row7_col6, #T_d34a8_row7_col7, #T_d34a8_row7_col8, #T_d34a8_row7_col9, #T_d34a8_row8_col0, #T_d34a8_row8_col1, #T_d34a8_row8_col2, #T_d34a8_row8_col3, #T_d34a8_row8_col4, #T_d34a8_row8_col5, #T_d34a8_row8_col6, #T_d34a8_row8_col7, #T_d34a8_row8_col8, #T_d34a8_row8_col9, #T_d34a8_row9_col0, #T_d34a8_row9_col1, #T_d34a8_row9_col2, #T_d34a8_row9_col3, #T_d34a8_row9_col4, #T_d34a8_row9_col5, #T_d34a8_row9_col6, #T_d34a8_row9_col7, #T_d34a8_row9_col8, #T_d34a8_row9_col9, #T_d34a8_row10_col0, #T_d34a8_row10_col1, #T_d34a8_row10_col2, #T_d34a8_row10_col3, #T_d34a8_row10_col4, #T_d34a8_row10_col5, #T_d34a8_row10_col6, #T_d34a8_row10_col7, #T_d34a8_row10_col8, #T_d34a8_row10_col9, #T_d34a8_row11_col0, #T_d34a8_row11_col1, #T_d34a8_row11_col2, #T_d34a8_row11_col3, #T_d34a8_row11_col4, #T_d34a8_row11_col5, #T_d34a8_row11_col6, #T_d34a8_row11_col7, #T_d34a8_row11_col8, #T_d34a8_row11_col9, #T_d34a8_row12_col0, #T_d34a8_row12_col1, #T_d34a8_row12_col2, #T_d34a8_row12_col3, #T_d34a8_row12_col4, #T_d34a8_row12_col5, #T_d34a8_row12_col6, #T_d34a8_row12_col7, #T_d34a8_row12_col8, #T_d34a8_row12_col9, #T_d34a8_row13_col0, #T_d34a8_row13_col1, #T_d34a8_row13_col2, #T_d34a8_row13_col3, #T_d34a8_row13_col4, #T_d34a8_row13_col5, #T_d34a8_row13_col6, #T_d34a8_row13_col7, #T_d34a8_row13_col8, #T_d34a8_row13_col9, #T_d34a8_row14_col0, #T_d34a8_row14_col1, #T_d34a8_row14_col2, #T_d34a8_row14_col3, #T_d34a8_row14_col4, #T_d34a8_row14_col5, #T_d34a8_row14_col6, #T_d34a8_row14_col7, #T_d34a8_row14_col8, #T_d34a8_row14_col9, #T_d34a8_row15_col0, #T_d34a8_row15_col1, #T_d34a8_row15_col2, #T_d34a8_row15_col3, #T_d34a8_row15_col4, #T_d34a8_row15_col5, #T_d34a8_row15_col6, #T_d34a8_row15_col7, #T_d34a8_row15_col8, #T_d34a8_row15_col9, #T_d34a8_row16_col0, #T_d34a8_row16_col1, #T_d34a8_row16_col2, #T_d34a8_row16_col3, #T_d34a8_row16_col4, #T_d34a8_row16_col5, #T_d34a8_row16_col6, #T_d34a8_row16_col7, #T_d34a8_row16_col8, #T_d34a8_row16_col9, #T_d34a8_row17_col0, #T_d34a8_row17_col1, #T_d34a8_row17_col2, #T_d34a8_row17_col3, #T_d34a8_row17_col4, #T_d34a8_row17_col5, #T_d34a8_row17_col6, #T_d34a8_row17_col7, #T_d34a8_row17_col8, #T_d34a8_row17_col9, #T_d34a8_row18_col0, #T_d34a8_row18_col1, #T_d34a8_row18_col2, #T_d34a8_row18_col3, #T_d34a8_row18_col4, #T_d34a8_row18_col5, #T_d34a8_row18_col6, #T_d34a8_row18_col7, #T_d34a8_row18_col8, #T_d34a8_row18_col9, #T_d34a8_row19_col0, #T_d34a8_row19_col1, #T_d34a8_row19_col2, #T_d34a8_row19_col3, #T_d34a8_row19_col4, #T_d3 ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 168887 entries, 0 to 168886
# Data columns (total 10 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Word             168887 non-null  object
#  1   Initial Scopes   168887 non-null  int64
#  2   Final Scopes     168887 non-null  int64
#  3   Tag              168887 non-null  object
#  4   POS              168887 non-null  object
#  5   LEMMA            168887 non-null  object
#  6   NUMBER           168887 non-null  int64
#  7   Contains NUMBER  168887 non-null  int64
#  8   Maj NUMBER       168887 non-null  int64
#  9   text_id          168887 non-null  int64
# dtypes: int64(6), object(4)
# memory usage: 12.9+ MB

# %%
# Filter the DataFrame where "Maj NUMBER" is equal to 1
filtered_df = data[(data['Maj NUMBER'] == 0) & (data['Contains NUMBER'] == 1)]
show_data(datos=filtered_df, first=0, second=10)
# Out:
# <style type="text/css">
# #T_d7958_row0_col0, #T_d7958_row0_col1, #T_d7958_row0_col2, #T_d7958_row0_col3, #T_d7958_row0_col4, #T_d7958_row0_col5, #T_d7958_row0_col6, #T_d7958_row0_col7, #T_d7958_row0_col8, #T_d7958_row0_col9, #T_d7958_row1_col0, #T_d7958_row1_col1, #T_d7958_row1_col2, #T_d7958_row1_col3, #T_d7958_row1_col4, #T_d7958_row1_col5, #T_d7958_row1_col6, #T_d7958_row1_col7, #T_d7958_row1_col8, #T_d7958_row1_col9, #T_d7958_row2_col0, #T_d7958_row2_col1, #T_d7958_row2_col2, #T_d7958_row2_col3, #T_d7958_row2_col4, #T_d7958_row2_col5, #T_d7958_row2_col6, #T_d7958_row2_col7, #T_d7958_row2_col8, #T_d7958_row2_col9, #T_d7958_row3_col0, #T_d7958_row3_col1, #T_d7958_row3_col2, #T_d7958_row3_col3, #T_d7958_row3_col4, #T_d7958_row3_col5, #T_d7958_row3_col6, #T_d7958_row3_col7, #T_d7958_row3_col8, #T_d7958_row3_col9, #T_d7958_row4_col0, #T_d7958_row4_col1, #T_d7958_row4_col2, #T_d7958_row4_col3, #T_d7958_row4_col4, #T_d7958_row4_col5, #T_d7958_row4_col6, #T_d7958_row4_col7, #T_d7958_row4_col8, #T_d7958_row4_col9, #T_d7958_row5_col0, #T_d7958_row5_col1, #T_d7958_row5_col2, #T_d7958_row5_col3, #T_d7958_row5_col4, #T_d7958_row5_col5, #T_d7958_row5_col6, #T_d7958_row5_col7, #T_d7958_row5_col8, #T_d7958_row5_col9, #T_d7958_row6_col0, #T_d7958_row6_col1, #T_d7958_row6_col2, #T_d7958_row6_col3, #T_d7958_row6_col4, #T_d7958_row6_col5, #T_d7958_row6_col6, #T_d7958_row6_col7, #T_d7958_row6_col8, #T_d7958_row6_col9, #T_d7958_row7_col0, #T_d7958_row7_col1, #T_d7958_row7_col2, #T_d7958_row7_col3, #T_d7958_row7_col4, #T_d7958_row7_col5, #T_d7958_row7_col6, #T_d7958_row7_col7, #T_d7958_row7_col8, #T_d7958_row7_col9, #T_d7958_row8_col0, #T_d7958_row8_col1, #T_d7958_row8_col2, #T_d7958_row8_col3, #T_d7958_row8_col4, #T_d7958_row8_col5, #T_d7958_row8_col6, #T_d7958_row8_col7, #T_d7958_row8_col8, #T_d7958_row8_col9, #T_d7958_row9_col0, #T_d7958_row9_col1, #T_d7958_row9_col2, #T_d7958_row9_col3, #T_d7958_row9_col4, #T_d7958_row9_col5, #T_d7958_row9_col6, #T_d7958_row9_col7, #T_d7958_row9_col8, #T_d7958_row9_col9 {
#   text-align: left;
# }
# </style>
# <table id="T_d7958" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d7958_level0_col0" class="col_heading level0 col0" >Word</th>
#       <th id="T_d7958_level0_col1" class="col_heading level0 col1" >Initial Scopes</th>
#       <th id="T_d7958_level0_col2" class="col_heading level0 col2" >Final Scopes</th>
#       <th id="T_d7958_level0_col3" class="col_heading level0 col3" >Tag</th>
#       <th id="T_d7958_level0_col4" class="col_heading level0 col4" >POS</th>
#       <th id="T_d7958_level0_col5" class="col_heading level0 col5" >LEMMA</th>
#       <th id="T_d7958_level0_col6" class="col_heading level0 col6" >NUMBER</th>
#       <th id="T_d7958_level0_col7" class="col_heading level0 col7" >Contains NUMBER</th>
#       <th id="T_d7958_level0_col8" class="col_heading level0 col8" >Maj NUMBER</th>
#       <th id="T_d7958_level0_col9" class="col_heading level0 col9" >text_id</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d7958_level0_row0" class="row_heading level0 row0" >456</th>
#       <td id="T_d7958_row0_col0" class="data row0 col0" >38ºc,</td>
#       <td id="T_d7958_row0_col1" class="data row0 col1" >3549</td>
#       <td id="T_d7958_row0_col2" class="data row0 col2" >3554</td>
#       <td id="T_d7958_row0_col3" class="data row0 col3" >O</td>
#       <td id="T_d7958_row0_col4" class="data row0 col4" >O</td>
#       <td id="T_d7958_row0_col5" class="data row0 col5" >O</td>
#       <td id="T_d7958_row0_col6" class="data row0 col6" >0</td>
#       <td id="T_d7958_row0_col7" class="data row0 col7" >1</td>
#       <td id="T_d7958_row0_col8" class="data row0 col8" >0</td>
#       <td id="T_d7958_row0_col9" class="data row0 col9" >2</td>
#     </tr>
#     <tr>
#       <th id="T_d7958_level0_row1" class="row_heading level0 row1" >818</th>
#       <td id="T_d7958_row1_col0" class="data row1 col0" >4gr</td>
#       <td id="T_d7958_row1_col1" class="data row1 col1" >1670</td>
#       <td id="T_d7958_row1_col2" class="data row1 col2" >1673</td>
#       <td id="T_d7958_row1_col3" class="data row1 col3" >O</td>
#       <td id="T_d7958_row1_col4" class="data row1 col4" >NUM</td>
#       <td id="T_d7958_row1_col5" class="data row1 col5" >4gr</td>
#       <td id="T_d7958_row1_col6" class="data row1 col6" >0</td>
#       <td id="T_d7958_row1_col7" class="data row1 col7" >1</td>
#       <td id="T_d7958_row1_col8" class="data row1 col8" >0</td>
#       <td id="T_d7958_row1_col9" class="data row1 col9" >4</td>
#     </tr>
#     <tr>
#       <th id="T_d7958_level0_row2" class="row_heading level0 row2" >820</th>
#       <td id="T_d7958_row2_col0" class="data row2 col0" >c/6hrs</td>
#       <td id="T_d7958_row2_col1" class="data row2 col1" >1677</td>
#       <td id="T_d7958_row2_col2" class="data row2 col2" >1683</td>
#       <td id="T_d7958_row2_col3" class="data row2 col3" >O</td>
#       <td id="T_d7958_row2_col4" class="data row2 col4" >PROPN</td>
#       <td id="T_d7958_row2_col5" class="data row2 col5" >c/6hrs</td>
#       <td id="T_d7958_row2_col6" class="data row2 col6" >0</td>
#       <td id="T_d7958_row2_col7" class="data row2 col7" >1</td>
#       <td id="T_d7958_row2_col8" class="data row2 col8" >0</td>
#       <td id="T_d7958_row2_col9" class="data row2 col9" >4</td>
#     </tr>
#     <tr>
#       <th id="T_d7958_level0_row3" class="row_heading level0 row3" >880</th>
#       <td id="T_d7958_row3_col0" class="data row3 col0" >c/8hrs</td>
#       <td id="T_d7958_row3_col1" class="data row3 col1" >2124</td>
#       <td id="T_d7958_row3_col2" class="data row3 col2" >2130</td>
#       <td id="T_d7958_row3_col3" class="data row3 col3" >O</td>
#       <td id="T_d7958_row3_col4" class="data row3 col4" >PROPN</td>
#       <td id="T_d7958_row3_col5" class="data row3 col5" >c/8hrs</td>
#       <td id="T_d7958_row3_col6" class="data row3 col6" >0</td>
#       <td id="T_d7958_row3_col7" class="data row3 col7" >1</td>
#       <td id="T_d7958_row3_col8" class="data row3 col8" >0</td>
#       <td id="T_d7958_row3_col9" class="data row3 col9" >4</td>
#     </tr>
#     <tr>
#       <th id="T_d7958_level0_row4" class="row_heading level0 row4" >1045</th>
#       <td id="T_d7958_row4_col0" class="data row4 col0" >x3</td>
#       <td id="T_d7958_row4_col1" class="data row4 col1" >3274</td>
#       <td id="T_d7958_row4_col2" class="data row4 col2" >3276</td>
#       <td id="T_d7958_row4_col3" class="data row4 col3" >O</td>
#       <td id="T_d7958_row4_col4" class="data row4 col4" >PROPN</td>
#       <td id="T_d7958_row4_col5" class="data row4 col5" >x3</td>
#       <td id="T_d7958_row4_col6" class="data row4 col6" >0</td>
#       <td id="T_d7958_row4_col7" class="data row4 col7" >1</td>
#       <td id="T_d7958_row4_col8" class="data row4 col8" >0</td>
#       <td id="T_d7958_row4_col9" class="data row4 col9" >5</td>
#     </tr>
#     <tr>
#       <th id="T_d7958_level0_row5" class="row_heading level0 row5" >1056</th>
#       <td id="T_d7958_row5_col0" class="data row5 col0" >4mg/6h</td>
#       <td id="T_d7958_row5_col1" class="data row5 col1" >3368</td>
#       <td id="T_d7958_row5_col2" class="data row5 col2" >3374</td>
#       <td id="T_d7958_row5_col3" class="data row5 col3" >O</td>
#       <td id="T_d7958_row5_col4" class="data row5 col4" >NUM</td>
#       <td id="T_d7958_row5_col5" class="data row5 col5" >4mg/6h</td>
#       <td id="T_d7958_row5_col6" class="data row5 col6" >0</td>
#       <td id="T_d7958_row5_col7" class="data row5 col7" >1</td>
#       <td id="T_d7958_row5_col8" class="data row5 col8" >0</td>
#       <td id="T_d7958_row5_col9" class="data row5 col9" >5</td>
#     </tr>
#     <tr>
#       <th id="T_d7958_level0_row6" class="row_heading level0 row6" >1071</th>
#       <td id="T_d7958_row6_col0" class="data row6 col0" >500mg/8h</td>
#       <td id="T_d7958_row6_col1" class="data row6 col1" >3484</td>
#       <td id="T_d7958_row6_col2" class="data row6 col2" >3492</td>
#       <td id="T_d7958_row6_col3" class="data row6 col3" >O</td>
#       <td id="T_d7958_row6_col4" class="data row6 col4" >NUM</td>
#       <td id="T_d7958_row6_col5" class="data row6 col5" >500

# %%
# Filter the DataFrame where "Maj NUMBER" is equal to 1
filtered_df = data[(data['Maj NUMBER'] == 1) & (data['Contains NUMBER'] == 1)]
show_data(datos=filtered_df, first=0, second=10)
# Out:
# <style type="text/css">
# #T_05c0d_row0_col0, #T_05c0d_row0_col1, #T_05c0d_row0_col2, #T_05c0d_row0_col3, #T_05c0d_row0_col4, #T_05c0d_row0_col5, #T_05c0d_row0_col6, #T_05c0d_row0_col7, #T_05c0d_row0_col8, #T_05c0d_row0_col9, #T_05c0d_row1_col0, #T_05c0d_row1_col1, #T_05c0d_row1_col2, #T_05c0d_row1_col3, #T_05c0d_row1_col4, #T_05c0d_row1_col5, #T_05c0d_row1_col6, #T_05c0d_row1_col7, #T_05c0d_row1_col8, #T_05c0d_row1_col9, #T_05c0d_row2_col0, #T_05c0d_row2_col1, #T_05c0d_row2_col2, #T_05c0d_row2_col3, #T_05c0d_row2_col4, #T_05c0d_row2_col5, #T_05c0d_row2_col6, #T_05c0d_row2_col7, #T_05c0d_row2_col8, #T_05c0d_row2_col9, #T_05c0d_row3_col0, #T_05c0d_row3_col1, #T_05c0d_row3_col2, #T_05c0d_row3_col3, #T_05c0d_row3_col4, #T_05c0d_row3_col5, #T_05c0d_row3_col6, #T_05c0d_row3_col7, #T_05c0d_row3_col8, #T_05c0d_row3_col9, #T_05c0d_row4_col0, #T_05c0d_row4_col1, #T_05c0d_row4_col2, #T_05c0d_row4_col3, #T_05c0d_row4_col4, #T_05c0d_row4_col5, #T_05c0d_row4_col6, #T_05c0d_row4_col7, #T_05c0d_row4_col8, #T_05c0d_row4_col9, #T_05c0d_row5_col0, #T_05c0d_row5_col1, #T_05c0d_row5_col2, #T_05c0d_row5_col3, #T_05c0d_row5_col4, #T_05c0d_row5_col5, #T_05c0d_row5_col6, #T_05c0d_row5_col7, #T_05c0d_row5_col8, #T_05c0d_row5_col9, #T_05c0d_row6_col0, #T_05c0d_row6_col1, #T_05c0d_row6_col2, #T_05c0d_row6_col3, #T_05c0d_row6_col4, #T_05c0d_row6_col5, #T_05c0d_row6_col6, #T_05c0d_row6_col7, #T_05c0d_row6_col8, #T_05c0d_row6_col9, #T_05c0d_row7_col0, #T_05c0d_row7_col1, #T_05c0d_row7_col2, #T_05c0d_row7_col3, #T_05c0d_row7_col4, #T_05c0d_row7_col5, #T_05c0d_row7_col6, #T_05c0d_row7_col7, #T_05c0d_row7_col8, #T_05c0d_row7_col9, #T_05c0d_row8_col0, #T_05c0d_row8_col1, #T_05c0d_row8_col2, #T_05c0d_row8_col3, #T_05c0d_row8_col4, #T_05c0d_row8_col5, #T_05c0d_row8_col6, #T_05c0d_row8_col7, #T_05c0d_row8_col8, #T_05c0d_row8_col9, #T_05c0d_row9_col0, #T_05c0d_row9_col1, #T_05c0d_row9_col2, #T_05c0d_row9_col3, #T_05c0d_row9_col4, #T_05c0d_row9_col5, #T_05c0d_row9_col6, #T_05c0d_row9_col7, #T_05c0d_row9_col8, #T_05c0d_row9_col9 {
#   text-align: left;
# }
# </style>
# <table id="T_05c0d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_05c0d_level0_col0" class="col_heading level0 col0" >Word</th>
#       <th id="T_05c0d_level0_col1" class="col_heading level0 col1" >Initial Scopes</th>
#       <th id="T_05c0d_level0_col2" class="col_heading level0 col2" >Final Scopes</th>
#       <th id="T_05c0d_level0_col3" class="col_heading level0 col3" >Tag</th>
#       <th id="T_05c0d_level0_col4" class="col_heading level0 col4" >POS</th>
#       <th id="T_05c0d_level0_col5" class="col_heading level0 col5" >LEMMA</th>
#       <th id="T_05c0d_level0_col6" class="col_heading level0 col6" >NUMBER</th>
#       <th id="T_05c0d_level0_col7" class="col_heading level0 col7" >Contains NUMBER</th>
#       <th id="T_05c0d_level0_col8" class="col_heading level0 col8" >Maj NUMBER</th>
#       <th id="T_05c0d_level0_col9" class="col_heading level0 col9" >text_id</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_05c0d_level0_row0" class="row_heading level0 row0" >57</th>
#       <td id="T_05c0d_row0_col0" class="data row0 col0" >81a</td>
#       <td id="T_05c0d_row0_col1" class="data row0 col1" >780</td>
#       <td id="T_05c0d_row0_col2" class="data row0 col2" >783</td>
#       <td id="T_05c0d_row0_col3" class="data row0 col3" >O</td>
#       <td id="T_05c0d_row0_col4" class="data row0 col4" >NUM</td>
#       <td id="T_05c0d_row0_col5" class="data row0 col5" >81a</td>
#       <td id="T_05c0d_row0_col6" class="data row0 col6" >0</td>
#       <td id="T_05c0d_row0_col7" class="data row0 col7" >1</td>
#       <td id="T_05c0d_row0_col8" class="data row0 col8" >1</td>
#       <td id="T_05c0d_row0_col9" class="data row0 col9" >0</td>
#     </tr>
#     <tr>
#       <th id="T_05c0d_level0_row1" class="row_heading level0 row1" >122</th>
#       <td id="T_05c0d_row1_col0" class="data row1 col0" >(11/2017):</td>
#       <td id="T_05c0d_row1_col1" class="data row1 col1" >1206</td>
#       <td id="T_05c0d_row1_col2" class="data row1 col2" >1216</td>
#       <td id="T_05c0d_row1_col3" class="data row1 col3" >O</td>
#       <td id="T_05c0d_row1_col4" class="data row1 col4" >O</td>
#       <td id="T_05c0d_row1_col5" class="data row1 col5" >O</td>
#       <td id="T_05c0d_row1_col6" class="data row1 col6" >0</td>
#       <td id="T_05c0d_row1_col7" class="data row1 col7" >1</td>
#       <td id="T_05c0d_row1_col8" class="data row1 col8" >1</td>
#       <td id="T_05c0d_row1_col9" class="data row1 col9" >0</td>
#     </tr>
#     <tr>
#       <th id="T_05c0d_level0_row2" class="row_heading level0 row2" >154</th>
#       <td id="T_05c0d_row2_col0" class="data row2 col0" >(250</td>
#       <td id="T_05c0d_row2_col1" class="data row2 col1" >1420</td>
#       <td id="T_05c0d_row2_col2" class="data row2 col2" >1424</td>
#       <td id="T_05c0d_row2_col3" class="data row2 col3" >O</td>
#       <td id="T_05c0d_row2_col4" class="data row2 col4" >O</td>
#       <td id="T_05c0d_row2_col5" class="data row2 col5" >O</td>
#       <td id="T_05c0d_row2_col6" class="data row2 col6" >0</td>
#       <td id="T_05c0d_row2_col7" class="data row2 col7" >1</td>
#       <td id="T_05c0d_row2_col8" class="data row2 col8" >1</td>
#       <td id="T_05c0d_row2_col9" class="data row2 col9" >0</td>
#     </tr>
#     <tr>
#       <th id="T_05c0d_level0_row3" class="row_heading level0 row3" >217</th>
#       <td id="T_05c0d_row3_col0" class="data row3 col0" >(10/2017)</td>
#       <td id="T_05c0d_row3_col1" class="data row3 col1" >1892</td>
#       <td id="T_05c0d_row3_col2" class="data row3 col2" >1901</td>
#       <td id="T_05c0d_row3_col3" class="data row3 col3" >O</td>
#       <td id="T_05c0d_row3_col4" class="data row3 col4" >O</td>
#       <td id="T_05c0d_row3_col5" class="data row3 col5" >O</td>
#       <td id="T_05c0d_row3_col6" class="data row3 col6" >0</td>
#       <td id="T_05c0d_row3_col7" class="data row3 col7" >1</td>
#       <td id="T_05c0d_row3_col8" class="data row3 col8" >1</td>
#       <td id="T_05c0d_row3_col9" class="data row3 col9" >1</td>
#     </tr>
#     <tr>
#       <th id="T_05c0d_level0_row4" class="row_heading level0 row4" >243</th>
#       <td id="T_05c0d_row4_col0" class="data row4 col0" >24</td>
#       <td id="T_05c0d_row4_col1" class="data row4 col1" >2086</td>
#       <td id="T_05c0d_row4_col2" class="data row4 col2" >2088</td>
#       <td id="T_05c0d_row4_col3" class="data row4 col3" >O</td>
#       <td id="T_05c0d_row4_col4" class="data row4 col4" >NUM</td>
#       <td id="T_05c0d_row4_col5" class="data row4 col5" >24</td>
#       <td id="T_05c0d_row4_col6" class="data row4 col6" >1</td>
#       <td id="T_05c0d_row4_col7" class="data row4 col7" >1</td>
#       <td id="T_05c0d_row4_col8" class="data row4 col8" >1</td>
#       <td id="T_05c0d_row4_col9" class="data row4 col9" >1</td>
#     </tr>
#     <tr>
#       <th id="T_05c0d_level0_row5" class="row_heading level0 row5" >247</th>
#       <td id="T_05c0d_row5_col0" class="data row5 col0" >2018</td>
#       <td id="T_05c0d_row5_col1" class="data row5 col1" >2101</td>
#       <td id="T_05c0d_row5_col2" class="data row5 col2" >2105</td>
#       <td id="T_05c0d_row5_col3" class="data row5 col3" >O</td>
#       <td id="T_05c0d_row5_col4" class="data row5 col4" >NUM</td>
#       <td id="T_05c0d_row5_col5" class="data row5 col5" >2018</td>
#       <td id="T_05c0d_row5_col6" class="data row5 col6" >1</td>
#       <td id="T_05c0d_row5_col7" class="data row5 col7" >1</td>
#       <td id="T_05c0d_row5_col8" class="data row5 col8" >1</td>
#       <td id="T_05c0d_row5_col9" class="data row5 col9" >1</td>
#     </tr>
#     <tr>
#       <th id="T_05c0d_level0_row6" class="row_heading level0 row6" >335</th>
#       <td id="T_05c0d_row6_col0" class="data row6 col0" >n40.0</td>
#       <td id="T_05c0d_row6_col1" class="data row6 col1" >2741</td>
#       <td id="T_05c0d_row6_col2" class="data row6 col2" >2746</td>
#       <td id="T_05c0d_row6_col3" class="data row6 col3" >O</td>
#       <td id="T_05c0d_row6_col4" class="data row6 col4" >ADJ</td>
#       <td id="T_05c0d_row6_col5" class="data row6 col5" >n40.0</td>
#       <td id="T_05c

# %%
# Filter the DataFrame where "Maj NUMBER" is equal to 1
filtered_df = data[(data['Maj NUMBER'] == 1) & (data['Contains NUMBER'] == 0)]
show_data(datos=filtered_df, first=0, second=10)
# Out:
# <style type="text/css">
# </style>
# <table id="T_ed2ae" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ed2ae_level0_col0" class="col_heading level0 col0" >Word</th>
#       <th id="T_ed2ae_level0_col1" class="col_heading level0 col1" >Initial Scopes</th>
#       <th id="T_ed2ae_level0_col2" class="col_heading level0 col2" >Final Scopes</th>
#       <th id="T_ed2ae_level0_col3" class="col_heading level0 col3" >Tag</th>
#       <th id="T_ed2ae_level0_col4" class="col_heading level0 col4" >POS</th>
#       <th id="T_ed2ae_level0_col5" class="col_heading level0 col5" >LEMMA</th>
#       <th id="T_ed2ae_level0_col6" class="col_heading level0 col6" >NUMBER</th>
#       <th id="T_ed2ae_level0_col7" class="col_heading level0 col7" >Contains NUMBER</th>
#       <th id="T_ed2ae_level0_col8" class="col_heading level0 col8" >Maj NUMBER</th>
#       <th id="T_ed2ae_level0_col9" class="col_heading level0 col9" >text_id</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
# Filter the DataFrame where "Maj NUMBER" is equal to 1
filtered_df = data[(data['Maj NUMBER'] == 0) & (data['Contains NUMBER'] == 0)]
show_data(datos=filtered_df, first=0, second=10)
# Out:
# <style type="text/css">
# #T_93920_row0_col0, #T_93920_row0_col1, #T_93920_row0_col2, #T_93920_row0_col3, #T_93920_row0_col4, #T_93920_row0_col5, #T_93920_row0_col6, #T_93920_row0_col7, #T_93920_row0_col8, #T_93920_row0_col9, #T_93920_row1_col0, #T_93920_row1_col1, #T_93920_row1_col2, #T_93920_row1_col3, #T_93920_row1_col4, #T_93920_row1_col5, #T_93920_row1_col6, #T_93920_row1_col7, #T_93920_row1_col8, #T_93920_row1_col9, #T_93920_row2_col0, #T_93920_row2_col1, #T_93920_row2_col2, #T_93920_row2_col3, #T_93920_row2_col4, #T_93920_row2_col5, #T_93920_row2_col6, #T_93920_row2_col7, #T_93920_row2_col8, #T_93920_row2_col9, #T_93920_row3_col0, #T_93920_row3_col1, #T_93920_row3_col2, #T_93920_row3_col3, #T_93920_row3_col4, #T_93920_row3_col5, #T_93920_row3_col6, #T_93920_row3_col7, #T_93920_row3_col8, #T_93920_row3_col9, #T_93920_row4_col0, #T_93920_row4_col1, #T_93920_row4_col2, #T_93920_row4_col3, #T_93920_row4_col4, #T_93920_row4_col5, #T_93920_row4_col6, #T_93920_row4_col7, #T_93920_row4_col8, #T_93920_row4_col9, #T_93920_row5_col0, #T_93920_row5_col1, #T_93920_row5_col2, #T_93920_row5_col3, #T_93920_row5_col4, #T_93920_row5_col5, #T_93920_row5_col6, #T_93920_row5_col7, #T_93920_row5_col8, #T_93920_row5_col9, #T_93920_row6_col0, #T_93920_row6_col1, #T_93920_row6_col2, #T_93920_row6_col3, #T_93920_row6_col4, #T_93920_row6_col5, #T_93920_row6_col6, #T_93920_row6_col7, #T_93920_row6_col8, #T_93920_row6_col9, #T_93920_row7_col0, #T_93920_row7_col1, #T_93920_row7_col2, #T_93920_row7_col3, #T_93920_row7_col4, #T_93920_row7_col5, #T_93920_row7_col6, #T_93920_row7_col7, #T_93920_row7_col8, #T_93920_row7_col9, #T_93920_row8_col0, #T_93920_row8_col1, #T_93920_row8_col2, #T_93920_row8_col3, #T_93920_row8_col4, #T_93920_row8_col5, #T_93920_row8_col6, #T_93920_row8_col7, #T_93920_row8_col8, #T_93920_row8_col9, #T_93920_row9_col0, #T_93920_row9_col1, #T_93920_row9_col2, #T_93920_row9_col3, #T_93920_row9_col4, #T_93920_row9_col5, #T_93920_row9_col6, #T_93920_row9_col7, #T_93920_row9_col8, #T_93920_row9_col9 {
#   text-align: left;
# }
# </style>
# <table id="T_93920" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_93920_level0_col0" class="col_heading level0 col0" >Word</th>
#       <th id="T_93920_level0_col1" class="col_heading level0 col1" >Initial Scopes</th>
#       <th id="T_93920_level0_col2" class="col_heading level0 col2" >Final Scopes</th>
#       <th id="T_93920_level0_col3" class="col_heading level0 col3" >Tag</th>
#       <th id="T_93920_level0_col4" class="col_heading level0 col4" >POS</th>
#       <th id="T_93920_level0_col5" class="col_heading level0 col5" >LEMMA</th>
#       <th id="T_93920_level0_col6" class="col_heading level0 col6" >NUMBER</th>
#       <th id="T_93920_level0_col7" class="col_heading level0 col7" >Contains NUMBER</th>
#       <th id="T_93920_level0_col8" class="col_heading level0 col8" >Maj NUMBER</th>
#       <th id="T_93920_level0_col9" class="col_heading level0 col9" >text_id</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_93920_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_93920_row0_col0" class="data row0 col0" >paciente</td>
#       <td id="T_93920_row0_col1" class="data row0 col1" >315</td>
#       <td id="T_93920_row0_col2" class="data row0 col2" >323</td>
#       <td id="T_93920_row0_col3" class="data row0 col3" >O</td>
#       <td id="T_93920_row0_col4" class="data row0 col4" >NOUN</td>
#       <td id="T_93920_row0_col5" class="data row0 col5" >paciente</td>
#       <td id="T_93920_row0_col6" class="data row0 col6" >0</td>
#       <td id="T_93920_row0_col7" class="data row0 col7" >0</td>
#       <td id="T_93920_row0_col8" class="data row0 col8" >0</td>
#       <td id="T_93920_row0_col9" class="data row0 col9" >0</td>
#     </tr>
#     <tr>
#       <th id="T_93920_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_93920_row1_col0" class="data row1 col0" >que</td>
#       <td id="T_93920_row1_col1" class="data row1 col1" >324</td>
#       <td id="T_93920_row1_col2" class="data row1 col2" >327</td>
#       <td id="T_93920_row1_col3" class="data row1 col3" >O</td>
#       <td id="T_93920_row1_col4" class="data row1 col4" >SCONJ</td>
#       <td id="T_93920_row1_col5" class="data row1 col5" >que</td>
#       <td id="T_93920_row1_col6" class="data row1 col6" >0</td>
#       <td id="T_93920_row1_col7" class="data row1 col7" >0</td>
#       <td id="T_93920_row1_col8" class="data row1 col8" >0</td>
#       <td id="T_93920_row1_col9" class="data row1 col9" >0</td>
#     </tr>
#     <tr>
#       <th id="T_93920_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_93920_row2_col0" class="data row2 col0" >ingresa</td>
#       <td id="T_93920_row2_col1" class="data row2 col1" >328</td>
#       <td id="T_93920_row2_col2" class="data row2 col2" >335</td>
#       <td id="T_93920_row2_col3" class="data row2 col3" >O</td>
#       <td id="T_93920_row2_col4" class="data row2 col4" >VERB</td>
#       <td id="T_93920_row2_col5" class="data row2 col5" >ingresar</td>
#       <td id="T_93920_row2_col6" class="data row2 col6" >0</td>
#       <td id="T_93920_row2_col7" class="data row2 col7" >0</td>
#       <td id="T_93920_row2_col8" class="data row2 col8" >0</td>
#       <td id="T_93920_row2_col9" class="data row2 col9" >0</td>
#     </tr>
#     <tr>
#       <th id="T_93920_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_93920_row3_col0" class="data row3 col0" >de</td>
#       <td id="T_93920_row3_col1" class="data row3 col1" >336</td>
#       <td id="T_93920_row3_col2" class="data row3 col2" >338</td>
#       <td id="T_93920_row3_col3" class="data row3 col3" >O</td>
#       <td id="T_93920_row3_col4" class="data row3 col4" >ADP</td>
#       <td id="T_93920_row3_col5" class="data row3 col5" >de</td>
#       <td id="T_93920_row3_col6" class="data row3 col6" >0</td>
#       <td id="T_93920_row3_col7" class="data row3 col7" >0</td>
#       <td id="T_93920_row3_col8" class="data row3 col8" >0</td>
#       <td id="T_93920_row3_col9" class="data row3 col9" >0</td>
#     </tr>
#     <tr>
#       <th id="T_93920_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_93920_row4_col0" class="data row4 col0" >forma</td>
#       <td id="T_93920_row4_col1" class="data row4 col1" >339</td>
#       <td id="T_93920_row4_col2" class="data row4 col2" >344</td>
#       <td id="T_93920_row4_col3" class="data row4 col3" >O</td>
#       <td id="T_93920_row4_col4" class="data row4 col4" >NOUN</td>
#       <td id="T_93920_row4_col5" class="data row4 col5" >forma</td>
#       <td id="T_93920_row4_col6" class="data row4 col6" >0</td>
#       <td id="T_93920_row4_col7" class="data row4 col7" >0</td>
#       <td id="T_93920_row4_col8" class="data row4 col8" >0</td>
#       <td id="T_93920_row4_col9" class="data row4 col9" >0</td>
#     </tr>
#     <tr>
#       <th id="T_93920_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_93920_row5_col0" class="data row5 col0" >programada</td>
#       <td id="T_93920_row5_col1" class="data row5 col1" >345</td>
#       <td id="T_93920_row5_col2" class="data row5 col2" >355</td>
#       <td id="T_93920_row5_col3" class="data row5 col3" >O</td>
#       <td id="T_93920_row5_col4" class="data row5 col4" >ADJ</td>
#       <td id="T_93920_row5_col5" class="data row5 col5" >programado</td>
#       <td id="T_93920_row5_col6" class="data row5 col6" >0</td>
#       <td id="T_93920_row5_col7" class="data row5 col7" >0</td>
#       <td id="T_93920_row5_col8" class="data row5 col8" >0</td>
#       <td id="T_93920_row5_col9" class="data row5 col9" >0</td>
#     </tr>
#     <tr>
#       <th id="T_93920_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_93920_row6_col0" class="data row6 col0" >para</td>
#       <td id="T_93920_row6_col1" class="data row6 col1" >356</td>
#       <td id="T_93920_row6_col2" class="data row6 col2" >360</td>
#       <td id="T_93920_row6_col3" class="data row6 col3" >O</td>
#       <td id="T_93920_row6_col4" class="data row6 col4" >ADP</td>
#       <td id="T_93920_row6_col5" class="data row6 col5" >para</td>
#       <t

# %%
# Filter the DataFrame where "Maj NUMBER" is equal to 1
filtered_df = data[data['NUMBER'] == 1]
show_data(datos=filtered_df, first=0, second=10)
# Out:
# <style type="text/css">
# #T_69cfb_row0_col0, #T_69cfb_row0_col1, #T_69cfb_row0_col2, #T_69cfb_row0_col3, #T_69cfb_row0_col4, #T_69cfb_row0_col5, #T_69cfb_row0_col6, #T_69cfb_row0_col7, #T_69cfb_row0_col8, #T_69cfb_row0_col9, #T_69cfb_row1_col0, #T_69cfb_row1_col1, #T_69cfb_row1_col2, #T_69cfb_row1_col3, #T_69cfb_row1_col4, #T_69cfb_row1_col5, #T_69cfb_row1_col6, #T_69cfb_row1_col7, #T_69cfb_row1_col8, #T_69cfb_row1_col9, #T_69cfb_row2_col0, #T_69cfb_row2_col1, #T_69cfb_row2_col2, #T_69cfb_row2_col3, #T_69cfb_row2_col4, #T_69cfb_row2_col5, #T_69cfb_row2_col6, #T_69cfb_row2_col7, #T_69cfb_row2_col8, #T_69cfb_row2_col9, #T_69cfb_row3_col0, #T_69cfb_row3_col1, #T_69cfb_row3_col2, #T_69cfb_row3_col3, #T_69cfb_row3_col4, #T_69cfb_row3_col5, #T_69cfb_row3_col6, #T_69cfb_row3_col7, #T_69cfb_row3_col8, #T_69cfb_row3_col9, #T_69cfb_row4_col0, #T_69cfb_row4_col1, #T_69cfb_row4_col2, #T_69cfb_row4_col3, #T_69cfb_row4_col4, #T_69cfb_row4_col5, #T_69cfb_row4_col6, #T_69cfb_row4_col7, #T_69cfb_row4_col8, #T_69cfb_row4_col9, #T_69cfb_row5_col0, #T_69cfb_row5_col1, #T_69cfb_row5_col2, #T_69cfb_row5_col3, #T_69cfb_row5_col4, #T_69cfb_row5_col5, #T_69cfb_row5_col6, #T_69cfb_row5_col7, #T_69cfb_row5_col8, #T_69cfb_row5_col9, #T_69cfb_row6_col0, #T_69cfb_row6_col1, #T_69cfb_row6_col2, #T_69cfb_row6_col3, #T_69cfb_row6_col4, #T_69cfb_row6_col5, #T_69cfb_row6_col6, #T_69cfb_row6_col7, #T_69cfb_row6_col8, #T_69cfb_row6_col9, #T_69cfb_row7_col0, #T_69cfb_row7_col1, #T_69cfb_row7_col2, #T_69cfb_row7_col3, #T_69cfb_row7_col4, #T_69cfb_row7_col5, #T_69cfb_row7_col6, #T_69cfb_row7_col7, #T_69cfb_row7_col8, #T_69cfb_row7_col9, #T_69cfb_row8_col0, #T_69cfb_row8_col1, #T_69cfb_row8_col2, #T_69cfb_row8_col3, #T_69cfb_row8_col4, #T_69cfb_row8_col5, #T_69cfb_row8_col6, #T_69cfb_row8_col7, #T_69cfb_row8_col8, #T_69cfb_row8_col9, #T_69cfb_row9_col0, #T_69cfb_row9_col1, #T_69cfb_row9_col2, #T_69cfb_row9_col3, #T_69cfb_row9_col4, #T_69cfb_row9_col5, #T_69cfb_row9_col6, #T_69cfb_row9_col7, #T_69cfb_row9_col8, #T_69cfb_row9_col9 {
#   text-align: left;
# }
# </style>
# <table id="T_69cfb" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_69cfb_level0_col0" class="col_heading level0 col0" >Word</th>
#       <th id="T_69cfb_level0_col1" class="col_heading level0 col1" >Initial Scopes</th>
#       <th id="T_69cfb_level0_col2" class="col_heading level0 col2" >Final Scopes</th>
#       <th id="T_69cfb_level0_col3" class="col_heading level0 col3" >Tag</th>
#       <th id="T_69cfb_level0_col4" class="col_heading level0 col4" >POS</th>
#       <th id="T_69cfb_level0_col5" class="col_heading level0 col5" >LEMMA</th>
#       <th id="T_69cfb_level0_col6" class="col_heading level0 col6" >NUMBER</th>
#       <th id="T_69cfb_level0_col7" class="col_heading level0 col7" >Contains NUMBER</th>
#       <th id="T_69cfb_level0_col8" class="col_heading level0 col8" >Maj NUMBER</th>
#       <th id="T_69cfb_level0_col9" class="col_heading level0 col9" >text_id</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_69cfb_level0_row0" class="row_heading level0 row0" >243</th>
#       <td id="T_69cfb_row0_col0" class="data row0 col0" >24</td>
#       <td id="T_69cfb_row0_col1" class="data row0 col1" >2086</td>
#       <td id="T_69cfb_row0_col2" class="data row0 col2" >2088</td>
#       <td id="T_69cfb_row0_col3" class="data row0 col3" >O</td>
#       <td id="T_69cfb_row0_col4" class="data row0 col4" >NUM</td>
#       <td id="T_69cfb_row0_col5" class="data row0 col5" >24</td>
#       <td id="T_69cfb_row0_col6" class="data row0 col6" >1</td>
#       <td id="T_69cfb_row0_col7" class="data row0 col7" >1</td>
#       <td id="T_69cfb_row0_col8" class="data row0 col8" >1</td>
#       <td id="T_69cfb_row0_col9" class="data row0 col9" >1</td>
#     </tr>
#     <tr>
#       <th id="T_69cfb_level0_row1" class="row_heading level0 row1" >247</th>
#       <td id="T_69cfb_row1_col0" class="data row1 col0" >2018</td>
#       <td id="T_69cfb_row1_col1" class="data row1 col1" >2101</td>
#       <td id="T_69cfb_row1_col2" class="data row1 col2" >2105</td>
#       <td id="T_69cfb_row1_col3" class="data row1 col3" >O</td>
#       <td id="T_69cfb_row1_col4" class="data row1 col4" >NUM</td>
#       <td id="T_69cfb_row1_col5" class="data row1 col5" >2018</td>
#       <td id="T_69cfb_row1_col6" class="data row1 col6" >1</td>
#       <td id="T_69cfb_row1_col7" class="data row1 col7" >1</td>
#       <td id="T_69cfb_row1_col8" class="data row1 col8" >1</td>
#       <td id="T_69cfb_row1_col9" class="data row1 col9" >1</td>
#     </tr>
#     <tr>
#       <th id="T_69cfb_level0_row2" class="row_heading level0 row2" >433</th>
#       <td id="T_69cfb_row2_col0" class="data row2 col0" >14</td>
#       <td id="T_69cfb_row2_col1" class="data row2 col1" >3411</td>
#       <td id="T_69cfb_row2_col2" class="data row2 col2" >3413</td>
#       <td id="T_69cfb_row2_col3" class="data row2 col3" >O</td>
#       <td id="T_69cfb_row2_col4" class="data row2 col4" >NUM</td>
#       <td id="T_69cfb_row2_col5" class="data row2 col5" >14</td>
#       <td id="T_69cfb_row2_col6" class="data row2 col6" >1</td>
#       <td id="T_69cfb_row2_col7" class="data row2 col7" >1</td>
#       <td id="T_69cfb_row2_col8" class="data row2 col8" >1</td>
#       <td id="T_69cfb_row2_col9" class="data row2 col9" >2</td>
#     </tr>
#     <tr>
#       <th id="T_69cfb_level0_row3" class="row_heading level0 row3" >445</th>
#       <td id="T_69cfb_row3_col0" class="data row3 col0" >1</td>
#       <td id="T_69cfb_row3_col1" class="data row3 col1" >3498</td>
#       <td id="T_69cfb_row3_col2" class="data row3 col2" >3499</td>
#       <td id="T_69cfb_row3_col3" class="data row3 col3" >O</td>
#       <td id="T_69cfb_row3_col4" class="data row3 col4" >NUM</td>
#       <td id="T_69cfb_row3_col5" class="data row3 col5" >1</td>
#       <td id="T_69cfb_row3_col6" class="data row3 col6" >1</td>
#       <td id="T_69cfb_row3_col7" class="data row3 col7" >1</td>
#       <td id="T_69cfb_row3_col8" class="data row3 col8" >1</td>
#       <td id="T_69cfb_row3_col9" class="data row3 col9" >2</td>
#     </tr>
#     <tr>
#       <th id="T_69cfb_level0_row4" class="row_heading level0 row4" >448</th>
#       <td id="T_69cfb_row4_col0" class="data row4 col0" >8</td>
#       <td id="T_69cfb_row4_col1" class="data row4 col1" >3507</td>
#       <td id="T_69cfb_row4_col2" class="data row4 col2" >3508</td>
#       <td id="T_69cfb_row4_col3" class="data row4 col3" >O</td>
#       <td id="T_69cfb_row4_col4" class="data row4 col4" >NUM</td>
#       <td id="T_69cfb_row4_col5" class="data row4 col5" >8</td>
#       <td id="T_69cfb_row4_col6" class="data row4 col6" >1</td>
#       <td id="T_69cfb_row4_col7" class="data row4 col7" >1</td>
#       <td id="T_69cfb_row4_col8" class="data row4 col8" >1</td>
#       <td id="T_69cfb_row4_col9" class="data row4 col9" >2</td>
#     </tr>
#     <tr>
#       <th id="T_69cfb_level0_row5" class="row_heading level0 row5" >540</th>
#       <td id="T_69cfb_row5_col0" class="data row5 col0" >2820</td>
#       <td id="T_69cfb_row5_col1" class="data row5 col1" >626</td>
#       <td id="T_69cfb_row5_col2" class="data row5 col2" >630</td>
#       <td id="T_69cfb_row5_col3" class="data row5 col3" >O</td>
#       <td id="T_69cfb_row5_col4" class="data row5 col4" >NUM</td>
#       <td id="T_69cfb_row5_col5" class="data row5 col5" >2820</td>
#       <td id="T_69cfb_row5_col6" class="data row5 col6" >1</td>
#       <td id="T_69cfb_row5_col7" class="data row5 col7" >1</td>
#       <td id="T_69cfb_row5_col8" class="data row5 col8" >1</td>
#       <td id="T_69cfb_row5_col9" class="data row5 col9" >2</td>
#     </tr>
#     <tr>
#       <th id="T_69cfb_level0_row6" class="row_heading level0 row6" >604</th>
#       <td id="T_69cfb_row6_col0" class="data row6 col0" >1</td>
#       <td id="T_69cfb_row6_col1" class="data row6 col1" >1163</td>
#       <td id="T_69cfb_row6_col2" class="data row6 col2" >1164</td>
#       <td id="T_69cfb_row6_col3" class="data row6 col3" >O</td>
#       <td id="T_69cfb_row6_col4" class="data row6 col4" >NUM</td>
#       <td id="T_69cfb_row6_col5" class="data row6 col5" >1</td>
#       <td id="T_69cfb_row6_col6" cla
